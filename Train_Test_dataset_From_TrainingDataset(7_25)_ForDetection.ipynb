# %% [markdown]
# <a href="https://colab.research.google.com/github/nattntn/DataPreparation_ForDeeptooth/blob/main/Train_Test_dataset_From_TrainingDataset(7_25)_ForDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #เรียกใช้ CSV

# %%
import pandas as pd
import shutil

# %%
#เชื่อม google drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# #Imports

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
import matplotlib.pyplot as plt
from IPython.display import Image
# %matplotlib inline
import datetime

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K

# %%
import PIL
from keras import models
from tensorflow.keras import layers
from tensorflow.keras import optimizers
from tensorflow.keras import losses
from tensorflow.keras import metrics
from keras import layers
from tensorflow.keras import optimizers
import tensorflow as tf
import os
import glob
import shutil
import sys
import numpy as np
from skimage.io import imread
from IPython.display import Image
import matplotlib.pyplot as plt
import os
from tensorflow.keras import callbacks
import pandas as pd
#fastest but dirty way to speed hack
from joblib import Parallel, delayed

# %% [markdown]
# # Data Preparation

# %%
df = pd.read_csv(r'/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/table_cut_images/table_train_10Fold_forGender.csv')
df
# Out:
#       Unnamed: 0  Age(year) Gender Folder_type Folder_name  \
# 0              0          7      F      Normal        Both
# 1              1          7      F      Normal        Both
# 2              2          7      F      Normal        Both
# 3              3          7      F      Normal        Both
# 4              4          7      F      Normal        Both
# ...          ...        ...    ...         ...         ...
# 4184        4184         25      M      Normal          Rt
# 4185        4185         25      M      Normal          Rt
# 4186        4186         25      M      Normal          Rt
# 4187        4187         25      M      Normal          Rt
# 4188        4188         25      M      Normal          Rt
#
#                                               Path_Name    Filename  Fold  \
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V1.jpg     2
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV1.jpg     4
# ...

# %%
df = df.iloc[:,1:]
df
# Out:
#       Age(year) Gender Folder_type Folder_name  \
# 0             7      F      Normal        Both
# 1             7      F      Normal        Both
# 2             7      F      Normal        Both
# 3             7      F      Normal        Both
# 4             7      F      Normal        Both
# ...         ...    ...         ...         ...
# 4184         25      M      Normal          Rt
# 4185         25      M      Normal          Rt
# 4186         25      M      Normal          Rt
# 4187         25      M      Normal          Rt
# 4188         25      M      Normal          Rt
#
#                                               Path_Name    Filename  Fold  \
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V1.jpg     2
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV1.jpg     4
# 2     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V2.jpg    10
# 3     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV2.jpg     9
# ...

# %%
df = df[['Age(year)', 'Gender','Gender_Class', 'Folder_type','Folder_name', 'Path_Name', 'Filename']]
df
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0             7      F             0      Normal        Both
# 1             7      F             0      Normal        Both
# 2             7      F             0      Normal        Both
# 3             7      F             0      Normal        Both
# 4             7      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 4184         25      M             1      Normal          Rt
# 4185         25      M             1      Normal          Rt
# 4186         25      M             1      Normal          Rt
# 4187         25      M             1      Normal          Rt
# 4188         25      M             1      Normal          Rt
#
#                                               Path_Name    Filename
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V1.jpg
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV1.jpg
# ...

# %% [markdown]
# # 7 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 7) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 114          7      M             1      Normal        Both
# 115          7      M             1      Normal        Both
# 116          7      M             1      Normal        Both
# 117          7      M             1      Normal        Both
# 118          7      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 209          7      M             1      Normal        Both
# 210          7      M             1      Normal        Both
# 211          7      M             1      Normal        Both
# 212          7      M             1      Normal        Both
# 213          7      M             1      Normal        Both
#
#                                              Path_Name       Filename
# 114  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       VV04.jpg
# 115  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipVV04.jpg
# ...

# %%
MB7 =  MB.iloc[:20,:]
MB7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 114          7      M             1      Normal        Both
# 115          7      M             1      Normal        Both
# 116          7      M             1      Normal        Both
# 117          7      M             1      Normal        Both
# 118          7      M             1      Normal        Both
# 119          7      M             1      Normal        Both
# 120          7      M             1      Normal        Both
# 121          7      M             1      Normal        Both
# 122          7      M             1      Normal        Both
# 123          7      M             1      Normal        Both
# 124          7      M             1      Normal        Both
# 125          7      M             1      Normal        Both
# 126          7      M             1      Normal        Both
# 127          7      M             1      Normal        Both
# 128          7      M             1      Normal        Both
# ...

# %%
len(MB7)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 7) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 214          7      M             1      Normal          Lt
# 215          7      M             1      Normal          Lt
# 216          7      M             1      Normal          Lt
# 217          7      M             1      Normal          Lt
# 218          7      M             1      Normal          Lt
#
#                                              Path_Name        Filename
# 214  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...    FlipVV28.jpg
# 215  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...    FlipVV30.jpg
# 216  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...    FlipVV67.jpg
# 217  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Flip*VV240.jpg
# 218  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Flip*VV105.jpg

# %%
ML7 =  ML.iloc[:1,:]
ML7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 214          7      M             1      Normal          Lt
#
#                                              Path_Name      Filename
# 214  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV28.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 7) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 219          7      M             1      Normal          Rt
# 220          7      M             1      Normal          Rt
# 221          7      M             1      Normal          Rt
# 222          7      M             1      Normal          Rt
# 223          7      M             1      Normal          Rt
# 224          7      M             1      Normal          Rt
#
#                                              Path_Name   Filename
# 219  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   VV02.jpg
# 220  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   VV20.jpg
# 221  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   VV53.jpg
# 222  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   VV66.jpg
# 223  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  VV126.jpg
# 224  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  VV254.jpg

# %%
MR7 =  MR.iloc[:1,:]
MR7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 219          7      M             1      Normal          Rt
#
#                                              Path_Name  Filename
# 219  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  VV02.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 7) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0            7      F             0      Normal        Both
# 1            7      F             0      Normal        Both
# 2            7      F             0      Normal        Both
# 3            7      F             0      Normal        Both
# 4            7      F             0      Normal        Both
# ..         ...    ...           ...         ...         ...
# 101          7      F             0      Normal        Both
# 102          7      F             0      Normal        Both
# 103          7      F             0      Normal        Both
# 104          7      F             0      Normal        Both
# 105          7      F             0      Normal        Both
#
#                                              Path_Name       Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...         V1.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...     FlipV1.jpg
# ...

# %%
FB7 =  FB.iloc[:20,:]
FB7
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0           7      F             0      Normal        Both
# 1           7      F             0      Normal        Both
# 2           7      F             0      Normal        Both
# 3           7      F             0      Normal        Both
# 4           7      F             0      Normal        Both
# 5           7      F             0      Normal        Both
# 6           7      F             0      Normal        Both
# 7           7      F             0      Normal        Both
# 8           7      F             0      Normal        Both
# 9           7      F             0      Normal        Both
# 10          7      F             0      Normal        Both
# 11          7      F             0      Normal        Both
# 12          7      F             0      Normal        Both
# 13          7      F             0      Normal        Both
# 14          7      F             0      Normal        Both
# ...

# %%
len(FB7)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 7) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 106          7      F             0      Normal          Lt
# 107          7      F             0      Normal          Lt
# 108          7      F             0      Normal          Lt
# 109          7      F             0      Normal          Lt
# 110          7      F             0      Normal          Lt
# 111          7      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 106  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV10.jpg
# 107  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV14.jpg
# 108  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV15.jpg
# 109  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV27.jpg
# 110  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV46.jpg
# 111  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV60.jpg

# %%
FL7 =  FL.iloc[:1,:]
FL7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 106          7      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 106  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV10.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 7) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 112          7      F             0      Normal          Rt
# 113          7      F             0      Normal          Rt
#
#                                              Path_Name Filename
# 112  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  V20.jpg
# 113  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  V50.jpg

# %%
FR7 =  FR.iloc[:1,:]
FR7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 112          7      F             0      Normal          Rt
#
#                                              Path_Name Filename
# 112  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  V20.jpg

# %% [markdown]
# ## 7Y (concat)

# %%
len(pd.concat([MB7,ML7,MR7]))
# Out:
# 22

# %%
len(pd.concat([FB7,FL7,FR7]))
# Out:
# 22

# %%
Y7 = pd.concat([MB7,ML7,MR7,FB7,FL7,FR7])
Y7
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 114          7      M             1      Normal        Both
# 115          7      M             1      Normal        Both
# 116          7      M             1      Normal        Both
# 117          7      M             1      Normal        Both
# 118          7      M             1      Normal        Both
# 119          7      M             1      Normal        Both
# 120          7      M             1      Normal        Both
# 121          7      M             1      Normal        Both
# 122          7      M             1      Normal        Both
# 123          7      M             1      Normal        Both
# 124          7      M             1      Normal        Both
# 125          7      M             1      Normal        Both
# 126          7      M             1      Normal        Both
# 127          7      M             1      Normal        Both
# 128          7      M             1      Normal        Both
# ...

# %%
len(Y7) #img
# Out:
# 44

# %% [markdown]
# # 8 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 8) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 341          8      M             1      Normal        Both
# 342          8      M             1      Normal        Both
# 343          8      M             1      Normal        Both
# 344          8      M             1      Normal        Both
# 345          8      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 442          8      M             1      Normal        Both
# 443          8      M             1      Normal        Both
# 444          8      M             1      Normal        Both
# 445          8      M             1      Normal        Both
# 446          8      M             1      Normal        Both
#
#                                              Path_Name       Filename
# 341  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       PP03.jpg
# 342  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipPP03.jpg
# ...

# %%
MB8 =  MB.iloc[:20,:]
MB8
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 341          8      M             1      Normal        Both
# 342          8      M             1      Normal        Both
# 343          8      M             1      Normal        Both
# 344          8      M             1      Normal        Both
# 345          8      M             1      Normal        Both
# 346          8      M             1      Normal        Both
# 347          8      M             1      Normal        Both
# 348          8      M             1      Normal        Both
# 349          8      M             1      Normal        Both
# 350          8      M             1      Normal        Both
# 351          8      M             1      Normal        Both
# 352          8      M             1      Normal        Both
# 353          8      M             1      Normal        Both
# 354          8      M             1      Normal        Both
# 355          8      M             1      Normal        Both
# ...

# %%
len(MB8)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 8) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 447          8      M             1      Normal          Lt
# 448          8      M             1      Normal          Lt
# 449          8      M             1      Normal          Lt
# 450          8      M             1      Normal          Lt
# 451          8      M             1      Normal          Lt
# 452          8      M             1      Normal          Lt
#
#                                              Path_Name       Filename
# 447  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipPP46.jpg
# 448  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipPP61.jpg
# 449  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP118.jpg
# 450  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP136.jpg
# 451  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP137.jpg
# 452  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP138.jpg

# %%
ML8 =  ML.iloc[:1,:]
ML8
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 447          8      M             1      Normal          Lt
#
#                                              Path_Name      Filename
# 447  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP46.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 8) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 453          8      M             1      Normal          Rt
# 454          8      M             1      Normal          Rt
# 455          8      M             1      Normal          Rt
# 456          8      M             1      Normal          Rt
#
#                                              Path_Name   Filename
# 453  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   PP27.jpg
# 454  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   PP38.jpg
# 455  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  PP119.jpg
# 456  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  PP141.jpg

# %%
MR8 =  MR.iloc[:1,:]
MR8
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 453          8      M             1      Normal          Rt
#
#                                              Path_Name  Filename
# 453  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  PP27.jpg

# %% [markdown]
# ## Female (12 คน 24 ภาพ)

# %% [markdown]
# ### Both (12/24)

# %%
FB = df[(df['Age(year)']== 8) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 225          8      F             0      Normal        Both
# 226          8      F             0      Normal        Both
# 227          8      F             0      Normal        Both
# 228          8      F             0      Normal        Both
# 229          8      F             0      Normal        Both
# ..         ...    ...           ...         ...         ...
# 336          8      F             0      Normal        Both
# 337          8      F             0      Normal        Both
# 338          8      F             0      Normal        Both
# 339          8      F             0      Normal        Both
# 340          8      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 225  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       P01.jpg
# 226  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipP01.jpg
# ...

# %%
FB8 =  FB.iloc[:24,:]
FB8
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 225          8      F             0      Normal        Both
# 226          8      F             0      Normal        Both
# 227          8      F             0      Normal        Both
# 228          8      F             0      Normal        Both
# 229          8      F             0      Normal        Both
# 230          8      F             0      Normal        Both
# 231          8      F             0      Normal        Both
# 232          8      F             0      Normal        Both
# 233          8      F             0      Normal        Both
# 234          8      F             0      Normal        Both
# 235          8      F             0      Normal        Both
# 236          8      F             0      Normal        Both
# 237          8      F             0      Normal        Both
# 238          8      F             0      Normal        Both
# 239          8      F             0      Normal        Both
# ...

# %%
len(FB8)
# Out:
# 24

# %% [markdown]
# ### Lt (0/0)

# %%
FL = df[(df['Age(year)']== 8) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FL8 =  FL.iloc[:1,:]
# FL8

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 8) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FR8 =  FR.iloc[:1,:]
# FR8

# %% [markdown]
# ## 8Y (concat)

# %%
len(pd.concat([MB8,ML8,MR8]))
# Out:
# 22

# %%
len(FB8)
# Out:
# 24

# %%
Y8 = pd.concat([MB8,ML8,MR8,FB8])
Y8
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 341          8      M             1      Normal        Both
# 342          8      M             1      Normal        Both
# 343          8      M             1      Normal        Both
# 344          8      M             1      Normal        Both
# 345          8      M             1      Normal        Both
# 346          8      M             1      Normal        Both
# 347          8      M             1      Normal        Both
# 348          8      M             1      Normal        Both
# 349          8      M             1      Normal        Both
# 350          8      M             1      Normal        Both
# 351          8      M             1      Normal        Both
# 352          8      M             1      Normal        Both
# 353          8      M             1      Normal        Both
# 354          8      M             1      Normal        Both
# 355          8      M             1      Normal        Both
# ...

# %%
len(Y8) #img
# Out:
# 46

# %% [markdown]
# # 9 Year

# %% [markdown]
# ## Male (12 คน 24 ภาพ)

# %% [markdown]
# ### Both (12/24)

# %%
MB = df[(df['Age(year)']== 9) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 577          9      M             1      Normal        Both
# 578          9      M             1      Normal        Both
# 579          9      M             1      Normal        Both
# 580          9      M             1      Normal        Both
# 581          9      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 694          9      M             1      Normal        Both
# 695          9      M             1      Normal        Both
# 696          9      M             1      Normal        Both
# 697          9      M             1      Normal        Both
# 698          9      M             1      Normal        Both
#
#                                              Path_Name       Filename
# 577  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       WW01.jpg
# 578  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipWW01.jpg
# ...

# %%
MB9 =  MB.iloc[:24,:]
MB9
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 577          9      M             1      Normal        Both
# 578          9      M             1      Normal        Both
# 579          9      M             1      Normal        Both
# 580          9      M             1      Normal        Both
# 581          9      M             1      Normal        Both
# 582          9      M             1      Normal        Both
# 583          9      M             1      Normal        Both
# 584          9      M             1      Normal        Both
# 585          9      M             1      Normal        Both
# 586          9      M             1      Normal        Both
# 587          9      M             1      Normal        Both
# 588          9      M             1      Normal        Both
# 589          9      M             1      Normal        Both
# 590          9      M             1      Normal        Both
# 591          9      M             1      Normal        Both
# ...

# %%
len(MB9)
# Out:
# 24

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 9) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# ML9 =  ML.iloc[:1,:]
# ML9

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 9) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# MR9 =  MR.iloc[:1,:]
# MR9

# %% [markdown]
# ## Female (13 คน 22 ภาพ)

# %% [markdown]
# ### Both (9/18)

# %%
FB = df[(df['Age(year)']== 9) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 457          9      F             0      Normal        Both
# 458          9      F             0      Normal        Both
# 459          9      F             0      Normal        Both
# 460          9      F             0      Normal        Both
# 461          9      F             0      Normal        Both
# ..         ...    ...           ...         ...         ...
# 568          9      F             0      Normal        Both
# 569          9      F             0      Normal        Both
# 570          9      F             0      Normal        Both
# 571          9      F             0      Normal        Both
# 572          9      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 457  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       W06.jpg
# 458  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipW06.jpg
# ...

# %%
FB9 =  FB.iloc[:18,:]
FB9
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 457          9      F             0      Normal        Both
# 458          9      F             0      Normal        Both
# 459          9      F             0      Normal        Both
# 460          9      F             0      Normal        Both
# 461          9      F             0      Normal        Both
# 462          9      F             0      Normal        Both
# 463          9      F             0      Normal        Both
# 464          9      F             0      Normal        Both
# 465          9      F             0      Normal        Both
# 466          9      F             0      Normal        Both
# 467          9      F             0      Normal        Both
# 468          9      F             0      Normal        Both
# 469          9      F             0      Normal        Both
# 470          9      F             0      Normal        Both
# 471          9      F             0      Normal        Both
# ...

# %%
len(FB9)
# Out:
# 18

# %% [markdown]
# ### Lt (3/3)

# %%
FL = df[(df['Age(year)']== 9) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 573          9      F             0      Normal          Lt
# 574          9      F             0      Normal          Lt
# 575          9      F             0      Normal          Lt
#
#                                              Path_Name      Filename
# 573  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipW37.jpg
# 574  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipW42.jpg
# 575  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW110.jpg

# %%
FL9 =  FL.iloc[:3,:]
FL9
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 573          9      F             0      Normal          Lt
# 574          9      F             0      Normal          Lt
# 575          9      F             0      Normal          Lt
#
#                                              Path_Name      Filename
# 573  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipW37.jpg
# 574  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipW42.jpg
# 575  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW110.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 9) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 576          9      F             0      Normal          Rt
#
#                                              Path_Name Filename
# 576  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  W21.jpg

# %%
FR9 =  FR.iloc[:1,:]
FR9
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 576          9      F             0      Normal          Rt
#
#                                              Path_Name Filename
# 576  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  W21.jpg

# %% [markdown]
# ## 9Y (concat)

# %%
len(MB9)
# Out:
# 24

# %%
len(pd.concat([FB9,FL9,FR9]))
# Out:
# 22

# %%
Y9 = pd.concat([MB9,FB9,FL9,FR9])
Y9
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 577          9      M             1      Normal        Both
# 578          9      M             1      Normal        Both
# 579          9      M             1      Normal        Both
# 580          9      M             1      Normal        Both
# 581          9      M             1      Normal        Both
# 582          9      M             1      Normal        Both
# 583          9      M             1      Normal        Both
# 584          9      M             1      Normal        Both
# 585          9      M             1      Normal        Both
# 586          9      M             1      Normal        Both
# 587          9      M             1      Normal        Both
# 588          9      M             1      Normal        Both
# 589          9      M             1      Normal        Both
# 590          9      M             1      Normal        Both
# 591          9      M             1      Normal        Both
# ...

# %%
len(Y9) #img
# Out:
# 46

# %% [markdown]
# # 10 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 10) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 815         10      M             1      Normal        Both
# 816         10      M             1      Normal        Both
# 817         10      M             1      Normal        Both
# 818         10      M             1      Normal        Both
# 819         10      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 924         10      M             1      Normal        Both
# 925         10      M             1      Normal        Both
# 926         10      M             1      Normal        Both
# 927         10      M             1      Normal        Both
# 928         10      M             1      Normal        Both
#
#                                              Path_Name       Filename
# 815  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...        HH4.jpg
# 816  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...    FlipHH4.jpg
# ...

# %%
MB10 =  MB.iloc[:22,:]
MB10
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 815         10      M             1      Normal        Both
# 816         10      M             1      Normal        Both
# 817         10      M             1      Normal        Both
# 818         10      M             1      Normal        Both
# 819         10      M             1      Normal        Both
# 820         10      M             1      Normal        Both
# 821         10      M             1      Normal        Both
# 822         10      M             1      Normal        Both
# 823         10      M             1      Normal        Both
# 824         10      M             1      Normal        Both
# 825         10      M             1      Normal        Both
# 826         10      M             1      Normal        Both
# 827         10      M             1      Normal        Both
# 828         10      M             1      Normal        Both
# 829         10      M             1      Normal        Both
# ...

# %%
len(MB10)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 10) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# ML10 =  ML.iloc[:1,:]
# ML10

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 10) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# MR10 =  MR.iloc[:1,:]
# MR10

# %% [markdown]
# ## Female (12 คน 24 ภาพ)

# %% [markdown]
# ### Both (12/24)

# %%
FB = df[(df['Age(year)']== 10) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 699         10      F             0      Normal        Both
# 700         10      F             0      Normal        Both
# 701         10      F             0      Normal        Both
# 702         10      F             0      Normal        Both
# 703         10      F             0      Normal        Both
# ..         ...    ...           ...         ...         ...
# 810         10      F             0      Normal        Both
# 811         10      F             0      Normal        Both
# 812         10      F             0      Normal        Both
# 813         10      F             0      Normal        Both
# 814         10      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 699  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       H02.jpg
# 700  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipH02.jpg
# ...

# %%
FB10 =  FB.iloc[:24,:]
FB10
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 699         10      F             0      Normal        Both
# 700         10      F             0      Normal        Both
# 701         10      F             0      Normal        Both
# 702         10      F             0      Normal        Both
# 703         10      F             0      Normal        Both
# 704         10      F             0      Normal        Both
# 705         10      F             0      Normal        Both
# 706         10      F             0      Normal        Both
# 707         10      F             0      Normal        Both
# 708         10      F             0      Normal        Both
# 709         10      F             0      Normal        Both
# 710         10      F             0      Normal        Both
# 711         10      F             0      Normal        Both
# 712         10      F             0      Normal        Both
# 713         10      F             0      Normal        Both
# ...

# %%
len(FB10)
# Out:
# 24

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 10) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FL10 =  FL.iloc[:1,:]
# FL10

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 10) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FR10 =  FR.iloc[:1,:]
# FR10

# %% [markdown]
# ## 10Y (concat)

# %%
len(MB10)
# Out:
# 22

# %%
len(FB10)
# Out:
# 24

# %%
Y10 = pd.concat([MB10,FB10])
Y10
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 815         10      M             1      Normal        Both
# 816         10      M             1      Normal        Both
# 817         10      M             1      Normal        Both
# 818         10      M             1      Normal        Both
# 819         10      M             1      Normal        Both
# 820         10      M             1      Normal        Both
# 821         10      M             1      Normal        Both
# 822         10      M             1      Normal        Both
# 823         10      M             1      Normal        Both
# 824         10      M             1      Normal        Both
# 825         10      M             1      Normal        Both
# 826         10      M             1      Normal        Both
# 827         10      M             1      Normal        Both
# 828         10      M             1      Normal        Both
# 829         10      M             1      Normal        Both
# ...

# %%
len(Y10) #img
# Out:
# 46

# %% [markdown]
# # 11 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 11) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1046         11      M             1      Normal        Both
# 1047         11      M             1      Normal        Both
# 1048         11      M             1      Normal        Both
# 1049         11      M             1      Normal        Both
# 1050         11      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1151         11      M             1      Normal        Both
# 1152         11      M             1      Normal        Both
# 1153         11      M             1      Normal        Both
# 1154         11      M             1      Normal        Both
# 1155         11      M             1      Normal        Both
#
#                                               Path_Name       Filename
# 1046  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       DD06.jpg
# 1047  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipDD06.jpg
# ...

# %%
MB11 =  MB.iloc[:20,:]
MB11
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1046         11      M             1      Normal        Both
# 1047         11      M             1      Normal        Both
# 1048         11      M             1      Normal        Both
# 1049         11      M             1      Normal        Both
# 1050         11      M             1      Normal        Both
# 1051         11      M             1      Normal        Both
# 1052         11      M             1      Normal        Both
# 1053         11      M             1      Normal        Both
# 1054         11      M             1      Normal        Both
# 1055         11      M             1      Normal        Both
# 1056         11      M             1      Normal        Both
# 1057         11      M             1      Normal        Both
# 1058         11      M             1      Normal        Both
# 1059         11      M             1      Normal        Both
# ...

# %%
len(MB11)
# Out:
# 20

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 11) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# ML11 =  ML.iloc[:1,:]
# ML11

# %% [markdown]
# ### Rt (2/2)

# %%
MR = df[(df['Age(year)']== 11) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1156         11      M             1      Normal          Rt
# 1157         11      M             1      Normal          Rt
# 1158         11      M             1      Normal          Rt
# 1159         11      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 1156  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD54.jpg
# 1157  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD61.jpg
# 1158  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD73.jpg
# 1159  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD75.jpg

# %%
MR11 =  MR.iloc[:2,:]
MR11
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1156         11      M             1      Normal          Rt
# 1157         11      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 1156  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD54.jpg
# 1157  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  DD61.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 11) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 929          11      F             0      Normal        Both
# 930          11      F             0      Normal        Both
# 931          11      F             0      Normal        Both
# 932          11      F             0      Normal        Both
# 933          11      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1034         11      F             0      Normal        Both
# 1035         11      F             0      Normal        Both
# 1036         11      F             0      Normal        Both
# 1037         11      F             0      Normal        Both
# 1038         11      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 929   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       D03.jpg
# 930   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipD03.jpg
# ...

# %%
FB11 =  FB.iloc[:20,:]
FB11
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 929         11      F             0      Normal        Both
# 930         11      F             0      Normal        Both
# 931         11      F             0      Normal        Both
# 932         11      F             0      Normal        Both
# 933         11      F             0      Normal        Both
# 934         11      F             0      Normal        Both
# 935         11      F             0      Normal        Both
# 936         11      F             0      Normal        Both
# 937         11      F             0      Normal        Both
# 938         11      F             0      Normal        Both
# 939         11      F             0      Normal        Both
# 940         11      F             0      Normal        Both
# 941         11      F             0      Normal        Both
# 942         11      F             0      Normal        Both
# 943         11      F             0      Normal        Both
# ...

# %%
len(FB11)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 11) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1039         11      F             0      Normal          Lt
# 1040         11      F             0      Normal          Lt
# 1041         11      F             0      Normal          Lt
# 1042         11      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 1039  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipD57.jpg
# 1040  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipD62.jpg
# 1041  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD130.jpg
# 1042  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD156.jpg

# %%
FL11 =  FL.iloc[:1,:]
FL11
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1039         11      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 1039  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD57.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 11) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1043         11      F             0      Normal          Rt
# 1044         11      F             0      Normal          Rt
# 1045         11      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 1043  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   D69.jpg
# 1044  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  D113.jpg
# 1045  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  D143.jpg

# %%
FR11 =  FR.iloc[:1,:]
FR11
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1043         11      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 1043  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  D69.jpg

# %% [markdown]
# ## 11Y (concat)

# %%
len(pd.concat([MB11,MR11]))
# Out:
# 22

# %%
len(pd.concat([FB11,FL11,FR11]))
# Out:
# 22

# %%
Y11 = pd.concat([MB11,MR11,FB11,FL11,FR11])
Y11
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1046         11      M             1      Normal        Both
# 1047         11      M             1      Normal        Both
# 1048         11      M             1      Normal        Both
# 1049         11      M             1      Normal        Both
# 1050         11      M             1      Normal        Both
# 1051         11      M             1      Normal        Both
# 1052         11      M             1      Normal        Both
# 1053         11      M             1      Normal        Both
# 1054         11      M             1      Normal        Both
# 1055         11      M             1      Normal        Both
# 1056         11      M             1      Normal        Both
# 1057         11      M             1      Normal        Both
# 1058         11      M             1      Normal        Both
# 1059         11      M             1      Normal        Both
# ...

# %%
len(Y11) #img
# Out:
# 44

# %% [markdown]
# # 12 Year

# %% [markdown]
# ## Male (12 คน 23 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 12) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1277         12      M             1      Normal        Both
# 1278         12      M             1      Normal        Both
# 1279         12      M             1      Normal        Both
# 1280         12      M             1      Normal        Both
# 1281         12      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1390         12      M             1      Normal        Both
# 1391         12      M             1      Normal        Both
# 1392         12      M             1      Normal        Both
# 1393         12      M             1      Normal        Both
# 1394         12      M             1      Normal        Both
#
#                                               Path_Name       Filename
# 1277  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       OO01.jpg
# 1278  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipOO01.jpg
# ...

# %%
MB12 =  MB.iloc[:22,:]
MB12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1277         12      M             1      Normal        Both
# 1278         12      M             1      Normal        Both
# 1279         12      M             1      Normal        Both
# 1280         12      M             1      Normal        Both
# 1281         12      M             1      Normal        Both
# 1282         12      M             1      Normal        Both
# 1283         12      M             1      Normal        Both
# 1284         12      M             1      Normal        Both
# 1285         12      M             1      Normal        Both
# 1286         12      M             1      Normal        Both
# 1287         12      M             1      Normal        Both
# 1288         12      M             1      Normal        Both
# 1289         12      M             1      Normal        Both
# 1290         12      M             1      Normal        Both
# ...

# %%
len(MB12)
# Out:
# 22

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 12) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1395         12      M             1      Normal          Lt
#
#                                               Path_Name       Filename
# 1395  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO157.jpg

# %%
ML12 =  ML.iloc[:1,:]
ML12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1395         12      M             1      Normal          Lt
#
#                                               Path_Name       Filename
# 1395  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO157.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 12) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# MR12 =  MR.iloc[:1,:]
# MR12

# %% [markdown]
# ## Female (13 คน 22 ภาพ)

# %% [markdown]
# ### Both (9/18)

# %%
FB = df[(df['Age(year)']== 12) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1160         12      F             0      Normal        Both
# 1161         12      F             0      Normal        Both
# 1162         12      F             0      Normal        Both
# 1163         12      F             0      Normal        Both
# 1164         12      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1263         12      F             0      Normal        Both
# 1264         12      F             0      Normal        Both
# 1265         12      F             0      Normal        Both
# 1266         12      F             0      Normal        Both
# 1267         12      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 1160  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O04.jpg
# 1161  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO04.jpg
# ...

# %%
FB12 =  FB.iloc[:18,:]
FB12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1160         12      F             0      Normal        Both
# 1161         12      F             0      Normal        Both
# 1162         12      F             0      Normal        Both
# 1163         12      F             0      Normal        Both
# 1164         12      F             0      Normal        Both
# 1165         12      F             0      Normal        Both
# 1166         12      F             0      Normal        Both
# 1167         12      F             0      Normal        Both
# 1168         12      F             0      Normal        Both
# 1169         12      F             0      Normal        Both
# 1170         12      F             0      Normal        Both
# 1171         12      F             0      Normal        Both
# 1172         12      F             0      Normal        Both
# 1173         12      F             0      Normal        Both
# ...

# %%
len(FB12)
# Out:
# 18

# %% [markdown]
# ### Lt (2/2)

# %%
FL = df[(df['Age(year)']== 12) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1268         12      F             0      Normal          Lt
# 1269         12      F             0      Normal          Lt
# 1270         12      F             0      Normal          Lt
# 1271         12      F             0      Normal          Lt
# 1272         12      F             0      Normal          Lt
# 1273         12      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 1268  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO01.jpg
# 1269  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO43.jpg
# 1270  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO109.jpg
# 1271  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO117.jpg
# 1272  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO139.jpg
# 1273  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO143.jpg

# %%
FL12 =  FL.iloc[:2,:]
FL12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1268         12      F             0      Normal          Lt
# 1269         12      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 1268  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO01.jpg
# 1269  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO43.jpg

# %% [markdown]
# ### Rt (2/2)

# %%
FR = df[(df['Age(year)']== 12) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1274         12      F             0      Normal          Rt
# 1275         12      F             0      Normal          Rt
# 1276         12      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 1274  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   O03.jpg
# 1275  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   O54.jpg
# 1276  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  O137.jpg

# %%
FR12 =  FR.iloc[:2,:]
FR12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1274         12      F             0      Normal          Rt
# 1275         12      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 1274  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  O03.jpg
# 1275  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  O54.jpg

# %% [markdown]
# ## 12Y (concat)

# %%
len(pd.concat([MB12,ML12]))
# Out:
# 23

# %%
len(pd.concat([FB12,FL12,FR12]))
# Out:
# 22

# %%
Y12 = pd.concat([MB12,ML12,FB12,FL12,FR12])
Y12
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1277         12      M             1      Normal        Both
# 1278         12      M             1      Normal        Both
# 1279         12      M             1      Normal        Both
# 1280         12      M             1      Normal        Both
# 1281         12      M             1      Normal        Both
# 1282         12      M             1      Normal        Both
# 1283         12      M             1      Normal        Both
# 1284         12      M             1      Normal        Both
# 1285         12      M             1      Normal        Both
# 1286         12      M             1      Normal        Both
# 1287         12      M             1      Normal        Both
# 1288         12      M             1      Normal        Both
# 1289         12      M             1      Normal        Both
# 1290         12      M             1      Normal        Both
# ...

# %%
len(Y12) #img
# Out:
# 45

# %% [markdown]
# # 13 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 13) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1504         13      M             1      Normal        Both
# 1505         13      M             1      Normal        Both
# 1506         13      M             1      Normal        Both
# 1507         13      M             1      Normal        Both
# 1508         13      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1595         13      M             1      Normal        Both
# 1596         13      M             1      Normal        Both
# 1597         13      M             1      Normal        Both
# 1598         13      M             1      Normal        Both
# 1599         13      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 1504  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG08.jpg
# 1505  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG08.jpg
# ...

# %%
MB13 =  MB.iloc[:22,:]
MB13
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1504         13      M             1      Normal        Both
# 1505         13      M             1      Normal        Both
# 1506         13      M             1      Normal        Both
# 1507         13      M             1      Normal        Both
# 1508         13      M             1      Normal        Both
# 1509         13      M             1      Normal        Both
# 1510         13      M             1      Normal        Both
# 1511         13      M             1      Normal        Both
# 1512         13      M             1      Normal        Both
# 1513         13      M             1      Normal        Both
# 1514         13      M             1      Normal        Both
# 1515         13      M             1      Normal        Both
# 1516         13      M             1      Normal        Both
# 1517         13      M             1      Normal        Both
# ...

# %%
len(MB13)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 13) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1600         13      M             1      Normal          Lt
# 1601         13      M             1      Normal          Lt
# 1602         13      M             1      Normal          Lt
# 1603         13      M             1      Normal          Lt
#
#                                               Path_Name       Filename
# 1600  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipGG47.jpg
# 1601  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipGG70.jpg
# 1602  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG104.jpg
# 1603  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG106.jpg

# %%
# ML13 =  ML.iloc[:1,:]
# ML13

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 13) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1604         13      M             1      Normal          Rt
# 1605         13      M             1      Normal          Rt
# 1606         13      M             1      Normal          Rt
# 1607         13      M             1      Normal          Rt
# 1608         13      M             1      Normal          Rt
# 1609         13      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 1604  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  GG25.jpg
# 1605  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  GG46.jpg
# 1606  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  GG64.jpg
# 1607  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  GG66.jpg
# 1608  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  GG90.jpg
# 1609  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  G216.jpg

# %%
# MR13 =  MR.iloc[:1,:]
# MR13

# %% [markdown]
# ## Female (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
FB = df[(df['Age(year)']== 13) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1396         13      F             0      Normal        Both
# 1397         13      F             0      Normal        Both
# 1398         13      F             0      Normal        Both
# 1399         13      F             0      Normal        Both
# 1400         13      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1499         13      F             0      Normal        Both
# 1500         13      F             0      Normal        Both
# 1501         13      F             0      Normal        Both
# 1502         13      F             0      Normal        Both
# 1503         13      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 1396  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G151.jpg
# 1397  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG151.jpg
# ...

# %%
FB13 =  FB.iloc[:22,:]
FB13
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1396         13      F             0      Normal        Both
# 1397         13      F             0      Normal        Both
# 1398         13      F             0      Normal        Both
# 1399         13      F             0      Normal        Both
# 1400         13      F             0      Normal        Both
# 1401         13      F             0      Normal        Both
# 1402         13      F             0      Normal        Both
# 1403         13      F             0      Normal        Both
# 1404         13      F             0      Normal        Both
# 1405         13      F             0      Normal        Both
# 1406         13      F             0      Normal        Both
# 1407         13      F             0      Normal        Both
# 1408         13      F             0      Normal        Both
# 1409         13      F             0      Normal        Both
# ...

# %%
len(FB13)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
FL = df[(df['Age(year)']== 13) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FL13 =  FL.iloc[:1,:]
# FL13

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 13) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FR13 =  FR.iloc[:1,:]
# FR13

# %% [markdown]
# ## 13Y (concat)

# %%
len(MB13)
# Out:
# 22

# %%
len(FB13)
# Out:
# 22

# %%
Y13 = pd.concat([MB13,FB13])
Y13
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1504         13      M             1      Normal        Both
# 1505         13      M             1      Normal        Both
# 1506         13      M             1      Normal        Both
# 1507         13      M             1      Normal        Both
# 1508         13      M             1      Normal        Both
# 1509         13      M             1      Normal        Both
# 1510         13      M             1      Normal        Both
# 1511         13      M             1      Normal        Both
# 1512         13      M             1      Normal        Both
# 1513         13      M             1      Normal        Both
# 1514         13      M             1      Normal        Both
# 1515         13      M             1      Normal        Both
# 1516         13      M             1      Normal        Both
# 1517         13      M             1      Normal        Both
# ...

# %%
len(Y13) #img
# Out:
# 44

# %% [markdown]
# # 14 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 14) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1723         14      M             1      Normal        Both
# 1724         14      M             1      Normal        Both
# 1725         14      M             1      Normal        Both
# 1726         14      M             1      Normal        Both
# 1727         14      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1814         14      M             1      Normal        Both
# 1815         14      M             1      Normal        Both
# 1816         14      M             1      Normal        Both
# 1817         14      M             1      Normal        Both
# 1818         14      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 1723  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY07.jpg
# 1724  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY07.jpg
# ...

# %%
MB14 =  MB.iloc[:20,:]
MB14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1723         14      M             1      Normal        Both
# 1724         14      M             1      Normal        Both
# 1725         14      M             1      Normal        Both
# 1726         14      M             1      Normal        Both
# 1727         14      M             1      Normal        Both
# 1728         14      M             1      Normal        Both
# 1729         14      M             1      Normal        Both
# 1730         14      M             1      Normal        Both
# 1731         14      M             1      Normal        Both
# 1732         14      M             1      Normal        Both
# 1733         14      M             1      Normal        Both
# 1734         14      M             1      Normal        Both
# 1735         14      M             1      Normal        Both
# 1736         14      M             1      Normal        Both
# ...

# %%
len(MB14)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 14) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1819         14      M             1      Normal          Lt
# 1820         14      M             1      Normal          Lt
# 1821         14      M             1      Normal          Lt
# 1822         14      M             1      Normal          Lt
# 1823         14      M             1      Normal          Lt
# 1824         14      M             1      Normal          Lt
# 1825         14      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 1819  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY27.jpg
# 1820  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY38.jpg
# 1821  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY39.jpg
# 1822  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY47.jpg
# 1823  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY64.jpg
# ...

# %%
ML14 =  ML.iloc[:1,:]
ML14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1819         14      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 1819  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY27.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 14) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1826         14      M             1      Normal          Rt
# 1827         14      M             1      Normal          Rt
# 1828         14      M             1      Normal          Rt
# 1829         14      M             1      Normal          Rt
# 1830         14      M             1      Normal          Rt
# 1831         14      M             1      Normal          Rt
# 1832         14      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 1826  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  YY01.jpg
# 1827  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  YY16.jpg
# 1828  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  YY69.jpg
# 1829  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Y231.jpg
# 1830  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Y286.jpg
# 1831  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Y309.jpg
# ...

# %%
MR14 =  MR.iloc[:1,:]
MR14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1826         14      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 1826  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  YY01.jpg

# %% [markdown]
# ## Female (12 คน 23 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
FB = df[(df['Age(year)']== 14) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1610         14      F             0      Normal        Both
# 1611         14      F             0      Normal        Both
# 1612         14      F             0      Normal        Both
# 1613         14      F             0      Normal        Both
# 1614         14      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1717         14      F             0      Normal        Both
# 1718         14      F             0      Normal        Both
# 1719         14      F             0      Normal        Both
# 1720         14      F             0      Normal        Both
# 1721         14      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 1610  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Y05.jpg
# 1611  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipY05.jpg
# ...

# %%
FB14 =  FB.iloc[:22,:]
FB14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1610         14      F             0      Normal        Both
# 1611         14      F             0      Normal        Both
# 1612         14      F             0      Normal        Both
# 1613         14      F             0      Normal        Both
# 1614         14      F             0      Normal        Both
# 1615         14      F             0      Normal        Both
# 1616         14      F             0      Normal        Both
# 1617         14      F             0      Normal        Both
# 1618         14      F             0      Normal        Both
# 1619         14      F             0      Normal        Both
# 1620         14      F             0      Normal        Both
# 1621         14      F             0      Normal        Both
# 1622         14      F             0      Normal        Both
# 1623         14      F             0      Normal        Both
# ...

# %%
len(FB14)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
FL = df[(df['Age(year)']== 14) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FL14 =  FL.iloc[:1,:]
# FL14

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 14) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1722         14      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 1722  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Y90.jpg

# %%
FR14 =  FR.iloc[:1,:]
FR14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1722         14      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 1722  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Y90.jpg

# %% [markdown]
# ## 14Y (concat)

# %%
len(pd.concat([MB14,ML14,MR14]))
# Out:
# 22

# %%
len(pd.concat([FB14,FR14]))
# Out:
# 23

# %%
Y14 = pd.concat([MB14,ML14,MR14,FB14,FR14])
Y14
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1723         14      M             1      Normal        Both
# 1724         14      M             1      Normal        Both
# 1725         14      M             1      Normal        Both
# 1726         14      M             1      Normal        Both
# 1727         14      M             1      Normal        Both
# 1728         14      M             1      Normal        Both
# 1729         14      M             1      Normal        Both
# 1730         14      M             1      Normal        Both
# 1731         14      M             1      Normal        Both
# 1732         14      M             1      Normal        Both
# 1733         14      M             1      Normal        Both
# 1734         14      M             1      Normal        Both
# 1735         14      M             1      Normal        Both
# 1736         14      M             1      Normal        Both
# ...

# %%
len(Y14) #img
# Out:
# 45

# %% [markdown]
# # 15 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 15) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1950         15      M             1      Normal        Both
# 1951         15      M             1      Normal        Both
# 1952         15      M             1      Normal        Both
# 1953         15      M             1      Normal        Both
# 1954         15      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2049         15      M             1      Normal        Both
# 2050         15      M             1      Normal        Both
# 2051         15      M             1      Normal        Both
# 2052         15      M             1      Normal        Both
# 2053         15      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 1950  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B03.jpg
# 1951  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB03.jpg
# ...

# %%
MB15 =  MB.iloc[:20,:]
MB15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1950         15      M             1      Normal        Both
# 1951         15      M             1      Normal        Both
# 1952         15      M             1      Normal        Both
# 1953         15      M             1      Normal        Both
# 1954         15      M             1      Normal        Both
# 1955         15      M             1      Normal        Both
# 1956         15      M             1      Normal        Both
# 1957         15      M             1      Normal        Both
# 1958         15      M             1      Normal        Both
# 1959         15      M             1      Normal        Both
# 1960         15      M             1      Normal        Both
# 1961         15      M             1      Normal        Both
# 1962         15      M             1      Normal        Both
# 1963         15      M             1      Normal        Both
# ...

# %%
len(MB15)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 15) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2054         15      M             1      Normal          Lt
# 2055         15      M             1      Normal          Lt
# 2056         15      M             1      Normal          Lt
# 2057         15      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 2054  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB30.jpg
# 2055  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB272.jpg
# 2056  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB337.jpg
# 2057  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB338.jpg

# %%
ML15 =  ML.iloc[:1,:]
ML15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2054         15      M             1      Normal          Lt
#
#                                               Path_Name     Filename
# 2054  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB30.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 15) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2058         15      M             1      Normal          Rt
# 2059         15      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2058  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  B279.jpg
# 2059  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  B289.jpg

# %%
MR15 =  MR.iloc[:1,:]
MR15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2058         15      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2058  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  B279.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 15) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1833         15      F             0      Normal        Both
# 1834         15      F             0      Normal        Both
# 1835         15      F             0      Normal        Both
# 1836         15      F             0      Normal        Both
# 1837         15      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 1942         15      F             0      Normal        Both
# 1943         15      F             0      Normal        Both
# 1944         15      F             0      Normal        Both
# 1945         15      F             0      Normal        Both
# 1946         15      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 1833  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B07.jpg
# 1834  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB07.jpg
# ...

# %%
FB15 =  FB.iloc[:20,:]
FB15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1833         15      F             0      Normal        Both
# 1834         15      F             0      Normal        Both
# 1835         15      F             0      Normal        Both
# 1836         15      F             0      Normal        Both
# 1837         15      F             0      Normal        Both
# 1838         15      F             0      Normal        Both
# 1839         15      F             0      Normal        Both
# 1840         15      F             0      Normal        Both
# 1841         15      F             0      Normal        Both
# 1842         15      F             0      Normal        Both
# 1843         15      F             0      Normal        Both
# 1844         15      F             0      Normal        Both
# 1845         15      F             0      Normal        Both
# 1846         15      F             0      Normal        Both
# ...

# %%
len(FB15)
# Out:
# 20

# %% [markdown]
# ### Lt (2/2)

# %%
FL = df[(df['Age(year)']== 15) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1947         15      F             0      Normal          Lt
# 1948         15      F             0      Normal          Lt
# 1949         15      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 1947  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB59.jpg
# 1948  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB111.jpg
# 1949  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB234.jpg

# %%
FL15 =  FL.iloc[:2,:]
FL15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1947         15      F             0      Normal          Lt
# 1948         15      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 1947  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB59.jpg
# 1948  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB111.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 15) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# FR15 =  FR.iloc[:1,:]
# FR15

# %% [markdown]
# ## 15Y (concat)

# %%
len(pd.concat([MB15,ML15,MR15]))
# Out:
# 22

# %%
len(pd.concat([FB15,FL15]))
# Out:
# 22

# %%
Y15 = pd.concat([MB15,ML15,MR15,FB15,FL15])
Y15
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 1950         15      M             1      Normal        Both
# 1951         15      M             1      Normal        Both
# 1952         15      M             1      Normal        Both
# 1953         15      M             1      Normal        Both
# 1954         15      M             1      Normal        Both
# 1955         15      M             1      Normal        Both
# 1956         15      M             1      Normal        Both
# 1957         15      M             1      Normal        Both
# 1958         15      M             1      Normal        Both
# 1959         15      M             1      Normal        Both
# 1960         15      M             1      Normal        Both
# 1961         15      M             1      Normal        Both
# 1962         15      M             1      Normal        Both
# 1963         15      M             1      Normal        Both
# ...

# %%
len(Y15) #img
# Out:
# 44

# %% [markdown]
# # 16 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 16) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2178         16      M             1      Normal        Both
# 2179         16      M             1      Normal        Both
# 2180         16      M             1      Normal        Both
# 2181         16      M             1      Normal        Both
# 2182         16      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2275         16      M             1      Normal        Both
# 2276         16      M             1      Normal        Both
# 2277         16      M             1      Normal        Both
# 2278         16      M             1      Normal        Both
# 2279         16      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 2178  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T03.jpg
# 2179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT03.jpg
# ...

# %%
MB16 =  MB.iloc[:20,:]
MB16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2178         16      M             1      Normal        Both
# 2179         16      M             1      Normal        Both
# 2180         16      M             1      Normal        Both
# 2181         16      M             1      Normal        Both
# 2182         16      M             1      Normal        Both
# 2183         16      M             1      Normal        Both
# 2184         16      M             1      Normal        Both
# 2185         16      M             1      Normal        Both
# 2186         16      M             1      Normal        Both
# 2187         16      M             1      Normal        Both
# 2188         16      M             1      Normal        Both
# 2189         16      M             1      Normal        Both
# 2190         16      M             1      Normal        Both
# 2191         16      M             1      Normal        Both
# ...

# %%
len(MB16)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 16) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2280         16      M             1      Normal          Lt
# 2281         16      M             1      Normal          Lt
# 2282         16      M             1      Normal          Lt
# 2283         16      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 2280  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT202.jpg
# 2281  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT309.jpg
# 2282  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT324.jpg
# 2283  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT327.jpg

# %%
ML16 =  ML.iloc[:1,:]
ML16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2280         16      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 2280  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT202.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 16) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2284         16      M             1      Normal          Rt
# 2285         16      M             1      Normal          Rt
# 2286         16      M             1      Normal          Rt
# 2287         16      M             1      Normal          Rt
# 2288         16      M             1      Normal          Rt
# 2289         16      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2284  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   T17.jpg
# 2285  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T130.jpg
# 2286  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T133.jpg
# 2287  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T271.jpg
# 2288  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T305.jpg
# 2289  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T307.jpg

# %%
MR16 =  MR.iloc[:1,:]
MR16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2284         16      M             1      Normal          Rt
#
#                                               Path_Name Filename
# 2284  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T17.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 16) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2060         16      F             0      Normal        Both
# 2061         16      F             0      Normal        Both
# 2062         16      F             0      Normal        Both
# 2063         16      F             0      Normal        Both
# 2064         16      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2169         16      F             0      Normal        Both
# 2170         16      F             0      Normal        Both
# 2171         16      F             0      Normal        Both
# 2172         16      F             0      Normal        Both
# 2173         16      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 2060  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T14.jpg
# 2061  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT14.jpg
# ...

# %%
FB16 =  FB.iloc[:20,:]
FB16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2060         16      F             0      Normal        Both
# 2061         16      F             0      Normal        Both
# 2062         16      F             0      Normal        Both
# 2063         16      F             0      Normal        Both
# 2064         16      F             0      Normal        Both
# 2065         16      F             0      Normal        Both
# 2066         16      F             0      Normal        Both
# 2067         16      F             0      Normal        Both
# 2068         16      F             0      Normal        Both
# 2069         16      F             0      Normal        Both
# 2070         16      F             0      Normal        Both
# 2071         16      F             0      Normal        Both
# 2072         16      F             0      Normal        Both
# 2073         16      F             0      Normal        Both
# ...

# %%
len(FB16)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 16) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2174         16      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 2174  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT20.jpg

# %%
FL16 =  FL.iloc[:1,:]
FL16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2174         16      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 2174  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT20.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 16) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2175         16      F             0      Normal          Rt
# 2176         16      F             0      Normal          Rt
# 2177         16      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 2175  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   T38.jpg
# 2176  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   T39.jpg
# 2177  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T270.jpg

# %%
FR16 =  FR.iloc[:1,:]
FR16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2175         16      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 2175  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  T38.jpg

# %% [markdown]
# ## 16Y (concat)

# %%
len(pd.concat([MB16,ML16,MR16]))
# Out:
# 22

# %%
len(pd.concat([FB16,FL16,FR16]))
# Out:
# 22

# %%
Y16 = pd.concat([MB16,ML16,MR16,FB16,FL16,FR16])
Y16
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2178         16      M             1      Normal        Both
# 2179         16      M             1      Normal        Both
# 2180         16      M             1      Normal        Both
# 2181         16      M             1      Normal        Both
# 2182         16      M             1      Normal        Both
# 2183         16      M             1      Normal        Both
# 2184         16      M             1      Normal        Both
# 2185         16      M             1      Normal        Both
# 2186         16      M             1      Normal        Both
# 2187         16      M             1      Normal        Both
# 2188         16      M             1      Normal        Both
# 2189         16      M             1      Normal        Both
# 2190         16      M             1      Normal        Both
# 2191         16      M             1      Normal        Both
# ...

# %%
len(Y16) #img
# Out:
# 44

# %% [markdown]
# # 17 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 17) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2402         17      M             1      Normal        Both
# 2403         17      M             1      Normal        Both
# 2404         17      M             1      Normal        Both
# 2405         17      M             1      Normal        Both
# 2406         17      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2501         17      M             1      Normal        Both
# 2502         17      M             1      Normal        Both
# 2503         17      M             1      Normal        Both
# 2504         17      M             1      Normal        Both
# 2505         17      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 2402  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       K17.jpg
# 2403  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipK17.jpg
# ...

# %%
MB17 =  MB.iloc[:22,:]
MB17
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2402         17      M             1      Normal        Both
# 2403         17      M             1      Normal        Both
# 2404         17      M             1      Normal        Both
# 2405         17      M             1      Normal        Both
# 2406         17      M             1      Normal        Both
# 2407         17      M             1      Normal        Both
# 2408         17      M             1      Normal        Both
# 2409         17      M             1      Normal        Both
# 2410         17      M             1      Normal        Both
# 2411         17      M             1      Normal        Both
# 2412         17      M             1      Normal        Both
# 2413         17      M             1      Normal        Both
# 2414         17      M             1      Normal        Both
# 2415         17      M             1      Normal        Both
# ...

# %%
len(MB17)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 17) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2506         17      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 2506  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK200.jpg

# %%
# ML17 =  ML.iloc[:1,:]
# ML17

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 17) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2507         17      M             1      Normal          Rt
# 2508         17      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2507  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  K324.jpg
# 2508  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  K325.jpg

# %%
# MR17 =  MR.iloc[:1,:]
# MR17

# %% [markdown]
# ## Female (11 คน 21 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 17) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2290         17      F             0      Normal        Both
# 2291         17      F             0      Normal        Both
# 2292         17      F             0      Normal        Both
# 2293         17      F             0      Normal        Both
# 2294         17      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2395         17      F             0      Normal        Both
# 2396         17      F             0      Normal        Both
# 2397         17      F             0      Normal        Both
# 2398         17      F             0      Normal        Both
# 2399         17      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 2290  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       K05.jpg
# 2291  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipK05.jpg
# ...

# %%
FB17 =  FB.iloc[:20,:]
FB17
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2290         17      F             0      Normal        Both
# 2291         17      F             0      Normal        Both
# 2292         17      F             0      Normal        Both
# 2293         17      F             0      Normal        Both
# 2294         17      F             0      Normal        Both
# 2295         17      F             0      Normal        Both
# 2296         17      F             0      Normal        Both
# 2297         17      F             0      Normal        Both
# 2298         17      F             0      Normal        Both
# 2299         17      F             0      Normal        Both
# 2300         17      F             0      Normal        Both
# 2301         17      F             0      Normal        Both
# 2302         17      F             0      Normal        Both
# 2303         17      F             0      Normal        Both
# ...

# %%
len(FB17)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 17) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2400         17      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 2400  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK93.jpg

# %%
FL17 =  FL.iloc[:1,:]
FL17
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2400         17      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 2400  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK93.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 17) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2401         17      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 2401  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  K89.jpg

# %%
# FR17 =  FR.iloc[:1,:]
# FR17

# %% [markdown]
# ## 17Y (concat)

# %%
len(MB17)
# Out:
# 22

# %%
len(pd.concat([FB17,FL17]))
# Out:
# 21

# %%
Y17 = pd.concat([MB17,FB17,FL17])
Y17
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2402         17      M             1      Normal        Both
# 2403         17      M             1      Normal        Both
# 2404         17      M             1      Normal        Both
# 2405         17      M             1      Normal        Both
# 2406         17      M             1      Normal        Both
# 2407         17      M             1      Normal        Both
# 2408         17      M             1      Normal        Both
# 2409         17      M             1      Normal        Both
# 2410         17      M             1      Normal        Both
# 2411         17      M             1      Normal        Both
# 2412         17      M             1      Normal        Both
# 2413         17      M             1      Normal        Both
# 2414         17      M             1      Normal        Both
# 2415         17      M             1      Normal        Both
# ...

# %%
len(Y17) #img
# Out:
# 43

# %% [markdown]
# # 18 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 18) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2637         18      M             1      Normal        Both
# 2638         18      M             1      Normal        Both
# 2639         18      M             1      Normal        Both
# 2640         18      M             1      Normal        Both
# 2641         18      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2734         18      M             1      Normal        Both
# 2735         18      M             1      Normal        Both
# 2736         18      M             1      Normal        Both
# 2737         18      M             1      Normal        Both
# 2738         18      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 2637  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S13.jpg
# 2638  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS13.jpg
# ...

# %%
MB18 =  MB.iloc[:20,:]
MB18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2637         18      M             1      Normal        Both
# 2638         18      M             1      Normal        Both
# 2639         18      M             1      Normal        Both
# 2640         18      M             1      Normal        Both
# 2641         18      M             1      Normal        Both
# 2642         18      M             1      Normal        Both
# 2643         18      M             1      Normal        Both
# 2644         18      M             1      Normal        Both
# 2645         18      M             1      Normal        Both
# 2646         18      M             1      Normal        Both
# 2647         18      M             1      Normal        Both
# 2648         18      M             1      Normal        Both
# 2649         18      M             1      Normal        Both
# 2650         18      M             1      Normal        Both
# ...

# %%
len(MB18)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 18) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2739         18      M             1      Normal          Lt
#
#                                               Path_Name     Filename
# 2739  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS53.jpg

# %%
ML18 =  ML.iloc[:1,:]
ML18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2739         18      M             1      Normal          Lt
#
#                                               Path_Name     Filename
# 2739  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS53.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 18) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2740         18      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2740  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  S367.jpg

# %%
MR18 =  MR.iloc[:1,:]
MR18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2740         18      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2740  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  S367.jpg

# %% [markdown]
# ## Female (13 คน 22 ภาพ)

# %% [markdown]
# ### Both (9/18)

# %%
FB = df[(df['Age(year)']== 18) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2509         18      F             0      Normal        Both
# 2510         18      F             0      Normal        Both
# 2511         18      F             0      Normal        Both
# 2512         18      F             0      Normal        Both
# 2513         18      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2614         18      F             0      Normal        Both
# 2615         18      F             0      Normal        Both
# 2616         18      F             0      Normal        Both
# 2617         18      F             0      Normal        Both
# 2618         18      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 2509  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S02.jpg
# 2510  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS02.jpg
# ...

# %%
FB18 =  FB.iloc[:18,:]
FB18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2509         18      F             0      Normal        Both
# 2510         18      F             0      Normal        Both
# 2511         18      F             0      Normal        Both
# 2512         18      F             0      Normal        Both
# 2513         18      F             0      Normal        Both
# 2514         18      F             0      Normal        Both
# 2515         18      F             0      Normal        Both
# 2516         18      F             0      Normal        Both
# 2517         18      F             0      Normal        Both
# 2518         18      F             0      Normal        Both
# 2519         18      F             0      Normal        Both
# 2520         18      F             0      Normal        Both
# 2521         18      F             0      Normal        Both
# 2522         18      F             0      Normal        Both
# ...

# %%
len(FB18)
# Out:
# 18

# %% [markdown]
# ### Lt (2/2)

# %%
FL = df[(df['Age(year)']== 18) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2619         18      F             0      Normal          Lt
# 2620         18      F             0      Normal          Lt
# 2621         18      F             0      Normal          Lt
# 2622         18      F             0      Normal          Lt
# 2623         18      F             0      Normal          Lt
# 2624         18      F             0      Normal          Lt
# 2625         18      F             0      Normal          Lt
# 2626         18      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 2619  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS118.jpg
# 2620  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS193.jpg
# 2621  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS225.jpg
# 2622  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS262.jpg
# ...

# %%
FL18 =  FL.iloc[:2,:]
FL18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2619         18      F             0      Normal          Lt
# 2620         18      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 2619  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS118.jpg
# 2620  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS193.jpg

# %% [markdown]
# ### Rt (2/2)

# %%
FR = df[(df['Age(year)']== 18) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2627         18      F             0      Normal          Rt
# 2628         18      F             0      Normal          Rt
# 2629         18      F             0      Normal          Rt
# 2630         18      F             0      Normal          Rt
# 2631         18      F             0      Normal          Rt
# 2632         18      F             0      Normal          Rt
# 2633         18      F             0      Normal          Rt
# 2634         18      F             0      Normal          Rt
# 2635         18      F             0      Normal          Rt
# 2636         18      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 2627  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   S40.jpg
# 2628  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   S74.jpg
# 2629  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  S116.jpg
# ...

# %%
FR18 =  FR.iloc[:2,:]
FR18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2627         18      F             0      Normal          Rt
# 2628         18      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 2627  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  S40.jpg
# 2628  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  S74.jpg

# %% [markdown]
# ## 18Y (concat)

# %%
len(pd.concat([MB18,ML18,MR18]))
# Out:
# 22

# %%
len(pd.concat([FB18,FL18,FR18]))
# Out:
# 22

# %%
Y18 = pd.concat([MB18,ML18,MR18,FB18,FL18,FR18])
Y18
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2637         18      M             1      Normal        Both
# 2638         18      M             1      Normal        Both
# 2639         18      M             1      Normal        Both
# 2640         18      M             1      Normal        Both
# 2641         18      M             1      Normal        Both
# 2642         18      M             1      Normal        Both
# 2643         18      M             1      Normal        Both
# 2644         18      M             1      Normal        Both
# 2645         18      M             1      Normal        Both
# 2646         18      M             1      Normal        Both
# 2647         18      M             1      Normal        Both
# 2648         18      M             1      Normal        Both
# 2649         18      M             1      Normal        Both
# 2650         18      M             1      Normal        Both
# ...

# %%
len(Y18) #img
# Out:
# 44

# %% [markdown]
# # 19 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 19) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2856         19      M             1      Normal        Both
# 2857         19      M             1      Normal        Both
# 2858         19      M             1      Normal        Both
# 2859         19      M             1      Normal        Both
# 2860         19      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2947         19      M             1      Normal        Both
# 2948         19      M             1      Normal        Both
# 2949         19      M             1      Normal        Both
# 2950         19      M             1      Normal        Both
# 2951         19      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 2856  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L09.jpg
# 2857  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL09.jpg
# ...

# %%
MB19 =  MB.iloc[:20,:]
MB19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2856         19      M             1      Normal        Both
# 2857         19      M             1      Normal        Both
# 2858         19      M             1      Normal        Both
# 2859         19      M             1      Normal        Both
# 2860         19      M             1      Normal        Both
# 2861         19      M             1      Normal        Both
# 2862         19      M             1      Normal        Both
# 2863         19      M             1      Normal        Both
# 2864         19      M             1      Normal        Both
# 2865         19      M             1      Normal        Both
# 2866         19      M             1      Normal        Both
# 2867         19      M             1      Normal        Both
# 2868         19      M             1      Normal        Both
# 2869         19      M             1      Normal        Both
# ...

# %%
len(MB19)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 19) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2952         19      M             1      Normal          Lt
# 2953         19      M             1      Normal          Lt
# 2954         19      M             1      Normal          Lt
# 2955         19      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 2952  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL74.jpg
# 2953  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL123.jpg
# 2954  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL181.jpg
# 2955  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL410.jpg

# %%
ML19 =  ML.iloc[:1,:]
ML19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2952         19      M             1      Normal          Lt
#
#                                               Path_Name     Filename
# 2952  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL74.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 19) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2956         19      M             1      Normal          Rt
# 2957         19      M             1      Normal          Rt
# 2958         19      M             1      Normal          Rt
# 2959         19      M             1      Normal          Rt
# 2960         19      M             1      Normal          Rt
# 2961         19      M             1      Normal          Rt
# 2962         19      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2956  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L171.jpg
# 2957  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L221.jpg
# 2958  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L229.jpg
# 2959  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L269.jpg
# 2960  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L289.jpg
# 2961  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L372.jpg
# ...

# %%
MR19 =  MR.iloc[:1,:]
MR19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2956         19      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 2956  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L171.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 19) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2741         19      F             0      Normal        Both
# 2742         19      F             0      Normal        Both
# 2743         19      F             0      Normal        Both
# 2744         19      F             0      Normal        Both
# 2745         19      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 2842         19      F             0      Normal        Both
# 2843         19      F             0      Normal        Both
# 2844         19      F             0      Normal        Both
# 2845         19      F             0      Normal        Both
# 2846         19      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 2741  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L12.jpg
# 2742  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL12.jpg
# ...

# %%
FB19 =  FB.iloc[:20,:]
FB19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2741         19      F             0      Normal        Both
# 2742         19      F             0      Normal        Both
# 2743         19      F             0      Normal        Both
# 2744         19      F             0      Normal        Both
# 2745         19      F             0      Normal        Both
# 2746         19      F             0      Normal        Both
# 2747         19      F             0      Normal        Both
# 2748         19      F             0      Normal        Both
# 2749         19      F             0      Normal        Both
# 2750         19      F             0      Normal        Both
# 2751         19      F             0      Normal        Both
# 2752         19      F             0      Normal        Both
# 2753         19      F             0      Normal        Both
# 2754         19      F             0      Normal        Both
# ...

# %%
len(FB19)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 19) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2847         19      F             0      Normal          Lt
# 2848         19      F             0      Normal          Lt
# 2849         19      F             0      Normal          Lt
# 2850         19      F             0      Normal          Lt
# 2851         19      F             0      Normal          Lt
# 2852         19      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 2847  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL24.jpg
# 2848  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL27.jpg
# 2849  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL34.jpg
# 2850  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL38.jpg
# 2851  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL145.jpg
# 2852  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL212.jpg

# %%
FL19 =  FL.iloc[:1,:]
FL19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2847         19      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 2847  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL24.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 19) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2853         19      F             0      Normal          Rt
# 2854         19      F             0      Normal          Rt
# 2855         19      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 2853  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L42.jpg
# 2854  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L76.jpg
# 2855  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L91.jpg

# %%
FR19 =  FR.iloc[:1,:]
FR19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2853         19      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 2853  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  L42.jpg

# %% [markdown]
# ## 19Y (concat)

# %%
len(pd.concat([MB19,ML19,MR19]))
# Out:
# 22

# %%
len(pd.concat([FB19,FL19,FR19]))
# Out:
# 22

# %%
Y19 = pd.concat([MB19,ML19,MR19,FB19,FL19,FR19])
Y19
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2856         19      M             1      Normal        Both
# 2857         19      M             1      Normal        Both
# 2858         19      M             1      Normal        Both
# 2859         19      M             1      Normal        Both
# 2860         19      M             1      Normal        Both
# 2861         19      M             1      Normal        Both
# 2862         19      M             1      Normal        Both
# 2863         19      M             1      Normal        Both
# 2864         19      M             1      Normal        Both
# 2865         19      M             1      Normal        Both
# 2866         19      M             1      Normal        Both
# 2867         19      M             1      Normal        Both
# 2868         19      M             1      Normal        Both
# 2869         19      M             1      Normal        Both
# ...

# %%
len(Y19) #img
# Out:
# 44

# %% [markdown]
# # 20 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 20) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3062         20      M             1      Normal        Both
# 3063         20      M             1      Normal        Both
# 3064         20      M             1      Normal        Both
# 3065         20      M             1      Normal        Both
# 3066         20      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3155         20      M             1      Normal        Both
# 3156         20      M             1      Normal        Both
# 3157         20      M             1      Normal        Both
# 3158         20      M             1      Normal        Both
# 3159         20      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 3062  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q13.jpg
# 3063  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ13.jpg
# ...

# %%
MB20 =  MB.iloc[:22,:]
MB20
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3062         20      M             1      Normal        Both
# 3063         20      M             1      Normal        Both
# 3064         20      M             1      Normal        Both
# 3065         20      M             1      Normal        Both
# 3066         20      M             1      Normal        Both
# 3067         20      M             1      Normal        Both
# 3068         20      M             1      Normal        Both
# 3069         20      M             1      Normal        Both
# 3070         20      M             1      Normal        Both
# 3071         20      M             1      Normal        Both
# 3072         20      M             1      Normal        Both
# 3073         20      M             1      Normal        Both
# 3074         20      M             1      Normal        Both
# 3075         20      M             1      Normal        Both
# ...

# %%
len(MB20)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 20) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3160         20      M             1      Normal          Lt
# 3161         20      M             1      Normal          Lt
# 3162         20      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 3160  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ37.jpg
# 3161  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ108.jpg
# 3162  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ434.jpg

# %%
# ML20 =  ML.iloc[:1,:]
# ML20

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 20) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3163         20      M             1      Normal          Rt
# 3164         20      M             1      Normal          Rt
# 3165         20      M             1      Normal          Rt
# 3166         20      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 3163  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   Q67.jpg
# 3164  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q209.jpg
# 3165  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q215.jpg
# 3166  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q299.jpg

# %%
# MR20 =  MR.iloc[:1,:]
# MR20

# %% [markdown]
# ## Female (11 คน 21 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 20) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2963         20      F             0      Normal        Both
# 2964         20      F             0      Normal        Both
# 2965         20      F             0      Normal        Both
# 2966         20      F             0      Normal        Both
# 2967         20      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3048         20      F             0      Normal        Both
# 3049         20      F             0      Normal        Both
# 3050         20      F             0      Normal        Both
# 3051         20      F             0      Normal        Both
# 3052         20      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 2963  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q08.jpg
# 2964  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ08.jpg
# ...

# %%
FB20 =  FB.iloc[:20,:]
FB20
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 2963         20      F             0      Normal        Both
# 2964         20      F             0      Normal        Both
# 2965         20      F             0      Normal        Both
# 2966         20      F             0      Normal        Both
# 2967         20      F             0      Normal        Both
# 2968         20      F             0      Normal        Both
# 2969         20      F             0      Normal        Both
# 2970         20      F             0      Normal        Both
# 2971         20      F             0      Normal        Both
# 2972         20      F             0      Normal        Both
# 2973         20      F             0      Normal        Both
# 2974         20      F             0      Normal        Both
# 2975         20      F             0      Normal        Both
# 2976         20      F             0      Normal        Both
# ...

# %%
len(FB20)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 20) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3053         20      F             0      Normal          Lt
# 3054         20      F             0      Normal          Lt
# 3055         20      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 3053  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ83.jpg
# 3054  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ146.jpg
# 3055  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ205.jpg

# %%
FL20 =  FL.iloc[:1,:]
FL20
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3053         20      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 3053  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ83.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 20) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3056         20      F             0      Normal          Rt
# 3057         20      F             0      Normal          Rt
# 3058         20      F             0      Normal          Rt
# 3059         20      F             0      Normal          Rt
# 3060         20      F             0      Normal          Rt
# 3061         20      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 3056  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   Q43.jpg
# 3057  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   Q74.jpg
# 3058  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   Q75.jpg
# 3059  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q119.jpg
# 3060  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q167.jpg
# 3061  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Q259.jpg

# %%
# FR20 =  FR.iloc[:1,:]
# FR20

# %% [markdown]
# ## 20Y (concat)

# %%
len(MB20)
# Out:
# 22

# %%
len(pd.concat([FB20,FL20]))
# Out:
# 21

# %%
Y20 = pd.concat([MB20,FB20,FL20])
Y20
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3062         20      M             1      Normal        Both
# 3063         20      M             1      Normal        Both
# 3064         20      M             1      Normal        Both
# 3065         20      M             1      Normal        Both
# 3066         20      M             1      Normal        Both
# 3067         20      M             1      Normal        Both
# 3068         20      M             1      Normal        Both
# 3069         20      M             1      Normal        Both
# 3070         20      M             1      Normal        Both
# 3071         20      M             1      Normal        Both
# 3072         20      M             1      Normal        Both
# 3073         20      M             1      Normal        Both
# 3074         20      M             1      Normal        Both
# 3075         20      M             1      Normal        Both
# ...

# %%
len(Y20) #img
# Out:
# 43

# %% [markdown]
# # 21 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 21) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3267         21      M             1      Normal        Both
# 3268         21      M             1      Normal        Both
# 3269         21      M             1      Normal        Both
# 3270         21      M             1      Normal        Both
# 3271         21      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3356         21      M             1      Normal        Both
# 3357         21      M             1      Normal        Both
# 3358         21      M             1      Normal        Both
# 3359         21      M             1      Normal        Both
# 3360         21      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 3267  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N25.jpg
# 3268  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN25.jpg
# ...

# %%
MB21 =  MB.iloc[:22,:]
MB21
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3267         21      M             1      Normal        Both
# 3268         21      M             1      Normal        Both
# 3269         21      M             1      Normal        Both
# 3270         21      M             1      Normal        Both
# 3271         21      M             1      Normal        Both
# 3272         21      M             1      Normal        Both
# 3273         21      M             1      Normal        Both
# 3274         21      M             1      Normal        Both
# 3275         21      M             1      Normal        Both
# 3276         21      M             1      Normal        Both
# 3277         21      M             1      Normal        Both
# 3278         21      M             1      Normal        Both
# 3279         21      M             1      Normal        Both
# 3280         21      M             1      Normal        Both
# ...

# %%
len(MB21)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 21) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3361         21      M             1      Normal          Lt
# 3362         21      M             1      Normal          Lt
# 3363         21      M             1      Normal          Lt
# 3364         21      M             1      Normal          Lt
# 3365         21      M             1      Normal          Lt
# 3366         21      M             1      Normal          Lt
# 3367         21      M             1      Normal          Lt
# 3368         21      M             1      Normal          Lt
# 3369         21      M             1      Normal          Lt
# 3370         21      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 3361  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN23.jpg
# 3362  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN42.jpg
# 3363  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN125.jpg
# ...

# %%
# ML21 =  ML.iloc[:1,:]
# ML21

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 21) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3371         21      M             1      Normal          Rt
# 3372         21      M             1      Normal          Rt
# 3373         21      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 3371  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   N76.jpg
# 3372  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  N314.jpg
# 3373  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  N430.jpg

# %%
# MR21 =  MR.iloc[:1,:]
# MR21

# %% [markdown]
# ## Female (11 คน 21 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 21) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3167         21      F             0      Normal        Both
# 3168         21      F             0      Normal        Both
# 3169         21      F             0      Normal        Both
# 3170         21      F             0      Normal        Both
# 3171         21      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3258         21      F             0      Normal        Both
# 3259         21      F             0      Normal        Both
# 3260         21      F             0      Normal        Both
# 3261         21      F             0      Normal        Both
# 3262         21      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 3167  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N18.jpg
# 3168  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN18.jpg
# ...

# %%
FB21 =  FB.iloc[:20,:]
FB21
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3167         21      F             0      Normal        Both
# 3168         21      F             0      Normal        Both
# 3169         21      F             0      Normal        Both
# 3170         21      F             0      Normal        Both
# 3171         21      F             0      Normal        Both
# 3172         21      F             0      Normal        Both
# 3173         21      F             0      Normal        Both
# 3174         21      F             0      Normal        Both
# 3175         21      F             0      Normal        Both
# 3176         21      F             0      Normal        Both
# 3177         21      F             0      Normal        Both
# 3178         21      F             0      Normal        Both
# 3179         21      F             0      Normal        Both
# 3180         21      F             0      Normal        Both
# ...

# %%
len(FB21)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 21) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3263         21      F             0      Normal          Lt
# 3264         21      F             0      Normal          Lt
# 3265         21      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 3263  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN36.jpg
# 3264  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN111.jpg
# 3265  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN268.jpg

# %%
FL21 =  FL.iloc[:1,:]
FL21
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3263         21      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 3263  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN36.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 21) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3266         21      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 3266  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  N21.jpg

# %%
# FR21 =  FR.iloc[:1,:]
# FR21

# %% [markdown]
# ## 21Y (concat)

# %%
len(MB21)
# Out:
# 22

# %%
len(pd.concat([FB21,FL21]))
# Out:
# 21

# %%
Y21 = pd.concat([MB21,FB21,FL21])
Y21
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3267         21      M             1      Normal        Both
# 3268         21      M             1      Normal        Both
# 3269         21      M             1      Normal        Both
# 3270         21      M             1      Normal        Both
# 3271         21      M             1      Normal        Both
# 3272         21      M             1      Normal        Both
# 3273         21      M             1      Normal        Both
# 3274         21      M             1      Normal        Both
# 3275         21      M             1      Normal        Both
# 3276         21      M             1      Normal        Both
# 3277         21      M             1      Normal        Both
# 3278         21      M             1      Normal        Both
# 3279         21      M             1      Normal        Both
# 3280         21      M             1      Normal        Both
# ...

# %%
len(Y21) #img
# Out:
# 43

# %% [markdown]
# # 22 Year

# %% [markdown]
# ## Male (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 22) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3479         22      M             1      Normal        Both
# 3480         22      M             1      Normal        Both
# 3481         22      M             1      Normal        Both
# 3482         22      M             1      Normal        Both
# 3483         22      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3552         22      M             1      Normal        Both
# 3553         22      M             1      Normal        Both
# 3554         22      M             1      Normal        Both
# 3555         22      M             1      Normal        Both
# 3556         22      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 3479  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U22.jpg
# 3480  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU22.jpg
# ...

# %%
MB22 =  MB.iloc[:20,:]
MB22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3479         22      M             1      Normal        Both
# 3480         22      M             1      Normal        Both
# 3481         22      M             1      Normal        Both
# 3482         22      M             1      Normal        Both
# 3483         22      M             1      Normal        Both
# 3484         22      M             1      Normal        Both
# 3485         22      M             1      Normal        Both
# 3486         22      M             1      Normal        Both
# 3487         22      M             1      Normal        Both
# 3488         22      M             1      Normal        Both
# 3489         22      M             1      Normal        Both
# 3490         22      M             1      Normal        Both
# 3491         22      M             1      Normal        Both
# 3492         22      M             1      Normal        Both
# ...

# %%
len(MB22)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
ML = df[(df['Age(year)']== 22) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3557         22      M             1      Normal          Lt
# 3558         22      M             1      Normal          Lt
# 3559         22      M             1      Normal          Lt
# 3560         22      M             1      Normal          Lt
# 3561         22      M             1      Normal          Lt
# 3562         22      M             1      Normal          Lt
# 3563         22      M             1      Normal          Lt
# 3564         22      M             1      Normal          Lt
# 3565         22      M             1      Normal          Lt
# 3566         22      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 3557  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU06.jpg
# 3558  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU204.jpg
# 3559  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU251.jpg
# ...

# %%
ML22 =  ML.iloc[:1,:]
ML22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3557         22      M             1      Normal          Lt
#
#                                               Path_Name     Filename
# 3557  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU06.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 22) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3567         22      M             1      Normal          Rt
# 3568         22      M             1      Normal          Rt
# 3569         22      M             1      Normal          Rt
# 3570         22      M             1      Normal          Rt
# 3571         22      M             1      Normal          Rt
# 3572         22      M             1      Normal          Rt
# 3573         22      M             1      Normal          Rt
# 3574         22      M             1      Normal          Rt
# 3575         22      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 3567  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   U30.jpg
# 3568  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   U54.jpg
# 3569  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   U80.jpg
# 3570  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   U81.jpg
# ...

# %%
MR22 =  MR.iloc[:1,:]
MR22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3567         22      M             1      Normal          Rt
#
#                                               Path_Name Filename
# 3567  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  U30.jpg

# %% [markdown]
# ## Female (11 คน 21 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 22) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3374         22      F             0      Normal        Both
# 3375         22      F             0      Normal        Both
# 3376         22      F             0      Normal        Both
# 3377         22      F             0      Normal        Both
# 3378         22      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3469         22      F             0      Normal        Both
# 3470         22      F             0      Normal        Both
# 3471         22      F             0      Normal        Both
# 3472         22      F             0      Normal        Both
# 3473         22      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 3374  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U04.jpg
# 3375  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU04.jpg
# ...

# %%
FB22 =  FB.iloc[:20,:]
FB22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3374         22      F             0      Normal        Both
# 3375         22      F             0      Normal        Both
# 3376         22      F             0      Normal        Both
# 3377         22      F             0      Normal        Both
# 3378         22      F             0      Normal        Both
# 3379         22      F             0      Normal        Both
# 3380         22      F             0      Normal        Both
# 3381         22      F             0      Normal        Both
# 3382         22      F             0      Normal        Both
# 3383         22      F             0      Normal        Both
# 3384         22      F             0      Normal        Both
# 3385         22      F             0      Normal        Both
# 3386         22      F             0      Normal        Both
# 3387         22      F             0      Normal        Both
# ...

# %%
len(FB22)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 22) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3474         22      F             0      Normal          Lt
# 3475         22      F             0      Normal          Lt
# 3476         22      F             0      Normal          Lt
# 3477         22      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 3474  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU20.jpg
# 3475  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU260.jpg
# 3476  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU433.jpg
# 3477  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU437.jpg

# %%
FL22 =  FL.iloc[:1,:]
FL22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3474         22      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 3474  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU20.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 22) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3478         22      F             0      Normal          Rt
#
#                                               Path_Name Filename
# 3478  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  U59.jpg

# %%
# FR22 =  FR.iloc[:1,:]
# FR22

# %% [markdown]
# ## 22Y (concat)

# %%
len(pd.concat([MB22,ML22,MR22]))
# Out:
# 22

# %%
len(pd.concat([FB22,FL22]))
# Out:
# 21

# %%
Y22 = pd.concat([MB22,ML22,MR22,FB22,FL22])
Y22
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3479         22      M             1      Normal        Both
# 3480         22      M             1      Normal        Both
# 3481         22      M             1      Normal        Both
# 3482         22      M             1      Normal        Both
# 3483         22      M             1      Normal        Both
# 3484         22      M             1      Normal        Both
# 3485         22      M             1      Normal        Both
# 3486         22      M             1      Normal        Both
# 3487         22      M             1      Normal        Both
# 3488         22      M             1      Normal        Both
# 3489         22      M             1      Normal        Both
# 3490         22      M             1      Normal        Both
# 3491         22      M             1      Normal        Both
# 3492         22      M             1      Normal        Both
# ...

# %%
len(Y22) #img
# Out:
# 43

# %% [markdown]
# # 23 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 23) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3677         23      M             1      Normal        Both
# 3678         23      M             1      Normal        Both
# 3679         23      M             1      Normal        Both
# 3680         23      M             1      Normal        Both
# 3681         23      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3780         23      M             1      Normal        Both
# 3781         23      M             1      Normal        Both
# 3782         23      M             1      Normal        Both
# 3783         23      M             1      Normal        Both
# 3784         23      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 3677  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E10.jpg
# 3678  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE10.jpg
# ...

# %%
MB23 =  MB.iloc[:22,:]
MB23
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3677         23      M             1      Normal        Both
# 3678         23      M             1      Normal        Both
# 3679         23      M             1      Normal        Both
# 3680         23      M             1      Normal        Both
# 3681         23      M             1      Normal        Both
# 3682         23      M             1      Normal        Both
# 3683         23      M             1      Normal        Both
# 3684         23      M             1      Normal        Both
# 3685         23      M             1      Normal        Both
# 3686         23      M             1      Normal        Both
# 3687         23      M             1      Normal        Both
# 3688         23      M             1      Normal        Both
# 3689         23      M             1      Normal        Both
# 3690         23      M             1      Normal        Both
# ...

# %%
len(MB23)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 23) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# ML23 =  ML.iloc[:1,:]
# ML23

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 23) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
# Empty DataFrame
# Columns: [Age(year), Gender, Gender_Class, Folder_type, Folder_name, Path_Name, Filename]
# Index: []

# %%
# MR23 =  MR.iloc[:1,:]
# MR23

# %% [markdown]
# ## Female (11 คน 21 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 23) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3576         23      F             0      Normal        Both
# 3577         23      F             0      Normal        Both
# 3578         23      F             0      Normal        Both
# 3579         23      F             0      Normal        Both
# 3580         23      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3657         23      F             0      Normal        Both
# 3658         23      F             0      Normal        Both
# 3659         23      F             0      Normal        Both
# 3660         23      F             0      Normal        Both
# 3661         23      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 3576  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E03.jpg
# 3577  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE03.jpg
# ...

# %%
FB23 =  FB.iloc[:20,:]
FB23
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3576         23      F             0      Normal        Both
# 3577         23      F             0      Normal        Both
# 3578         23      F             0      Normal        Both
# 3579         23      F             0      Normal        Both
# 3580         23      F             0      Normal        Both
# 3581         23      F             0      Normal        Both
# 3582         23      F             0      Normal        Both
# 3583         23      F             0      Normal        Both
# 3584         23      F             0      Normal        Both
# 3585         23      F             0      Normal        Both
# 3586         23      F             0      Normal        Both
# 3587         23      F             0      Normal        Both
# 3588         23      F             0      Normal        Both
# 3589         23      F             0      Normal        Both
# ...

# %%
len(FB23)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 23) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3662         23      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 3662  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE43.jpg

# %%
FL23 =  FL.iloc[:1,:]
FL23
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3662         23      F             0      Normal          Lt
#
#                                               Path_Name     Filename
# 3662  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE43.jpg

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 23) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3663         23      F             0      Normal          Rt
# 3664         23      F             0      Normal          Rt
# 3665         23      F             0      Normal          Rt
# 3666         23      F             0      Normal          Rt
# 3667         23      F             0      Normal          Rt
# 3668         23      F             0      Normal          Rt
# 3669         23      F             0      Normal          Rt
# 3670         23      F             0      Normal          Rt
# 3671         23      F             0      Normal          Rt
# 3672         23      F             0      Normal          Rt
# 3673         23      F             0      Normal          Rt
# 3674         23      F             0      Normal          Rt
# 3675         23      F             0      Normal          Rt
# 3676         23      F             0      Normal          Rt
#
# ...

# %%
# FR23 =  FR.iloc[:1,:]
# FR23

# %% [markdown]
# ## 23Y (concat)

# %%
len(MB23)
# Out:
# 22

# %%
len(pd.concat([FB23,FL23]))
# Out:
# 21

# %%
Y23 = pd.concat([MB23,FB23,FL23])
Y23
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3677         23      M             1      Normal        Both
# 3678         23      M             1      Normal        Both
# 3679         23      M             1      Normal        Both
# 3680         23      M             1      Normal        Both
# 3681         23      M             1      Normal        Both
# 3682         23      M             1      Normal        Both
# 3683         23      M             1      Normal        Both
# 3684         23      M             1      Normal        Both
# 3685         23      M             1      Normal        Both
# 3686         23      M             1      Normal        Both
# 3687         23      M             1      Normal        Both
# 3688         23      M             1      Normal        Both
# 3689         23      M             1      Normal        Both
# 3690         23      M             1      Normal        Both
# ...

# %%
len(Y23) #img
# Out:
# 43

# %% [markdown]
# # 24 Year

# %% [markdown]
# ## Male (11 คน 22 ภาพ)

# %% [markdown]
# ### Both (11/22)

# %%
MB = df[(df['Age(year)']== 24) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3876         24      M             1      Normal        Both
# 3877         24      M             1      Normal        Both
# 3878         24      M             1      Normal        Both
# 3879         24      M             1      Normal        Both
# 3880         24      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3969         24      M             1      Normal        Both
# 3970         24      M             1      Normal        Both
# 3971         24      M             1      Normal        Both
# 3972         24      M             1      Normal        Both
# 3973         24      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 3876  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z09.jpg
# 3877  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ09.jpg
# ...

# %%
MB24 =  MB.iloc[:22,:]
MB24
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3876         24      M             1      Normal        Both
# 3877         24      M             1      Normal        Both
# 3878         24      M             1      Normal        Both
# 3879         24      M             1      Normal        Both
# 3880         24      M             1      Normal        Both
# 3881         24      M             1      Normal        Both
# 3882         24      M             1      Normal        Both
# 3883         24      M             1      Normal        Both
# 3884         24      M             1      Normal        Both
# 3885         24      M             1      Normal        Both
# 3886         24      M             1      Normal        Both
# 3887         24      M             1      Normal        Both
# 3888         24      M             1      Normal        Both
# 3889         24      M             1      Normal        Both
# ...

# %%
len(MB24)
# Out:
# 22

# %% [markdown]
# ### Lt (0/0)

# %%
ML = df[(df['Age(year)']== 24) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3974         24      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 3974  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ403.jpg

# %%
# ML24 =  ML.iloc[:1,:]
# ML24

# %% [markdown]
# ### Rt (0/0)

# %%
MR = df[(df['Age(year)']== 24) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3975         24      M             1      Normal          Rt
# 3976         24      M             1      Normal          Rt
# 3977         24      M             1      Normal          Rt
# 3978         24      M             1      Normal          Rt
# 3979         24      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 3975  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z207.jpg
# 3976  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z224.jpg
# 3977  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z412.jpg
# 3978  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z416.jpg
# 3979  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z428.jpg

# %%
# MR24 =  MR.iloc[:1,:]
# MR24

# %% [markdown]
# ## Female (10 คน 20 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 24) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3785         24      F             0      Normal        Both
# 3786         24      F             0      Normal        Both
# 3787         24      F             0      Normal        Both
# 3788         24      F             0      Normal        Both
# 3789         24      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3866         24      F             0      Normal        Both
# 3867         24      F             0      Normal        Both
# 3868         24      F             0      Normal        Both
# 3869         24      F             0      Normal        Both
# 3870         24      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 3785  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z04.jpg
# 3786  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ04.jpg
# ...

# %%
FB24 =  FB.iloc[:20,:]
FB24
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3785         24      F             0      Normal        Both
# 3786         24      F             0      Normal        Both
# 3787         24      F             0      Normal        Both
# 3788         24      F             0      Normal        Both
# 3789         24      F             0      Normal        Both
# 3790         24      F             0      Normal        Both
# 3791         24      F             0      Normal        Both
# 3792         24      F             0      Normal        Both
# 3793         24      F             0      Normal        Both
# 3794         24      F             0      Normal        Both
# 3795         24      F             0      Normal        Both
# 3796         24      F             0      Normal        Both
# 3797         24      F             0      Normal        Both
# 3798         24      F             0      Normal        Both
# ...

# %%
len(FB24)
# Out:
# 20

# %% [markdown]
# ### Lt (0/0)

# %%
FL = df[(df['Age(year)']== 24) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3871         24      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 3871  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ242.jpg

# %%
# FL24 =  FL.iloc[:1,:]
# FL24

# %% [markdown]
# ### Rt (0/0)

# %%
FR = df[(df['Age(year)']== 24) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3872         24      F             0      Normal          Rt
# 3873         24      F             0      Normal          Rt
# 3874         24      F             0      Normal          Rt
# 3875         24      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 3872  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z156.jpg
# 3873  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z170.jpg
# 3874  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z278.jpg
# 3875  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  Z293.jpg

# %%
# FR24 =  FR.iloc[:1,:]
# FR24

# %% [markdown]
# ## 24Y (concat)

# %%
len(MB24)
# Out:
# 22

# %%
len(FB24)
# Out:
# 20

# %%
Y24 = pd.concat([MB24,FB24])
Y24
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3876         24      M             1      Normal        Both
# 3877         24      M             1      Normal        Both
# 3878         24      M             1      Normal        Both
# 3879         24      M             1      Normal        Both
# 3880         24      M             1      Normal        Both
# 3881         24      M             1      Normal        Both
# 3882         24      M             1      Normal        Both
# 3883         24      M             1      Normal        Both
# 3884         24      M             1      Normal        Both
# 3885         24      M             1      Normal        Both
# 3886         24      M             1      Normal        Both
# 3887         24      M             1      Normal        Both
# 3888         24      M             1      Normal        Both
# 3889         24      M             1      Normal        Both
# ...

# %%
len(Y24) #img
# Out:
# 42

# %% [markdown]
# # 25 Year

# %% [markdown]
# ## Male (13 คน 23 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
MB = df[(df['Age(year)']== 25) & (df['Gender']== 'M')& (df['Folder_name']== 'Both')]
MB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4093         25      M             1      Normal        Both
# 4094         25      M             1      Normal        Both
# 4095         25      M             1      Normal        Both
# 4096         25      M             1      Normal        Both
# 4097         25      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 4160         25      M             1      Normal        Both
# 4161         25      M             1      Normal        Both
# 4162         25      M             1      Normal        Both
# 4163         25      M             1      Normal        Both
# 4164         25      M             1      Normal        Both
#
#                                               Path_Name      Filename
# 4093  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J27.jpg
# 4094  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ27.jpg
# ...

# %%
MB25 =  MB.iloc[:20,:]
MB25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4093         25      M             1      Normal        Both
# 4094         25      M             1      Normal        Both
# 4095         25      M             1      Normal        Both
# 4096         25      M             1      Normal        Both
# 4097         25      M             1      Normal        Both
# 4098         25      M             1      Normal        Both
# 4099         25      M             1      Normal        Both
# 4100         25      M             1      Normal        Both
# 4101         25      M             1      Normal        Both
# 4102         25      M             1      Normal        Both
# 4103         25      M             1      Normal        Both
# 4104         25      M             1      Normal        Both
# 4105         25      M             1      Normal        Both
# 4106         25      M             1      Normal        Both
# ...

# %%
len(MB25)
# Out:
# 20

# %% [markdown]
# ### Lt (2/2)

# %%
ML = df[(df['Age(year)']== 25) & (df['Gender']== 'M')& (df['Folder_name']== 'Lt')]
ML
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4165         25      M             1      Normal          Lt
# 4166         25      M             1      Normal          Lt
# 4167         25      M             1      Normal          Lt
# 4168         25      M             1      Normal          Lt
# 4169         25      M             1      Normal          Lt
# 4170         25      M             1      Normal          Lt
# 4171         25      M             1      Normal          Lt
# 4172         25      M             1      Normal          Lt
# 4173         25      M             1      Normal          Lt
# 4174         25      M             1      Normal          Lt
# 4175         25      M             1      Normal          Lt
# 4176         25      M             1      Normal          Lt
# 4177         25      M             1      Normal          Lt
# 4178         25      M             1      Normal          Lt
#
# ...

# %%
ML25 =  ML.iloc[:2,:]
ML25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4165         25      M             1      Normal          Lt
# 4166         25      M             1      Normal          Lt
#
#                                               Path_Name      Filename
# 4165  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ134.jpg
# 4166  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ136.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
MR = df[(df['Age(year)']== 25) & (df['Gender']== 'M')& (df['Folder_name']== 'Rt')]
MR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4179         25      M             1      Normal          Rt
# 4180         25      M             1      Normal          Rt
# 4181         25      M             1      Normal          Rt
# 4182         25      M             1      Normal          Rt
# 4183         25      M             1      Normal          Rt
# 4184         25      M             1      Normal          Rt
# 4185         25      M             1      Normal          Rt
# 4186         25      M             1      Normal          Rt
# 4187         25      M             1      Normal          Rt
# 4188         25      M             1      Normal          Rt
#
#                                               Path_Name  Filename
# 4179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   J55.jpg
# 4180  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   J81.jpg
# 4181  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J146.jpg
# ...

# %%
MR25 =  MR.iloc[:1,:]
MR25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4179         25      M             1      Normal          Rt
#
#                                               Path_Name Filename
# 4179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J55.jpg

# %% [markdown]
# ## Female (12 คน 22 ภาพ)

# %% [markdown]
# ### Both (10/20)

# %%
FB = df[(df['Age(year)']== 25) & (df['Gender']== 'F')& (df['Folder_name']== 'Both')]
FB
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3980         25      F             0      Normal        Both
# 3981         25      F             0      Normal        Both
# 3982         25      F             0      Normal        Both
# 3983         25      F             0      Normal        Both
# 3984         25      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 4079         25      F             0      Normal        Both
# 4080         25      F             0      Normal        Both
# 4081         25      F             0      Normal        Both
# 4082         25      F             0      Normal        Both
# 4083         25      F             0      Normal        Both
#
#                                               Path_Name      Filename
# 3980  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J10.jpg
# 3981  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ10.jpg
# ...

# %%
FB25 =  FB.iloc[:20,:]
FB25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 3980         25      F             0      Normal        Both
# 3981         25      F             0      Normal        Both
# 3982         25      F             0      Normal        Both
# 3983         25      F             0      Normal        Both
# 3984         25      F             0      Normal        Both
# 3985         25      F             0      Normal        Both
# 3986         25      F             0      Normal        Both
# 3987         25      F             0      Normal        Both
# 3988         25      F             0      Normal        Both
# 3989         25      F             0      Normal        Both
# 3990         25      F             0      Normal        Both
# 3991         25      F             0      Normal        Both
# 3992         25      F             0      Normal        Both
# 3993         25      F             0      Normal        Both
# ...

# %%
len(FB25)
# Out:
# 20

# %% [markdown]
# ### Lt (1/1)

# %%
FL = df[(df['Age(year)']== 25) & (df['Gender']== 'F')& (df['Folder_name']== 'Lt')]
FL
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4084         25      F             0      Normal          Lt
# 4085         25      F             0      Normal          Lt
# 4086         25      F             0      Normal          Lt
# 4087         25      F             0      Normal          Lt
# 4088         25      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 4084  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ269.jpg
# 4085  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ272.jpg
# 4086  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ280.jpg
# 4087  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ286.jpg
# 4088  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ485.jpg

# %%
FL25 =  FL.iloc[:1,:]
FL25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4084         25      F             0      Normal          Lt
#
#                                               Path_Name      Filename
# 4084  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ269.jpg

# %% [markdown]
# ### Rt (1/1)

# %%
FR = df[(df['Age(year)']== 25) & (df['Gender']== 'F')& (df['Folder_name']== 'Rt')]
FR
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4089         25      F             0      Normal          Rt
# 4090         25      F             0      Normal          Rt
# 4091         25      F             0      Normal          Rt
# 4092         25      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 4089  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J243.jpg
# 4090  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J244.jpg
# 4091  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J287.jpg
# 4092  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J489.jpg

# %%
FR25 =  FR.iloc[:1,:]
FR25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4089         25      F             0      Normal          Rt
#
#                                               Path_Name  Filename
# 4089  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  J243.jpg

# %% [markdown]
# ## 25Y (concat)

# %%
len(pd.concat([MB25,ML25,MR25]))
# Out:
# 23

# %%
len(pd.concat([FB25,FL25,FR25]))
# Out:
# 22

# %%
Y25 = pd.concat([MB25,ML25,MR25,FB25,FL25,FR25])
Y25
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 4093         25      M             1      Normal        Both
# 4094         25      M             1      Normal        Both
# 4095         25      M             1      Normal        Both
# 4096         25      M             1      Normal        Both
# 4097         25      M             1      Normal        Both
# 4098         25      M             1      Normal        Both
# 4099         25      M             1      Normal        Both
# 4100         25      M             1      Normal        Both
# 4101         25      M             1      Normal        Both
# 4102         25      M             1      Normal        Both
# 4103         25      M             1      Normal        Both
# 4104         25      M             1      Normal        Both
# 4105         25      M             1      Normal        Both
# 4106         25      M             1      Normal        Both
# ...

# %%
len(Y25) #img
# Out:
# 45

# %% [markdown]
# # Table Test 20% from 4,189 images

# %%
Test = pd.concat([Y7,Y8,Y9,Y10,Y11,Y12,Y13,Y14,Y15,Y16,Y17,Y18,Y19,Y20,Y21,Y22,Y23,Y24,Y25])
Test
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 114           7      M             1      Normal        Both
# 115           7      M             1      Normal        Both
# 116           7      M             1      Normal        Both
# 117           7      M             1      Normal        Both
# 118           7      M             1      Normal        Both
# ...         ...    ...           ...         ...         ...
# 3997         25      F             0      Normal        Both
# 3998         25      F             0      Normal        Both
# 3999         25      F             0      Normal        Both
# 4084         25      F             0      Normal          Lt
# 4089         25      F             0      Normal          Rt
#
#                                               Path_Name      Filename
# 114   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# 115   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV04.jpg
# ...

# %%
len(Test['Filename'].unique())
# Out:
# 838

# %%
Test = Test.reset_index()
Test
# Out:
#      index  Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0      114          7      M             1      Normal        Both
# 1      115          7      M             1      Normal        Both
# 2      116          7      M             1      Normal        Both
# 3      117          7      M             1      Normal        Both
# 4      118          7      M             1      Normal        Both
# ..     ...        ...    ...           ...         ...         ...
# 833   3997         25      F             0      Normal        Both
# 834   3998         25      F             0      Normal        Both
# 835   3999         25      F             0      Normal        Both
# 836   4084         25      F             0      Normal          Lt
# 837   4089         25      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# ...

# %%
Test = Test.iloc[:,1:]
print(Test.shape)
Test.head(3)
# Out:
# (838, 7)
#    Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0          7      M             1      Normal        Both
# 1          7      M             1      Normal        Both
# 2          7      M             1      Normal        Both
#
#                                            Path_Name      Filename
# 0  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# 1  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV04.jpg
# 2  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV08.jpg

# %%
# os.makedirs('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/100percent', exist_ok=True)
# Test.to_csv('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/100percent/table_test_detection.csv') #save ลงไดร์ฟ

# %% [markdown]
# # Table Train 80% from 4,189 images

# %%
Train = df[~df['Filename'].isin(Test['Filename'])]
Train
# Out:
#       Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 20            7      F             0      Normal        Both
# 21            7      F             0      Normal        Both
# 22            7      F             0      Normal        Both
# 23            7      F             0      Normal        Both
# 24            7      F             0      Normal        Both
# ...         ...    ...           ...         ...         ...
# 4184         25      M             1      Normal          Rt
# 4185         25      M             1      Normal          Rt
# 4186         25      M             1      Normal          Rt
# 4187         25      M             1      Normal          Rt
# 4188         25      M             1      Normal          Rt
#
#                                               Path_Name     Filename
# 20    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V26.jpg
# 21    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV26.jpg
# ...

# %%
Train = Train.reset_index()
print(Train.shape)
Train.head()
# Out:
# (3351, 8)
#    index  Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0     20          7      F             0      Normal        Both
# 1     21          7      F             0      Normal        Both
# 2     22          7      F             0      Normal        Both
# 3     23          7      F             0      Normal        Both
# 4     24          7      F             0      Normal        Both
#
#                                            Path_Name     Filename
# 0  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V26.jpg
# 1  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV26.jpg
# 2  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V29.jpg
# 3  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV29.jpg
# 4  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V30.jpg

# %%
Train = Train.iloc[:,1:]
print(Train.shape)
Train.head(3)
# Out:
# (3351, 7)
#    Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0          7      F             0      Normal        Both
# 1          7      F             0      Normal        Both
# 2          7      F             0      Normal        Both
#
#                                            Path_Name     Filename
# 0  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V26.jpg
# 1  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV26.jpg
# 2  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V29.jpg

# %%
# os.makedirs('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/100percent', exist_ok=True)
# Train.to_csv('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/100percent/table_train_detection.csv') #save ลงไดร์ฟ
