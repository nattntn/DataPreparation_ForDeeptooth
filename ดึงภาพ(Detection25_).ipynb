# %% [markdown]
# <a href="https://colab.research.google.com/github/nattntn/DataPreparation_ForDeeptooth/blob/main/%E0%B8%94%E0%B8%B6%E0%B8%87%E0%B8%A0%E0%B8%B2%E0%B8%9E(Detection25_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import shutil
import cv2
import PIL
from PIL import Image
import os
import glob
import numpy as np
import sys

# %%
#เชื่อม google drive
from google.colab  import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Test 25%

# %%
df =  pd.read_csv (r'/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/table_test_detection.csv')
df
# Out:
#      Unnamed: 0  Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0             0          7      M             1      Normal        Both
# 1             1          7      M             1      Normal        Both
# 2             2          7      M             1      Normal        Both
# 3             3          7      M             1      Normal        Both
# 4             4          7      M             1      Normal        Both
# ..          ...        ...    ...           ...         ...         ...
# 207         207         25      F             0      Normal        Both
# 208         208         25      F             0      Normal        Both
# 209         209         25      F             0      Normal        Both
# 210         210         25      F             0      Normal        Both
# 211         211         25      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV04.jpg
# 2    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV08.jpg
# 3    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV08.jpg
# 4    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV11.jpg
# ..                                                 ...           ...
# 207  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ10.jpg
# 208  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J16.jpg
# 209  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ16.jpg
# 210  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J23.jpg
# 211  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ23.jpg
#
# [212 rows x 8 columns]

# %%
df = df.iloc[:,1:]
df
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0            7      M             1      Normal        Both
# 1            7      M             1      Normal        Both
# 2            7      M             1      Normal        Both
# 3            7      M             1      Normal        Both
# 4            7      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 207         25      F             0      Normal        Both
# 208         25      F             0      Normal        Both
# 209         25      F             0      Normal        Both
# 210         25      F             0      Normal        Both
# 211         25      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV04.jpg
# 2    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV08.jpg
# 3    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV08.jpg
# 4    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV11.jpg
# ..                                                 ...           ...
# 207  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ10.jpg
# 208  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J16.jpg
# 209  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ16.jpg
# 210  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J23.jpg
# 211  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ23.jpg
#
# [212 rows x 7 columns]

# %% [markdown]
# ## Y7

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y7 = os.path.join(base_dir, '7Y')
os.makedirs(Full_image_Y7, exist_ok=True)

# %%
Full_image_Y7_F = os.path.join(Full_image_Y7, 'Female')
os.makedirs(Full_image_Y7_F, exist_ok=True)

Full_image_Y7_M = os.path.join(Full_image_Y7, 'Male')
os.makedirs(Full_image_Y7_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y7F = df[(df['Age(year)'] == 7)&(df['Gender']=='F')]
Y7F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 6           7      F             0      Normal        Both
# 7           7      F             0      Normal        Both
# 8           7      F             0      Normal        Both
# 9           7      F             0      Normal        Both
# 10          7      F             0      Normal          Lt
#
#                                             Path_Name     Filename
# 6   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       V1.jpg
# 7   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipV1.jpg
# 8   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       V2.jpg
# 9   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipV2.jpg
# 10  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV10.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y7F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/7Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y7M = df[(df['Age(year)'] == 7)&(df['Gender']=='M')]
Y7M
# Out:
#    Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0          7      M             1      Normal        Both
# 1          7      M             1      Normal        Both
# 2          7      M             1      Normal        Both
# 3          7      M             1      Normal        Both
# 4          7      M             1      Normal        Both
# 5          7      M             1      Normal        Both
#
#                                            Path_Name      Filename
# 0  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV04.jpg
# 1  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV04.jpg
# 2  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV08.jpg
# 3  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV08.jpg
# 4  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV11.jpg
# 5  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV11.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y7M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/7Y/Male/'+filename)

# %% [markdown]
# ## Y8

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y8 = os.path.join(base_dir, '8Y')
os.makedirs(Full_image_Y8, exist_ok=True)

# %%
Full_image_Y8_F = os.path.join(Full_image_Y8, 'Female')
os.makedirs(Full_image_Y8_F, exist_ok=True)

Full_image_Y8_M = os.path.join(Full_image_Y8, 'Male')
os.makedirs(Full_image_Y8_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y8F = df[(df['Age(year)'] == 8)&(df['Gender']=='F')]
Y8F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 17          8      F             0      Normal        Both
# 18          8      F             0      Normal        Both
# 19          8      F             0      Normal        Both
# 20          8      F             0      Normal        Both
# 21          8      F             0      Normal        Both
# 22          8      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 17  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P01.jpg
# 18  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP01.jpg
# 19  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P02.jpg
# 20  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP02.jpg
# 21  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P07.jpg
# 22  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP07.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y8F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/8Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y8M = df[(df['Age(year)'] == 8)&(df['Gender']=='M')]
Y8M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 11          8      M             1      Normal        Both
# 12          8      M             1      Normal        Both
# 13          8      M             1      Normal        Both
# 14          8      M             1      Normal        Both
# 15          8      M             1      Normal        Both
# 16          8      M             1      Normal        Both
#
#                                             Path_Name      Filename
# 11  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP03.jpg
# 12  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP03.jpg
# 13  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP04.jpg
# 14  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP04.jpg
# 15  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP05.jpg
# 16  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP05.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y8M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/8Y/Male/'+filename)

# %% [markdown]
# ## Y9

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y9 = os.path.join(base_dir, '9Y')
os.makedirs(Full_image_Y9, exist_ok=True)

# %%
Full_image_Y9_F = os.path.join(Full_image_Y9, 'Female')
os.makedirs(Full_image_Y9_F, exist_ok=True)

Full_image_Y9_M = os.path.join(Full_image_Y9, 'Male')
os.makedirs(Full_image_Y9_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y9F = df[(df['Age(year)'] == 9)&(df['Gender']=='F')]
Y9F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 29          9      F             0      Normal        Both
# 30          9      F             0      Normal        Both
# 31          9      F             0      Normal        Both
# 32          9      F             0      Normal        Both
# 33          9      F             0      Normal        Both
# 34          9      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 29  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W06.jpg
# 30  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW06.jpg
# 31  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W09.jpg
# 32  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW09.jpg
# 33  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W13.jpg
# 34  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW13.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y9F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/9Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y9M = df[(df['Age(year)'] == 9)&(df['Gender']=='M')]
Y9M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 23          9      M             1      Normal        Both
# 24          9      M             1      Normal        Both
# 25          9      M             1      Normal        Both
# 26          9      M             1      Normal        Both
# 27          9      M             1      Normal        Both
# 28          9      M             1      Normal        Both
#
#                                             Path_Name      Filename
# 23  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW01.jpg
# 24  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW01.jpg
# 25  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW05.jpg
# 26  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW05.jpg
# 27  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW07.jpg
# 28  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW07.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y9M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/9Y/Male/'+filename)

# %% [markdown]
# ## Y10

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y10 = os.path.join(base_dir, '10Y')
os.makedirs(Full_image_Y10, exist_ok=True)

# %%
Full_image_Y10_F = os.path.join(Full_image_Y10, 'Female')
os.makedirs(Full_image_Y10_F, exist_ok=True)

Full_image_Y10_M = os.path.join(Full_image_Y10, 'Male')
os.makedirs(Full_image_Y10_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y10F = df[(df['Age(year)'] == 10)&(df['Gender']=='F')]
Y10F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 41         10      F             0      Normal        Both
# 42         10      F             0      Normal        Both
# 43         10      F             0      Normal        Both
# 44         10      F             0      Normal        Both
# 45         10      F             0      Normal        Both
# 46         10      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 41  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H02.jpg
# 42  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH02.jpg
# 43  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H03.jpg
# 44  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH03.jpg
# 45  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H08.jpg
# 46  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH08.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y10F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/10Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y10M = df[(df['Age(year)'] == 10)&(df['Gender']=='M')]
Y10M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 35         10      M             1      Normal        Both
# 36         10      M             1      Normal        Both
# 37         10      M             1      Normal        Both
# 38         10      M             1      Normal        Both
# 39         10      M             1      Normal        Both
# 40         10      M             1      Normal        Both
#
#                                             Path_Name      Filename
# 35  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       HH4.jpg
# 36  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipHH4.jpg
# 37  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       HH6.jpg
# 38  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipHH6.jpg
# 39  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH13.jpg
# 40  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH13.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y10M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/10Y/Male/'+filename)

# %% [markdown]
# ## Y11

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y11 = os.path.join(base_dir, '11Y')
os.makedirs(Full_image_Y11, exist_ok=True)

# %%
Full_image_Y11_F = os.path.join(Full_image_Y11, 'Female')
os.makedirs(Full_image_Y11_F, exist_ok=True)

Full_image_Y11_M = os.path.join(Full_image_Y11, 'Male')
os.makedirs(Full_image_Y11_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y11F = df[(df['Age(year)'] == 11)&(df['Gender']=='F')]
Y11F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 52         11      F             0      Normal        Both
# 53         11      F             0      Normal        Both
# 54         11      F             0      Normal        Both
# 55         11      F             0      Normal        Both
# 56         11      F             0      Normal        Both
# 57         11      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 52  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D03.jpg
# 53  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD03.jpg
# 54  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D04.jpg
# 55  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD04.jpg
# 56  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D10.jpg
# 57  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD10.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y11F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/11Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y11M = df[(df['Age(year)'] == 11)&(df['Gender']=='M')]
Y11M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 47         11      M             1      Normal        Both
# 48         11      M             1      Normal        Both
# 49         11      M             1      Normal        Both
# 50         11      M             1      Normal        Both
# 51         11      M             1      Normal          Rt
#
#                                             Path_Name      Filename
# 47  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD06.jpg
# 48  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD06.jpg
# 49  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD07.jpg
# 50  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD07.jpg
# 51  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD54.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y11M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/11Y/Male/'+filename)

# %% [markdown]
# ## Y12

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y12 = os.path.join(base_dir, '12Y')
os.makedirs(Full_image_Y12, exist_ok=True)

# %%
Full_image_Y12_F = os.path.join(Full_image_Y12, 'Female')
os.makedirs(Full_image_Y12_F, exist_ok=True)

Full_image_Y12_M = os.path.join(Full_image_Y12, 'Male')
os.makedirs(Full_image_Y12_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y12F = df[(df['Age(year)'] == 12)&(df['Gender']=='F')]
Y12F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 64         12      F             0      Normal        Both
# 65         12      F             0      Normal        Both
# 66         12      F             0      Normal        Both
# 67         12      F             0      Normal        Both
# 68         12      F             0      Normal          Rt
#
#                                             Path_Name     Filename
# 64  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      O04.jpg
# 65  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO04.jpg
# 66  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      O05.jpg
# 67  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO05.jpg
# 68  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      O03.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y12F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/12Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y12M = df[(df['Age(year)'] == 12)&(df['Gender']=='M')]
Y12M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 58         12      M             1      Normal        Both
# 59         12      M             1      Normal        Both
# 60         12      M             1      Normal        Both
# 61         12      M             1      Normal        Both
# 62         12      M             1      Normal        Both
# 63         12      M             1      Normal        Both
#
#                                             Path_Name      Filename
# 58  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO01.jpg
# 59  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO01.jpg
# 60  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO05.jpg
# 61  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO05.jpg
# 62  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO07.jpg
# 63  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO07.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y12M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/12Y/Male/'+filename)

# %% [markdown]
# ## Y13

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y13 = os.path.join(base_dir, '13Y')
os.makedirs(Full_image_Y13, exist_ok=True)

# %%
Full_image_Y13_F = os.path.join(Full_image_Y13, 'Female')
os.makedirs(Full_image_Y13_F, exist_ok=True)

Full_image_Y13_M = os.path.join(Full_image_Y13, 'Male')
os.makedirs(Full_image_Y13_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y13F = df[(df['Age(year)'] == 13)&(df['Gender']=='F')]
Y13F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 75         13      F             0      Normal        Both
# 76         13      F             0      Normal        Both
# 77         13      F             0      Normal        Both
# 78         13      F             0      Normal        Both
# 79         13      F             0      Normal        Both
# 80         13      F             0      Normal        Both
#
#                                             Path_Name      Filename
# 75  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G151.jpg
# 76  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG151.jpg
# 77  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G156.jpg
# 78  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG156.jpg
# 79  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G157.jpg
# 80  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG157.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y13F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/13Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y13M = df[(df['Age(year)'] == 13)&(df['Gender']=='M')]
Y13M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 69         13      M             1      Normal        Both
# 70         13      M             1      Normal        Both
# 71         13      M             1      Normal        Both
# 72         13      M             1      Normal        Both
# 73         13      M             1      Normal        Both
# 74         13      M             1      Normal        Both
#
#                                             Path_Name      Filename
# 69  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG08.jpg
# 70  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG08.jpg
# 71  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG09.jpg
# 72  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG09.jpg
# 73  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG10.jpg
# 74  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG10.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y13M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/13Y/Male/'+filename)

# %% [markdown]
# ## Y14

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y14 = os.path.join(base_dir, '14Y')
os.makedirs(Full_image_Y14, exist_ok=True)

# %%
Full_image_Y14_F = os.path.join(Full_image_Y14, 'Female')
os.makedirs(Full_image_Y14_F, exist_ok=True)

Full_image_Y14_M = os.path.join(Full_image_Y14, 'Male')
os.makedirs(Full_image_Y14_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y14F = df[(df['Age(year)'] == 14)&(df['Gender']=='F')]
Y14F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 86         14      F             0      Normal        Both
# 87         14      F             0      Normal        Both
# 88         14      F             0      Normal        Both
# 89         14      F             0      Normal        Both
# 90         14      F             0      Normal        Both
# 91         14      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 86  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y05.jpg
# 87  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY05.jpg
# 88  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y06.jpg
# 89  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY06.jpg
# 90  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y11.jpg
# 91  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY11.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y14F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/14Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y14M = df[(df['Age(year)'] == 14)&(df['Gender']=='M')]
Y14M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 81         14      M             1      Normal        Both
# 82         14      M             1      Normal        Both
# 83         14      M             1      Normal        Both
# 84         14      M             1      Normal        Both
# 85         14      M             1      Normal          Lt
#
#                                             Path_Name      Filename
# 81  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY07.jpg
# 82  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY07.jpg
# 83  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY10.jpg
# 84  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY10.jpg
# 85  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY27.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y14M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/14Y/Male/'+filename)

# %% [markdown]
# ## Y15

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y15 = os.path.join(base_dir, '15Y')
os.makedirs(Full_image_Y15, exist_ok=True)

# %%
Full_image_Y15_F = os.path.join(Full_image_Y15, 'Female')
os.makedirs(Full_image_Y15_F, exist_ok=True)

Full_image_Y15_M = os.path.join(Full_image_Y15, 'Male')
os.makedirs(Full_image_Y15_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y15F = df[(df['Age(year)'] == 15)&(df['Gender']=='F')]
Y15F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 98          15      F             0      Normal        Both
# 99          15      F             0      Normal        Both
# 100         15      F             0      Normal        Both
# 101         15      F             0      Normal        Both
# 102         15      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 98   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B07.jpg
# 99   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB07.jpg
# 100  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B08.jpg
# 101  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB08.jpg
# 102  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB59.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y15F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/15Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y15M = df[(df['Age(year)'] == 15)&(df['Gender']=='M')]
Y15M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 92         15      M             1      Normal        Both
# 93         15      M             1      Normal        Both
# 94         15      M             1      Normal        Both
# 95         15      M             1      Normal        Both
# 96         15      M             1      Normal        Both
# 97         15      M             1      Normal        Both
#
#                                             Path_Name     Filename
# 92  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B03.jpg
# 93  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB03.jpg
# 94  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B25.jpg
# 95  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB25.jpg
# 96  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B37.jpg
# 97  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB37.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y15M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/15Y/Male/'+filename)

# %% [markdown]
# ## Y16

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y16 = os.path.join(base_dir, '16Y')
os.makedirs(Full_image_Y16, exist_ok=True)

# %%
Full_image_Y16_F = os.path.join(Full_image_Y16, 'Female')
os.makedirs(Full_image_Y16_F, exist_ok=True)

Full_image_Y16_M = os.path.join(Full_image_Y16, 'Male')
os.makedirs(Full_image_Y16_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y16F = df[(df['Age(year)'] == 16)&(df['Gender']=='F')]
Y16F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 108         16      F             0      Normal        Both
# 109         16      F             0      Normal        Both
# 110         16      F             0      Normal        Both
# 111         16      F             0      Normal        Both
# 112         16      F             0      Normal        Both
# 113         16      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 108  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T14.jpg
# 109  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT14.jpg
# 110  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T16.jpg
# 111  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT16.jpg
# 112  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T21.jpg
# 113  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT21.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y16F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/16Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y16M = df[(df['Age(year)'] == 16)&(df['Gender']=='M')]
Y16M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 103         16      M             1      Normal        Both
# 104         16      M             1      Normal        Both
# 105         16      M             1      Normal        Both
# 106         16      M             1      Normal        Both
# 107         16      M             1      Normal          Lt
#
#                                              Path_Name      Filename
# 103  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T03.jpg
# 104  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT03.jpg
# 105  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T15.jpg
# 106  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT15.jpg
# 107  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT202.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y16M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/16Y/Male/'+filename)

# %% [markdown]
# ## Y17

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y17 = os.path.join(base_dir, '17Y')
os.makedirs(Full_image_Y17, exist_ok=True)

# %%
Full_image_Y17_F = os.path.join(Full_image_Y17, 'Female')
os.makedirs(Full_image_Y17_F, exist_ok=True)

Full_image_Y17_M = os.path.join(Full_image_Y17, 'Male')
os.makedirs(Full_image_Y17_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y17F = df[(df['Age(year)'] == 17)&(df['Gender']=='F')]
Y17F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 120         17      F             0      Normal        Both
# 121         17      F             0      Normal        Both
# 122         17      F             0      Normal        Both
# 123         17      F             0      Normal        Both
# 124         17      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 120  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K05.jpg
# 121  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK05.jpg
# 122  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K15.jpg
# 123  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK15.jpg
# 124  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK93.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y17F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/17Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y17M = df[(df['Age(year)'] == 17)&(df['Gender']=='M')]
Y17M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 114         17      M             1      Normal        Both
# 115         17      M             1      Normal        Both
# 116         17      M             1      Normal        Both
# 117         17      M             1      Normal        Both
# 118         17      M             1      Normal        Both
# 119         17      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 114  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K17.jpg
# 115  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK17.jpg
# 116  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K21.jpg
# 117  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK21.jpg
# 118  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K23.jpg
# 119  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK23.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y17M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/17Y/Male/'+filename)

# %% [markdown]
# ## Y18

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y18 = os.path.join(base_dir, '18Y')
os.makedirs(Full_image_Y18, exist_ok=True)

# %%
Full_image_Y18_F = os.path.join(Full_image_Y18, 'Female')
os.makedirs(Full_image_Y18_F, exist_ok=True)

Full_image_Y18_M = os.path.join(Full_image_Y18, 'Male')
os.makedirs(Full_image_Y18_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y18F = df[(df['Age(year)'] == 18)&(df['Gender']=='F')]
Y18F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 130         18      F             0      Normal        Both
# 131         18      F             0      Normal        Both
# 132         18      F             0      Normal        Both
# 133         18      F             0      Normal        Both
# 134         18      F             0      Normal        Both
# 135         18      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 130  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S02.jpg
# 131  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS02.jpg
# 132  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S08.jpg
# 133  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS08.jpg
# 134  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S16.jpg
# 135  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS16.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y18F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/18Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y18M = df[(df['Age(year)'] == 18)&(df['Gender']=='M')]
Y18M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 125         18      M             1      Normal        Both
# 126         18      M             1      Normal        Both
# 127         18      M             1      Normal        Both
# 128         18      M             1      Normal        Both
# 129         18      M             1      Normal          Rt
#
#                                              Path_Name     Filename
# 125  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S13.jpg
# 126  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS13.jpg
# 127  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S14.jpg
# 128  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS14.jpg
# 129  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...     S367.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y18M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/18Y/Male/'+filename)

# %% [markdown]
# ## Y19

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y19 = os.path.join(base_dir, '19Y')
os.makedirs(Full_image_Y19, exist_ok=True)

# %%
Full_image_Y19_F = os.path.join(Full_image_Y19, 'Female')
os.makedirs(Full_image_Y19_F, exist_ok=True)

Full_image_Y19_M = os.path.join(Full_image_Y19, 'Male')
os.makedirs(Full_image_Y19_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y19F = df[(df['Age(year)'] == 19)&(df['Gender']=='F')]
Y19F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 142         19      F             0      Normal        Both
# 143         19      F             0      Normal        Both
# 144         19      F             0      Normal        Both
# 145         19      F             0      Normal        Both
# 146         19      F             0      Normal          Rt
#
#                                              Path_Name     Filename
# 142  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L12.jpg
# 143  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL12.jpg
# 144  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L15.jpg
# 145  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL15.jpg
# 146  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L42.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y19F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/19Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y19M = df[(df['Age(year)'] == 19)&(df['Gender']=='M')]
Y19M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 136         19      M             1      Normal        Both
# 137         19      M             1      Normal        Both
# 138         19      M             1      Normal        Both
# 139         19      M             1      Normal        Both
# 140         19      M             1      Normal        Both
# 141         19      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 136  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L09.jpg
# 137  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL09.jpg
# 138  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L20.jpg
# 139  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL20.jpg
# 140  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L33.jpg
# 141  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL33.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y19M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/19Y/Male/'+filename)

# %% [markdown]
# ## Y20

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y20 = os.path.join(base_dir, '20Y')
os.makedirs(Full_image_Y20, exist_ok=True)

# %%
Full_image_Y20_F = os.path.join(Full_image_Y20, 'Female')
os.makedirs(Full_image_Y20_F, exist_ok=True)

Full_image_Y20_M = os.path.join(Full_image_Y20, 'Male')
os.makedirs(Full_image_Y20_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y20F = df[(df['Age(year)'] == 20)&(df['Gender']=='F')]
Y20F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 153         20      F             0      Normal        Both
# 154         20      F             0      Normal        Both
# 155         20      F             0      Normal        Both
# 156         20      F             0      Normal        Both
# 157         20      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 153  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q08.jpg
# 154  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ08.jpg
# 155  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q15.jpg
# 156  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ15.jpg
# 157  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ83.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y20F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/20Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y20M = df[(df['Age(year)'] == 20)&(df['Gender']=='M')]
Y20M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 147         20      M             1      Normal        Both
# 148         20      M             1      Normal        Both
# 149         20      M             1      Normal        Both
# 150         20      M             1      Normal        Both
# 151         20      M             1      Normal        Both
# 152         20      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 147  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q13.jpg
# 148  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ13.jpg
# 149  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q14.jpg
# 150  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ14.jpg
# 151  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q19.jpg
# 152  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ19.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y20M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/20Y/Male/'+filename)

# %% [markdown]
# ## Y21

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y21 = os.path.join(base_dir, '21Y')
os.makedirs(Full_image_Y21, exist_ok=True)

# %%
Full_image_Y21_F = os.path.join(Full_image_Y21, 'Female')
os.makedirs(Full_image_Y21_F, exist_ok=True)

Full_image_Y21_M = os.path.join(Full_image_Y21, 'Male')
os.makedirs(Full_image_Y21_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y21F = df[(df['Age(year)'] == 21)&(df['Gender']=='F')]
Y21F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 164         21      F             0      Normal        Both
# 165         21      F             0      Normal        Both
# 166         21      F             0      Normal        Both
# 167         21      F             0      Normal        Both
# 168         21      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 164  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N18.jpg
# 165  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN18.jpg
# 166  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N26.jpg
# 167  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN26.jpg
# 168  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN36.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y21F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/21Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y21M = df[(df['Age(year)'] == 21)&(df['Gender']=='M')]
Y21M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 158         21      M             1      Normal        Both
# 159         21      M             1      Normal        Both
# 160         21      M             1      Normal        Both
# 161         21      M             1      Normal        Both
# 162         21      M             1      Normal        Both
# 163         21      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 158  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N25.jpg
# 159  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN25.jpg
# 160  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N38.jpg
# 161  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN38.jpg
# 162  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N47.jpg
# 163  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN47.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y21M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/21Y/Male/'+filename)

# %% [markdown]
# ## Y22

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y22 = os.path.join(base_dir, '22Y')
os.makedirs(Full_image_Y22, exist_ok=True)

# %%
Full_image_Y22_F = os.path.join(Full_image_Y22, 'Female')
os.makedirs(Full_image_Y22_F, exist_ok=True)

Full_image_Y22_M = os.path.join(Full_image_Y22, 'Male')
os.makedirs(Full_image_Y22_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y22F = df[(df['Age(year)'] == 22)&(df['Gender']=='F')]
Y22F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 174         22      F             0      Normal        Both
# 175         22      F             0      Normal        Both
# 176         22      F             0      Normal        Both
# 177         22      F             0      Normal        Both
# 178         22      F             0      Normal        Both
# 179         22      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 174  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U04.jpg
# 175  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU04.jpg
# 176  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U24.jpg
# 177  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU24.jpg
# 178  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U25.jpg
# 179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU25.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y22F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/22Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y22M = df[(df['Age(year)'] == 22)&(df['Gender']=='M')]
Y22M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 169         22      M             1      Normal        Both
# 170         22      M             1      Normal        Both
# 171         22      M             1      Normal        Both
# 172         22      M             1      Normal        Both
# 173         22      M             1      Normal          Lt
#
#                                              Path_Name     Filename
# 169  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U22.jpg
# 170  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU22.jpg
# 171  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U26.jpg
# 172  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU26.jpg
# 173  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU06.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y22M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/22Y/Male/'+filename)

# %% [markdown]
# ## Y23

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y23 = os.path.join(base_dir, '23Y')
os.makedirs(Full_image_Y23, exist_ok=True)

# %%
Full_image_Y23_F = os.path.join(Full_image_Y23, 'Female')
os.makedirs(Full_image_Y23_F, exist_ok=True)

Full_image_Y23_M = os.path.join(Full_image_Y23, 'Male')
os.makedirs(Full_image_Y23_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y23F = df[(df['Age(year)'] == 23)&(df['Gender']=='F')]
Y23F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 186         23      F             0      Normal        Both
# 187         23      F             0      Normal        Both
# 188         23      F             0      Normal        Both
# 189         23      F             0      Normal        Both
# 190         23      F             0      Normal          Lt
#
#                                              Path_Name     Filename
# 186  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E03.jpg
# 187  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE03.jpg
# 188  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E14.jpg
# 189  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE14.jpg
# 190  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE43.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y23F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/23Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y23M = df[(df['Age(year)'] == 23)&(df['Gender']=='M')]
Y23M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 180         23      M             1      Normal        Both
# 181         23      M             1      Normal        Both
# 182         23      M             1      Normal        Both
# 183         23      M             1      Normal        Both
# 184         23      M             1      Normal        Both
# 185         23      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 180  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E10.jpg
# 181  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE10.jpg
# 182  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E24.jpg
# 183  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE24.jpg
# 184  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E27.jpg
# 185  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE27.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y23M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/23Y/Male/'+filename)

# %% [markdown]
# ## Y24

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y24 = os.path.join(base_dir, '24Y')
os.makedirs(Full_image_Y24, exist_ok=True)

# %%
Full_image_Y24_F = os.path.join(Full_image_Y24, 'Female')
os.makedirs(Full_image_Y24_F, exist_ok=True)

Full_image_Y24_M = os.path.join(Full_image_Y24, 'Male')
os.makedirs(Full_image_Y24_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y24F = df[(df['Age(year)'] == 24)&(df['Gender']=='F')]
Y24F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 197         24      F             0      Normal        Both
# 198         24      F             0      Normal        Both
# 199         24      F             0      Normal        Both
# 200         24      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 197  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z04.jpg
# 198  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ04.jpg
# 199  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z12.jpg
# 200  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ12.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y24F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/24Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y24M = df[(df['Age(year)'] == 24)&(df['Gender']=='M')]
Y24M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 191         24      M             1      Normal        Both
# 192         24      M             1      Normal        Both
# 193         24      M             1      Normal        Both
# 194         24      M             1      Normal        Both
# 195         24      M             1      Normal        Both
# 196         24      M             1      Normal        Both
#
#                                              Path_Name     Filename
# 191  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z09.jpg
# 192  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ09.jpg
# 193  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z11.jpg
# 194  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ11.jpg
# 195  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z13.jpg
# 196  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ13.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y24M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/24Y/Male/'+filename)

# %% [markdown]
# ## Y25

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y25 = os.path.join(base_dir, '25Y')
os.makedirs(Full_image_Y25, exist_ok=True)

# %%
Full_image_Y25_F = os.path.join(Full_image_Y25, 'Female')
os.makedirs(Full_image_Y25_F, exist_ok=True)

Full_image_Y25_M = os.path.join(Full_image_Y25, 'Male')
os.makedirs(Full_image_Y25_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y25F = df[(df['Age(year)'] == 25)&(df['Gender']=='F')]
Y25F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 206         25      F             0      Normal        Both
# 207         25      F             0      Normal        Both
# 208         25      F             0      Normal        Both
# 209         25      F             0      Normal        Both
# 210         25      F             0      Normal        Both
# 211         25      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 206  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J10.jpg
# 207  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ10.jpg
# 208  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J16.jpg
# 209  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ16.jpg
# 210  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J23.jpg
# 211  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ23.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y25F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/25Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y25M = df[(df['Age(year)'] == 25)&(df['Gender']=='M')]
Y25M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 201         25      M             1      Normal        Both
# 202         25      M             1      Normal        Both
# 203         25      M             1      Normal        Both
# 204         25      M             1      Normal        Both
# 205         25      M             1      Normal          Rt
#
#                                              Path_Name     Filename
# 201  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J27.jpg
# 202  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ27.jpg
# 203  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J37.jpg
# 204  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ37.jpg
# 205  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J55.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y25M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Test/25Y/Male/'+filename)

# %% [markdown]
# # Train 25%

# %%
df =  pd.read_csv (r'/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/table_train_detection.csv')
df
# Out:
#      Unnamed: 0  Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0             0          7      M             1      Normal        Both
# 1             1          7      M             1      Normal        Both
# 2             2          7      M             1      Normal        Both
# 3             3          7      M             1      Normal        Both
# 4             4          7      M             1      Normal        Both
# ..          ...        ...    ...           ...         ...         ...
# 835         835         25      F             0      Normal        Both
# 836         836         25      F             0      Normal        Both
# 837         837         25      F             0      Normal          Lt
# 838         838         25      F             0      Normal          Lt
# 839         839         25      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV24.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV24.jpg
# 2    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV26.jpg
# 3    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV26.jpg
# 4    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV36.jpg
# ..                                                 ...           ...
# 835  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J140.jpg
# 836  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ140.jpg
# 837  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ272.jpg
# 838  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ280.jpg
# 839  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J244.jpg
#
# [840 rows x 8 columns]

# %%
df = df.iloc[:,1:]
df
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0            7      M             1      Normal        Both
# 1            7      M             1      Normal        Both
# 2            7      M             1      Normal        Both
# 3            7      M             1      Normal        Both
# 4            7      M             1      Normal        Both
# ..         ...    ...           ...         ...         ...
# 835         25      F             0      Normal        Both
# 836         25      F             0      Normal        Both
# 837         25      F             0      Normal          Lt
# 838         25      F             0      Normal          Lt
# 839         25      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 0    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV24.jpg
# 1    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV24.jpg
# 2    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV26.jpg
# 3    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV26.jpg
# 4    /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV36.jpg
# ..                                                 ...           ...
# 835  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J140.jpg
# 836  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ140.jpg
# 837  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ272.jpg
# 838  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ280.jpg
# 839  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J244.jpg
#
# [840 rows x 7 columns]

# %% [markdown]
# ## Y7

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y7 = os.path.join(base_dir, '7Y')
os.makedirs(Full_image_Y7, exist_ok=True)

# %%
Full_image_Y7_F = os.path.join(Full_image_Y7, 'Female')
os.makedirs(Full_image_Y7_F, exist_ok=True)

Full_image_Y7_M = os.path.join(Full_image_Y7, 'Male')
os.makedirs(Full_image_Y7_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y7F = df[(df['Age(year)'] == 7)&(df['Gender']=='F')]
Y7F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 23          7      F             0      Normal        Both
# 24          7      F             0      Normal        Both
# 25          7      F             0      Normal        Both
# 26          7      F             0      Normal        Both
# 27          7      F             0      Normal        Both
# 28          7      F             0      Normal        Both
# 29          7      F             0      Normal        Both
# 30          7      F             0      Normal        Both
# 31          7      F             0      Normal        Both
# 32          7      F             0      Normal        Both
# 33          7      F             0      Normal        Both
# 34          7      F             0      Normal        Both
# 35          7      F             0      Normal        Both
# 36          7      F             0      Normal        Both
# 37          7      F             0      Normal        Both
# 38          7      F             0      Normal        Both
# 39          7      F             0      Normal        Both
# 40          7      F             0      Normal        Both
# 41          7      F             0      Normal        Both
# 42          7      F             0      Normal        Both
# 43          7      F             0      Normal          Lt
# 44          7      F             0      Normal          Rt
#
#                                             Path_Name     Filename
# 23  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V26.jpg
# 24  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV26.jpg
# 25  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V29.jpg
# 26  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV29.jpg
# 27  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V30.jpg
# 28  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV30.jpg
# 29  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V34.jpg
# 30  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV34.jpg
# 31  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V35.jpg
# 32  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV35.jpg
# 33  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V38.jpg
# 34  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV38.jpg
# 35  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V40.jpg
# 36  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV40.jpg
# 37  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V41.jpg
# 38  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV41.jpg
# 39  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V42.jpg
# 40  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV42.jpg
# 41  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V43.jpg
# 42  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV43.jpg
# 43  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipV14.jpg
# 44  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      V50.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y7F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/7Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y7M = df[(df['Age(year)'] == 7)&(df['Gender']=='M')]
Y7M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 0           7      M             1      Normal        Both
# 1           7      M             1      Normal        Both
# 2           7      M             1      Normal        Both
# 3           7      M             1      Normal        Both
# 4           7      M             1      Normal        Both
# 5           7      M             1      Normal        Both
# 6           7      M             1      Normal        Both
# 7           7      M             1      Normal        Both
# 8           7      M             1      Normal        Both
# 9           7      M             1      Normal        Both
# 10          7      M             1      Normal        Both
# 11          7      M             1      Normal        Both
# 12          7      M             1      Normal        Both
# 13          7      M             1      Normal        Both
# 14          7      M             1      Normal        Both
# 15          7      M             1      Normal        Both
# 16          7      M             1      Normal        Both
# 17          7      M             1      Normal        Both
# 18          7      M             1      Normal        Both
# 19          7      M             1      Normal        Both
# 20          7      M             1      Normal          Lt
# 21          7      M             1      Normal          Lt
# 22          7      M             1      Normal          Rt
#
#                                             Path_Name      Filename
# 0   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV24.jpg
# 1   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV24.jpg
# 2   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV26.jpg
# 3   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV26.jpg
# 4   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV36.jpg
# 5   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV36.jpg
# 6   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV39.jpg
# 7   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV39.jpg
# 8   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV41.jpg
# 9   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV41.jpg
# 10  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV45.jpg
# 11  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV45.jpg
# 12  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV46.jpg
# 13  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV46.jpg
# 14  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV50.jpg
# 15  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV50.jpg
# 16  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV51.jpg
# 17  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV51.jpg
# 18  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV52.jpg
# 19  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV52.jpg
# 20  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV30.jpg
# 21  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipVV67.jpg
# 22  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV20.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y7M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/7Y/Male/'+filename)

# %% [markdown]
# ## Y8

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y8 = os.path.join(base_dir, '8Y')
os.makedirs(Full_image_Y8, exist_ok=True)

# %%
Full_image_Y8_F = os.path.join(Full_image_Y8, 'Female')
os.makedirs(Full_image_Y8_F, exist_ok=True)

Full_image_Y8_M = os.path.join(Full_image_Y8, 'Male')
os.makedirs(Full_image_Y8_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y8F = df[(df['Age(year)'] == 8)&(df['Gender']=='F')]
Y8F
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 68          8      F             0      Normal        Both
# 69          8      F             0      Normal        Both
# 70          8      F             0      Normal        Both
# 71          8      F             0      Normal        Both
# 72          8      F             0      Normal        Both
# 73          8      F             0      Normal        Both
# 74          8      F             0      Normal        Both
# 75          8      F             0      Normal        Both
# 76          8      F             0      Normal        Both
# 77          8      F             0      Normal        Both
# 78          8      F             0      Normal        Both
# 79          8      F             0      Normal        Both
# 80          8      F             0      Normal        Both
# 81          8      F             0      Normal        Both
# 82          8      F             0      Normal        Both
# 83          8      F             0      Normal        Both
# 84          8      F             0      Normal        Both
# 85          8      F             0      Normal        Both
# 86          8      F             0      Normal        Both
# 87          8      F             0      Normal        Both
# 88          8      F             0      Normal        Both
# 89          8      F             0      Normal        Both
# 90          8      F             0      Normal        Both
# 91          8      F             0      Normal        Both
#
#                                             Path_Name     Filename
# 68  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P29.jpg
# 69  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP29.jpg
# 70  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P30.jpg
# 71  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP30.jpg
# 72  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P35.jpg
# 73  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP35.jpg
# 74  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P38.jpg
# 75  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP38.jpg
# 76  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P40.jpg
# 77  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP40.jpg
# 78  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P42.jpg
# 79  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP42.jpg
# 80  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P43.jpg
# 81  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP43.jpg
# 82  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P45.jpg
# 83  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP45.jpg
# 84  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P47.jpg
# 85  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP47.jpg
# 86  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P50.jpg
# 87  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP50.jpg
# 88  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P52.jpg
# 89  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP52.jpg
# 90  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      P53.jpg
# 91  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipP53.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y8F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/8Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y8M = df[(df['Age(year)'] == 8)&(df['Gender']=='M')]
Y8M
# Out:
#     Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 45          8      M             1      Normal        Both
# 46          8      M             1      Normal        Both
# 47          8      M             1      Normal        Both
# 48          8      M             1      Normal        Both
# 49          8      M             1      Normal        Both
# 50          8      M             1      Normal        Both
# 51          8      M             1      Normal        Both
# 52          8      M             1      Normal        Both
# 53          8      M             1      Normal        Both
# 54          8      M             1      Normal        Both
# 55          8      M             1      Normal        Both
# 56          8      M             1      Normal        Both
# 57          8      M             1      Normal        Both
# 58          8      M             1      Normal        Both
# 59          8      M             1      Normal        Both
# 60          8      M             1      Normal        Both
# 61          8      M             1      Normal        Both
# 62          8      M             1      Normal        Both
# 63          8      M             1      Normal        Both
# 64          8      M             1      Normal        Both
# 65          8      M             1      Normal        Both
# 66          8      M             1      Normal        Both
# 67          8      M             1      Normal          Lt
#
#                                             Path_Name      Filename
# 45  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP22.jpg
# 46  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP22.jpg
# 47  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP24.jpg
# 48  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP24.jpg
# 49  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP25.jpg
# 50  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP25.jpg
# 51  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP28.jpg
# 52  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP28.jpg
# 53  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP30.jpg
# 54  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP30.jpg
# 55  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP31.jpg
# 56  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP31.jpg
# 57  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP34.jpg
# 58  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP34.jpg
# 59  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP36.jpg
# 60  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP36.jpg
# 61  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP37.jpg
# 62  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP37.jpg
# 63  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP40.jpg
# 64  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP40.jpg
# 65  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      PP45.jpg
# 66  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP45.jpg
# 67  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipPP61.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y8M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/8Y/Male/'+filename)

# %% [markdown]
# ## Y9

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y9 = os.path.join(base_dir, '9Y')
os.makedirs(Full_image_Y9, exist_ok=True)

# %%
Full_image_Y9_F = os.path.join(Full_image_Y9, 'Female')
os.makedirs(Full_image_Y9_F, exist_ok=True)

Full_image_Y9_M = os.path.join(Full_image_Y9, 'Male')
os.makedirs(Full_image_Y9_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y9F = df[(df['Age(year)'] == 9)&(df['Gender']=='F')]
Y9F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 116          9      F             0      Normal        Both
# 117          9      F             0      Normal        Both
# 118          9      F             0      Normal        Both
# 119          9      F             0      Normal        Both
# 120          9      F             0      Normal        Both
# 121          9      F             0      Normal        Both
# 122          9      F             0      Normal        Both
# 123          9      F             0      Normal        Both
# 124          9      F             0      Normal        Both
# 125          9      F             0      Normal        Both
# 126          9      F             0      Normal        Both
# 127          9      F             0      Normal        Both
# 128          9      F             0      Normal        Both
# 129          9      F             0      Normal        Both
# 130          9      F             0      Normal        Both
# 131          9      F             0      Normal        Both
# 132          9      F             0      Normal        Both
# 133          9      F             0      Normal        Both
# 134          9      F             0      Normal        Both
# 135          9      F             0      Normal        Both
# 136          9      F             0      Normal        Both
# 137          9      F             0      Normal        Both
# 138          9      F             0      Normal        Both
# 139          9      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 116  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W25.jpg
# 117  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW25.jpg
# 118  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W27.jpg
# 119  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW27.jpg
# 120  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W30.jpg
# 121  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW30.jpg
# 122  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W31.jpg
# 123  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW31.jpg
# 124  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W35.jpg
# 125  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW35.jpg
# 126  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W36.jpg
# 127  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW36.jpg
# 128  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W40.jpg
# 129  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW40.jpg
# 130  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W44.jpg
# 131  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW44.jpg
# 132  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W45.jpg
# 133  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW45.jpg
# 134  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W48.jpg
# 135  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW48.jpg
# 136  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W49.jpg
# 137  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW49.jpg
# 138  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      W55.jpg
# 139  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipW55.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y9F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/9Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y9M = df[(df['Age(year)'] == 9)&(df['Gender']=='M')]
Y9M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 92           9      M             1      Normal        Both
# 93           9      M             1      Normal        Both
# 94           9      M             1      Normal        Both
# 95           9      M             1      Normal        Both
# 96           9      M             1      Normal        Both
# 97           9      M             1      Normal        Both
# 98           9      M             1      Normal        Both
# 99           9      M             1      Normal        Both
# 100          9      M             1      Normal        Both
# 101          9      M             1      Normal        Both
# 102          9      M             1      Normal        Both
# 103          9      M             1      Normal        Both
# 104          9      M             1      Normal        Both
# 105          9      M             1      Normal        Both
# 106          9      M             1      Normal        Both
# 107          9      M             1      Normal        Both
# 108          9      M             1      Normal        Both
# 109          9      M             1      Normal        Both
# 110          9      M             1      Normal        Both
# 111          9      M             1      Normal        Both
# 112          9      M             1      Normal        Both
# 113          9      M             1      Normal        Both
# 114          9      M             1      Normal        Both
# 115          9      M             1      Normal        Both
#
#                                              Path_Name      Filename
# 92   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW26.jpg
# 93   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW26.jpg
# 94   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW29.jpg
# 95   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW29.jpg
# 96   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW31.jpg
# 97   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW31.jpg
# 98   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW34.jpg
# 99   /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW34.jpg
# 100  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW39.jpg
# 101  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW39.jpg
# 102  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW40.jpg
# 103  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW40.jpg
# 104  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW41.jpg
# 105  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW41.jpg
# 106  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW42.jpg
# 107  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW42.jpg
# 108  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW46.jpg
# 109  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW46.jpg
# 110  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW49.jpg
# 111  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW49.jpg
# 112  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW50.jpg
# 113  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW50.jpg
# 114  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      WW51.jpg
# 115  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipWW51.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y9M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/9Y/Male/'+filename)

# %% [markdown]
# ## Y10

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y10 = os.path.join(base_dir, '10Y')
os.makedirs(Full_image_Y10, exist_ok=True)

# %%
Full_image_Y10_F = os.path.join(Full_image_Y10, 'Female')
os.makedirs(Full_image_Y10_F, exist_ok=True)

Full_image_Y10_M = os.path.join(Full_image_Y10, 'Male')
os.makedirs(Full_image_Y10_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y10F = df[(df['Age(year)'] == 10)&(df['Gender']=='F')]
Y10F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 164         10      F             0      Normal        Both
# 165         10      F             0      Normal        Both
# 166         10      F             0      Normal        Both
# 167         10      F             0      Normal        Both
# 168         10      F             0      Normal        Both
# 169         10      F             0      Normal        Both
# 170         10      F             0      Normal        Both
# 171         10      F             0      Normal        Both
# 172         10      F             0      Normal        Both
# 173         10      F             0      Normal        Both
# 174         10      F             0      Normal        Both
# 175         10      F             0      Normal        Both
# 176         10      F             0      Normal        Both
# 177         10      F             0      Normal        Both
# 178         10      F             0      Normal        Both
# 179         10      F             0      Normal        Both
# 180         10      F             0      Normal        Both
# 181         10      F             0      Normal        Both
# 182         10      F             0      Normal        Both
# 183         10      F             0      Normal        Both
# 184         10      F             0      Normal        Both
# 185         10      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 164  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H25.jpg
# 165  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH25.jpg
# 166  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H28.jpg
# 167  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH28.jpg
# 168  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H30.jpg
# 169  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH30.jpg
# 170  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H34.jpg
# 171  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH34.jpg
# 172  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H40.jpg
# 173  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH40.jpg
# 174  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H41.jpg
# 175  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH41.jpg
# 176  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H47.jpg
# 177  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH47.jpg
# 178  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H48.jpg
# 179  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH48.jpg
# 180  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H53.jpg
# 181  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH53.jpg
# 182  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H54.jpg
# 183  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH54.jpg
# 184  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      H56.jpg
# 185  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipH56.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y10F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/10Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y10M = df[(df['Age(year)'] == 10)&(df['Gender']=='M')]
Y10M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 140         10      M             1      Normal        Both
# 141         10      M             1      Normal        Both
# 142         10      M             1      Normal        Both
# 143         10      M             1      Normal        Both
# 144         10      M             1      Normal        Both
# 145         10      M             1      Normal        Both
# 146         10      M             1      Normal        Both
# 147         10      M             1      Normal        Both
# 148         10      M             1      Normal        Both
# 149         10      M             1      Normal        Both
# 150         10      M             1      Normal        Both
# 151         10      M             1      Normal        Both
# 152         10      M             1      Normal        Both
# 153         10      M             1      Normal        Both
# 154         10      M             1      Normal        Both
# 155         10      M             1      Normal        Both
# 156         10      M             1      Normal        Both
# 157         10      M             1      Normal        Both
# 158         10      M             1      Normal        Both
# 159         10      M             1      Normal        Both
# 160         10      M             1      Normal        Both
# 161         10      M             1      Normal        Both
# 162         10      M             1      Normal        Both
# 163         10      M             1      Normal        Both
#
#                                              Path_Name      Filename
# 140  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH33.jpg
# 141  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH33.jpg
# 142  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH34.jpg
# 143  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH34.jpg
# 144  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH36.jpg
# 145  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH36.jpg
# 146  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH40.jpg
# 147  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH40.jpg
# 148  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH42.jpg
# 149  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH42.jpg
# 150  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH43.jpg
# 151  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH43.jpg
# 152  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH45.jpg
# 153  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH45.jpg
# 154  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH49.jpg
# 155  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH49.jpg
# 156  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH51.jpg
# 157  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH51.jpg
# 158  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH55.jpg
# 159  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH55.jpg
# 160  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH56.jpg
# 161  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH56.jpg
# 162  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      HH58.jpg
# 163  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipHH58.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y10M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/10Y/Male/'+filename)

# %% [markdown]
# ## Y11

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y11 = os.path.join(base_dir, '11Y')
os.makedirs(Full_image_Y11, exist_ok=True)

# %%
Full_image_Y11_F = os.path.join(Full_image_Y11, 'Female')
os.makedirs(Full_image_Y11_F, exist_ok=True)

Full_image_Y11_M = os.path.join(Full_image_Y11, 'Male')
os.makedirs(Full_image_Y11_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y11F = df[(df['Age(year)'] == 11)&(df['Gender']=='F')]
Y11F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 209         11      F             0      Normal        Both
# 210         11      F             0      Normal        Both
# 211         11      F             0      Normal        Both
# 212         11      F             0      Normal        Both
# 213         11      F             0      Normal        Both
# 214         11      F             0      Normal        Both
# 215         11      F             0      Normal        Both
# 216         11      F             0      Normal        Both
# 217         11      F             0      Normal        Both
# 218         11      F             0      Normal        Both
# 219         11      F             0      Normal        Both
# 220         11      F             0      Normal        Both
# 221         11      F             0      Normal        Both
# 222         11      F             0      Normal        Both
# 223         11      F             0      Normal        Both
# 224         11      F             0      Normal        Both
# 225         11      F             0      Normal        Both
# 226         11      F             0      Normal        Both
# 227         11      F             0      Normal        Both
# 228         11      F             0      Normal        Both
# 229         11      F             0      Normal        Both
# 230         11      F             0      Normal        Both
# 231         11      F             0      Normal        Both
# 232         11      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 209  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D26.jpg
# 210  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD26.jpg
# 211  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D27.jpg
# 212  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD27.jpg
# 213  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D30.jpg
# 214  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD30.jpg
# 215  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D16.jpg
# 216  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD16.jpg
# 217  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D32.jpg
# 218  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD32.jpg
# 219  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D35.jpg
# 220  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD35.jpg
# 221  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D36.jpg
# 222  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD36.jpg
# 223  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D38.jpg
# 224  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD38.jpg
# 225  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D39.jpg
# 226  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD39.jpg
# 227  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D40.jpg
# 228  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD40.jpg
# 229  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D34.jpg
# 230  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD34.jpg
# 231  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      D46.jpg
# 232  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipD46.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y11F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/11Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y11M = df[(df['Age(year)'] == 11)&(df['Gender']=='M')]
Y11M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 186         11      M             1      Normal        Both
# 187         11      M             1      Normal        Both
# 188         11      M             1      Normal        Both
# 189         11      M             1      Normal        Both
# 190         11      M             1      Normal        Both
# 191         11      M             1      Normal        Both
# 192         11      M             1      Normal        Both
# 193         11      M             1      Normal        Both
# 194         11      M             1      Normal        Both
# 195         11      M             1      Normal        Both
# 196         11      M             1      Normal        Both
# 197         11      M             1      Normal        Both
# 198         11      M             1      Normal        Both
# 199         11      M             1      Normal        Both
# 200         11      M             1      Normal        Both
# 201         11      M             1      Normal        Both
# 202         11      M             1      Normal        Both
# 203         11      M             1      Normal        Both
# 204         11      M             1      Normal        Both
# 205         11      M             1      Normal        Both
# 206         11      M             1      Normal        Both
# 207         11      M             1      Normal        Both
# 208         11      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 186  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD26.jpg
# 187  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD26.jpg
# 188  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD28.jpg
# 189  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD28.jpg
# 190  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD31.jpg
# 191  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD31.jpg
# 192  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD34.jpg
# 193  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD34.jpg
# 194  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD35.jpg
# 195  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD35.jpg
# 196  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD36.jpg
# 197  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD36.jpg
# 198  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD37.jpg
# 199  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD37.jpg
# 200  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD39.jpg
# 201  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD39.jpg
# 202  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD32.jpg
# 203  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD32.jpg
# 204  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD42.jpg
# 205  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD42.jpg
# 206  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD44.jpg
# 207  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipDD44.jpg
# 208  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      DD73.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y11M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/11Y/Male/'+filename)

# %% [markdown]
# ## Y12

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y12 = os.path.join(base_dir, '12Y')
os.makedirs(Full_image_Y12, exist_ok=True)

# %%
Full_image_Y12_F = os.path.join(Full_image_Y12, 'Female')
os.makedirs(Full_image_Y12_F, exist_ok=True)

Full_image_Y12_M = os.path.join(Full_image_Y12, 'Male')
os.makedirs(Full_image_Y12_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y12F = df[(df['Age(year)'] == 12)&(df['Gender']=='F')]
Y12F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 257         12      F             0      Normal        Both
# 258         12      F             0      Normal        Both
# 259         12      F             0      Normal        Both
# 260         12      F             0      Normal        Both
# 261         12      F             0      Normal        Both
# 262         12      F             0      Normal        Both
# 263         12      F             0      Normal        Both
# 264         12      F             0      Normal        Both
# 265         12      F             0      Normal        Both
# 266         12      F             0      Normal        Both
# 267         12      F             0      Normal        Both
# 268         12      F             0      Normal        Both
# 269         12      F             0      Normal        Both
# 270         12      F             0      Normal        Both
# 271         12      F             0      Normal        Both
# 272         12      F             0      Normal        Both
# 273         12      F             0      Normal        Both
# 274         12      F             0      Normal        Both
# 275         12      F             0      Normal        Both
# 276         12      F             0      Normal        Both
# 277         12      F             0      Normal        Both
# 278         12      F             0      Normal        Both
# 279         12      F             0      Normal          Lt
# 280         12      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 257  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O25.jpg
# 258  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO25.jpg
# 259  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O33.jpg
# 260  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO33.jpg
# 261  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O34.jpg
# 262  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO34.jpg
# 263  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O35.jpg
# 264  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO35.jpg
# 265  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O36.jpg
# 266  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO36.jpg
# 267  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O37.jpg
# 268  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO37.jpg
# 269  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O38.jpg
# 270  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO38.jpg
# 271  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O39.jpg
# 272  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO39.jpg
# 273  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O48.jpg
# 274  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO48.jpg
# 275  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O51.jpg
# 276  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO51.jpg
# 277  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       O52.jpg
# 278  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipO52.jpg
# 279  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipO109.jpg
# 280  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      O137.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y12F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/12Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y12M = df[(df['Age(year)'] == 12)&(df['Gender']=='M')]
Y12M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 233         12      M             1      Normal        Both
# 234         12      M             1      Normal        Both
# 235         12      M             1      Normal        Both
# 236         12      M             1      Normal        Both
# 237         12      M             1      Normal        Both
# 238         12      M             1      Normal        Both
# 239         12      M             1      Normal        Both
# 240         12      M             1      Normal        Both
# 241         12      M             1      Normal        Both
# 242         12      M             1      Normal        Both
# 243         12      M             1      Normal        Both
# 244         12      M             1      Normal        Both
# 245         12      M             1      Normal        Both
# 246         12      M             1      Normal        Both
# 247         12      M             1      Normal        Both
# 248         12      M             1      Normal        Both
# 249         12      M             1      Normal        Both
# 250         12      M             1      Normal        Both
# 251         12      M             1      Normal        Both
# 252         12      M             1      Normal        Both
# 253         12      M             1      Normal        Both
# 254         12      M             1      Normal        Both
# 255         12      M             1      Normal        Both
# 256         12      M             1      Normal        Both
#
#                                              Path_Name      Filename
# 233  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO41.jpg
# 234  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO41.jpg
# 235  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO43.jpg
# 236  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO43.jpg
# 237  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO48.jpg
# 238  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO48.jpg
# 239  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO50.jpg
# 240  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO50.jpg
# 241  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO52.jpg
# 242  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO52.jpg
# 243  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO53.jpg
# 244  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO53.jpg
# 245  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO55.jpg
# 246  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO55.jpg
# 247  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO56.jpg
# 248  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO56.jpg
# 249  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO58.jpg
# 250  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO58.jpg
# 251  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO59.jpg
# 252  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO59.jpg
# 253  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO60.jpg
# 254  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO60.jpg
# 255  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      OO62.jpg
# 256  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipOO62.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y12M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/12Y/Male/'+filename)

# %% [markdown]
# ## Y13

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y13 = os.path.join(base_dir, '13Y')
os.makedirs(Full_image_Y13, exist_ok=True)

# %%
Full_image_Y13_F = os.path.join(Full_image_Y13, 'Female')
os.makedirs(Full_image_Y13_F, exist_ok=True)

Full_image_Y13_M = os.path.join(Full_image_Y13, 'Male')
os.makedirs(Full_image_Y13_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y13F = df[(df['Age(year)'] == 13)&(df['Gender']=='F')]
Y13F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 302         13      F             0      Normal        Both
# 303         13      F             0      Normal        Both
# 304         13      F             0      Normal        Both
# 305         13      F             0      Normal        Both
# 306         13      F             0      Normal        Both
# 307         13      F             0      Normal        Both
# 308         13      F             0      Normal        Both
# 309         13      F             0      Normal        Both
# 310         13      F             0      Normal        Both
# 311         13      F             0      Normal        Both
# 312         13      F             0      Normal        Both
# 313         13      F             0      Normal        Both
# 314         13      F             0      Normal        Both
# 315         13      F             0      Normal        Both
# 316         13      F             0      Normal        Both
# 317         13      F             0      Normal        Both
# 318         13      F             0      Normal        Both
# 319         13      F             0      Normal        Both
# 320         13      F             0      Normal        Both
# 321         13      F             0      Normal        Both
# 322         13      F             0      Normal        Both
# 323         13      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 302  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G16.jpg
# 303  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG16.jpg
# 304  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G19.jpg
# 305  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG19.jpg
# 306  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G20.jpg
# 307  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG20.jpg
# 308  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G23.jpg
# 309  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG23.jpg
# 310  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G24.jpg
# 311  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG24.jpg
# 312  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G25.jpg
# 313  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG25.jpg
# 314  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G27.jpg
# 315  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG27.jpg
# 316  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G28.jpg
# 317  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG28.jpg
# 318  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G05.jpg
# 319  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG05.jpg
# 320  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G06.jpg
# 321  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG06.jpg
# 322  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      G32.jpg
# 323  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipG32.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y13F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/13Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y13M = df[(df['Age(year)'] == 13)&(df['Gender']=='M')]
Y13M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 281         13      M             1      Normal        Both
# 282         13      M             1      Normal        Both
# 283         13      M             1      Normal        Both
# 284         13      M             1      Normal        Both
# 285         13      M             1      Normal        Both
# 286         13      M             1      Normal        Both
# 287         13      M             1      Normal        Both
# 288         13      M             1      Normal        Both
# 289         13      M             1      Normal        Both
# 290         13      M             1      Normal        Both
# 291         13      M             1      Normal        Both
# 292         13      M             1      Normal        Both
# 293         13      M             1      Normal        Both
# 294         13      M             1      Normal        Both
# 295         13      M             1      Normal        Both
# 296         13      M             1      Normal        Both
# 297         13      M             1      Normal        Both
# 298         13      M             1      Normal        Both
# 299         13      M             1      Normal          Lt
# 300         13      M             1      Normal          Rt
# 301         13      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 281  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG37.jpg
# 282  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG37.jpg
# 283  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG43.jpg
# 284  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG43.jpg
# 285  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG49.jpg
# 286  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG49.jpg
# 287  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG50.jpg
# 288  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG50.jpg
# 289  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG53.jpg
# 290  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG53.jpg
# 291  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG58.jpg
# 292  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG58.jpg
# 293  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG61.jpg
# 294  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG61.jpg
# 295  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG62.jpg
# 296  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG62.jpg
# 297  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG63.jpg
# 298  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG63.jpg
# 299  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipGG47.jpg
# 300  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG25.jpg
# 301  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      GG46.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y13M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/13Y/Male/'+filename)

# %% [markdown]
# ## Y14

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y14 = os.path.join(base_dir, '14Y')
os.makedirs(Full_image_Y14, exist_ok=True)

# %%
Full_image_Y14_F = os.path.join(Full_image_Y14, 'Female')
os.makedirs(Full_image_Y14_F, exist_ok=True)

Full_image_Y14_M = os.path.join(Full_image_Y14, 'Male')
os.makedirs(Full_image_Y14_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y14F = df[(df['Age(year)'] == 14)&(df['Gender']=='F')]
Y14F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 345         14      F             0      Normal        Both
# 346         14      F             0      Normal        Both
# 347         14      F             0      Normal        Both
# 348         14      F             0      Normal        Both
# 349         14      F             0      Normal        Both
# 350         14      F             0      Normal        Both
# 351         14      F             0      Normal        Both
# 352         14      F             0      Normal        Both
# 353         14      F             0      Normal        Both
# 354         14      F             0      Normal        Both
# 355         14      F             0      Normal        Both
# 356         14      F             0      Normal        Both
# 357         14      F             0      Normal        Both
# 358         14      F             0      Normal        Both
# 359         14      F             0      Normal        Both
# 360         14      F             0      Normal        Both
# 361         14      F             0      Normal        Both
# 362         14      F             0      Normal        Both
# 363         14      F             0      Normal        Both
# 364         14      F             0      Normal        Both
# 365         14      F             0      Normal        Both
# 366         14      F             0      Normal        Both
# 367         14      F             0      Normal        Both
# 368         14      F             0      Normal        Both
#
#                                              Path_Name     Filename
# 345  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y28.jpg
# 346  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY28.jpg
# 347  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y30.jpg
# 348  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY30.jpg
# 349  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y36.jpg
# 350  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY36.jpg
# 351  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y37.jpg
# 352  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY37.jpg
# 353  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y38.jpg
# 354  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY38.jpg
# 355  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y43.jpg
# 356  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY43.jpg
# 357  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y45.jpg
# 358  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY45.jpg
# 359  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y50.jpg
# 360  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY50.jpg
# 361  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y52.jpg
# 362  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY52.jpg
# 363  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y53.jpg
# 364  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY53.jpg
# 365  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y57.jpg
# 366  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY57.jpg
# 367  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Y58.jpg
# 368  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipY58.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y14F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/14Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y14M = df[(df['Age(year)'] == 14)&(df['Gender']=='M')]
Y14M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 324         14      M             1      Normal        Both
# 325         14      M             1      Normal        Both
# 326         14      M             1      Normal        Both
# 327         14      M             1      Normal        Both
# 328         14      M             1      Normal        Both
# 329         14      M             1      Normal        Both
# 330         14      M             1      Normal        Both
# 331         14      M             1      Normal        Both
# 332         14      M             1      Normal        Both
# 333         14      M             1      Normal        Both
# 334         14      M             1      Normal        Both
# 335         14      M             1      Normal        Both
# 336         14      M             1      Normal        Both
# 337         14      M             1      Normal        Both
# 338         14      M             1      Normal        Both
# 339         14      M             1      Normal        Both
# 340         14      M             1      Normal        Both
# 341         14      M             1      Normal        Both
# 342         14      M             1      Normal          Lt
# 343         14      M             1      Normal          Rt
# 344         14      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 324  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY42.jpg
# 325  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY42.jpg
# 326  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY44.jpg
# 327  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY44.jpg
# 328  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY45.jpg
# 329  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY45.jpg
# 330  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY46.jpg
# 331  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY46.jpg
# 332  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY50.jpg
# 333  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY50.jpg
# 334  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY51.jpg
# 335  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY51.jpg
# 336  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY56.jpg
# 337  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY56.jpg
# 338  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY59.jpg
# 339  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY59.jpg
# 340  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY61.jpg
# 341  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY61.jpg
# 342  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipYY38.jpg
# 343  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY16.jpg
# 344  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      YY69.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y14M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/14Y/Male/'+filename)

# %% [markdown]
# ## Y15

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y15 = os.path.join(base_dir, '15Y')
os.makedirs(Full_image_Y15, exist_ok=True)

# %%
Full_image_Y15_F = os.path.join(Full_image_Y15, 'Female')
os.makedirs(Full_image_Y15_F, exist_ok=True)

Full_image_Y15_M = os.path.join(Full_image_Y15, 'Male')
os.makedirs(Full_image_Y15_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y15F = df[(df['Age(year)'] == 15)&(df['Gender']=='F')]
Y15F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 392         15      F             0      Normal        Both
# 393         15      F             0      Normal        Both
# 394         15      F             0      Normal        Both
# 395         15      F             0      Normal        Both
# 396         15      F             0      Normal        Both
# 397         15      F             0      Normal        Both
# 398         15      F             0      Normal        Both
# 399         15      F             0      Normal        Both
# 400         15      F             0      Normal        Both
# 401         15      F             0      Normal        Both
# 402         15      F             0      Normal        Both
# 403         15      F             0      Normal        Both
# 404         15      F             0      Normal        Both
# 405         15      F             0      Normal        Both
# 406         15      F             0      Normal        Both
# 407         15      F             0      Normal        Both
# 408         15      F             0      Normal        Both
# 409         15      F             0      Normal        Both
# 410         15      F             0      Normal        Both
# 411         15      F             0      Normal        Both
# 412         15      F             0      Normal        Both
# 413         15      F             0      Normal        Both
# 414         15      F             0      Normal          Lt
#
#                                              Path_Name      Filename
# 392  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B57.jpg
# 393  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB57.jpg
# 394  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B58.jpg
# 395  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB58.jpg
# 396  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B60.jpg
# 397  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB60.jpg
# 398  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B67.jpg
# 399  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB67.jpg
# 400  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B80.jpg
# 401  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB80.jpg
# 402  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B81.jpg
# 403  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB81.jpg
# 404  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B83.jpg
# 405  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB83.jpg
# 406  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B86.jpg
# 407  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB86.jpg
# 408  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B89.jpg
# 409  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB89.jpg
# 410  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B90.jpg
# 411  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB90.jpg
# 412  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       B94.jpg
# 413  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipB94.jpg
# 414  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB234.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y15F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/15Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y15M = df[(df['Age(year)'] == 15)&(df['Gender']=='M')]
Y15M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 369         15      M             1      Normal        Both
# 370         15      M             1      Normal        Both
# 371         15      M             1      Normal        Both
# 372         15      M             1      Normal        Both
# 373         15      M             1      Normal        Both
# 374         15      M             1      Normal        Both
# 375         15      M             1      Normal        Both
# 376         15      M             1      Normal        Both
# 377         15      M             1      Normal        Both
# 378         15      M             1      Normal        Both
# 379         15      M             1      Normal        Both
# 380         15      M             1      Normal        Both
# 381         15      M             1      Normal        Both
# 382         15      M             1      Normal        Both
# 383         15      M             1      Normal        Both
# 384         15      M             1      Normal        Both
# 385         15      M             1      Normal        Both
# 386         15      M             1      Normal        Both
# 387         15      M             1      Normal        Both
# 388         15      M             1      Normal        Both
# 389         15      M             1      Normal        Both
# 390         15      M             1      Normal        Both
# 391         15      M             1      Normal          Lt
#
#                                              Path_Name      Filename
# 369  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B113.jpg
# 370  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB113.jpg
# 371  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B140.jpg
# 372  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB140.jpg
# 373  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B143.jpg
# 374  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB143.jpg
# 375  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B147.jpg
# 376  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB147.jpg
# 377  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B159.jpg
# 378  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB159.jpg
# 379  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B160.jpg
# 380  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB160.jpg
# 381  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B161.jpg
# 382  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB161.jpg
# 383  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B164.jpg
# 384  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB164.jpg
# 385  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B168.jpg
# 386  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB168.jpg
# 387  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B177.jpg
# 388  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB177.jpg
# 389  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      B187.jpg
# 390  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB187.jpg
# 391  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipB272.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y15M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/15Y/Male/'+filename)

# %% [markdown]
# ## Y16

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y16 = os.path.join(base_dir, '16Y')
os.makedirs(Full_image_Y16, exist_ok=True)

# %%
Full_image_Y16_F = os.path.join(Full_image_Y16, 'Female')
os.makedirs(Full_image_Y16_F, exist_ok=True)

Full_image_Y16_M = os.path.join(Full_image_Y16, 'Male')
os.makedirs(Full_image_Y16_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y16F = df[(df['Age(year)'] == 16)&(df['Gender']=='F')]
Y16F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 439         16      F             0      Normal        Both
# 440         16      F             0      Normal        Both
# 441         16      F             0      Normal        Both
# 442         16      F             0      Normal        Both
# 443         16      F             0      Normal        Both
# 444         16      F             0      Normal        Both
# 445         16      F             0      Normal        Both
# 446         16      F             0      Normal        Both
# 447         16      F             0      Normal        Both
# 448         16      F             0      Normal        Both
# 449         16      F             0      Normal        Both
# 450         16      F             0      Normal        Both
# 451         16      F             0      Normal        Both
# 452         16      F             0      Normal        Both
# 453         16      F             0      Normal        Both
# 454         16      F             0      Normal        Both
# 455         16      F             0      Normal        Both
# 456         16      F             0      Normal        Both
# 457         16      F             0      Normal        Both
# 458         16      F             0      Normal        Both
# 459         16      F             0      Normal        Both
# 460         16      F             0      Normal        Both
# 461         16      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 439  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T67.jpg
# 440  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT67.jpg
# 441  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T90.jpg
# 442  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT90.jpg
# 443  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T92.jpg
# 444  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT92.jpg
# 445  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T103.jpg
# 446  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT103.jpg
# 447  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T107.jpg
# 448  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT107.jpg
# 449  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T108.jpg
# 450  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT108.jpg
# 451  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T112.jpg
# 452  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT112.jpg
# 453  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T115.jpg
# 454  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT115.jpg
# 455  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T126.jpg
# 456  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT126.jpg
# 457  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T129.jpg
# 458  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT129.jpg
# 459  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T131.jpg
# 460  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT131.jpg
# 461  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T39.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y16F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/16Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y16M = df[(df['Age(year)'] == 16)&(df['Gender']=='M')]
Y16M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 415         16      M             1      Normal        Both
# 416         16      M             1      Normal        Both
# 417         16      M             1      Normal        Both
# 418         16      M             1      Normal        Both
# 419         16      M             1      Normal        Both
# 420         16      M             1      Normal        Both
# 421         16      M             1      Normal        Both
# 422         16      M             1      Normal        Both
# 423         16      M             1      Normal        Both
# 424         16      M             1      Normal        Both
# 425         16      M             1      Normal        Both
# 426         16      M             1      Normal        Both
# 427         16      M             1      Normal        Both
# 428         16      M             1      Normal        Both
# 429         16      M             1      Normal        Both
# 430         16      M             1      Normal        Both
# 431         16      M             1      Normal        Both
# 432         16      M             1      Normal        Both
# 433         16      M             1      Normal        Both
# 434         16      M             1      Normal        Both
# 435         16      M             1      Normal        Both
# 436         16      M             1      Normal        Both
# 437         16      M             1      Normal          Lt
# 438         16      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 415  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T95.jpg
# 416  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT95.jpg
# 417  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       T99.jpg
# 418  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipT99.jpg
# 419  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T114.jpg
# 420  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT114.jpg
# 421  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T117.jpg
# 422  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT117.jpg
# 423  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T119.jpg
# 424  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT119.jpg
# 425  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T134.jpg
# 426  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT134.jpg
# 427  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T143.jpg
# 428  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT143.jpg
# 429  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T144.jpg
# 430  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT144.jpg
# 431  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T145.jpg
# 432  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT145.jpg
# 433  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T155.jpg
# 434  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT155.jpg
# 435  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T165.jpg
# 436  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT165.jpg
# 437  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipT309.jpg
# 438  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      T130.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y16M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/16Y/Male/'+filename)

# %% [markdown]
# ## Y17

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y17 = os.path.join(base_dir, '17Y')
os.makedirs(Full_image_Y17, exist_ok=True)

# %%
Full_image_Y17_F = os.path.join(Full_image_Y17, 'Female')
os.makedirs(Full_image_Y17_F, exist_ok=True)

Full_image_Y17_M = os.path.join(Full_image_Y17, 'Male')
os.makedirs(Full_image_Y17_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y17F = df[(df['Age(year)'] == 17)&(df['Gender']=='F')]
Y17F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 483         17      F             0      Normal        Both
# 484         17      F             0      Normal        Both
# 485         17      F             0      Normal        Both
# 486         17      F             0      Normal        Both
# 487         17      F             0      Normal        Both
# 488         17      F             0      Normal        Both
# 489         17      F             0      Normal        Both
# 490         17      F             0      Normal        Both
# 491         17      F             0      Normal        Both
# 492         17      F             0      Normal        Both
# 493         17      F             0      Normal        Both
# 494         17      F             0      Normal        Both
# 495         17      F             0      Normal        Both
# 496         17      F             0      Normal        Both
# 497         17      F             0      Normal        Both
# 498         17      F             0      Normal        Both
# 499         17      F             0      Normal        Both
# 500         17      F             0      Normal        Both
# 501         17      F             0      Normal        Both
# 502         17      F             0      Normal        Both
# 503         17      F             0      Normal        Both
# 504         17      F             0      Normal        Both
# 505         17      F             0      Normal          Rt
#
#                                              Path_Name     Filename
# 483  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K44.jpg
# 484  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK44.jpg
# 485  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K45.jpg
# 486  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK45.jpg
# 487  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K47.jpg
# 488  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK47.jpg
# 489  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K48.jpg
# 490  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK48.jpg
# 491  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K50.jpg
# 492  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK50.jpg
# 493  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K53.jpg
# 494  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK53.jpg
# 495  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K58.jpg
# 496  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK58.jpg
# 497  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K60.jpg
# 498  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK60.jpg
# 499  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K61.jpg
# 500  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK61.jpg
# 501  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K76.jpg
# 502  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK76.jpg
# 503  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K78.jpg
# 504  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK78.jpg
# 505  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K89.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y17F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/17Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y17M = df[(df['Age(year)'] == 17)&(df['Gender']=='M')]
Y17M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 462         17      M             1      Normal        Both
# 463         17      M             1      Normal        Both
# 464         17      M             1      Normal        Both
# 465         17      M             1      Normal        Both
# 466         17      M             1      Normal        Both
# 467         17      M             1      Normal        Both
# 468         17      M             1      Normal        Both
# 469         17      M             1      Normal        Both
# 470         17      M             1      Normal        Both
# 471         17      M             1      Normal        Both
# 472         17      M             1      Normal        Both
# 473         17      M             1      Normal        Both
# 474         17      M             1      Normal        Both
# 475         17      M             1      Normal        Both
# 476         17      M             1      Normal        Both
# 477         17      M             1      Normal        Both
# 478         17      M             1      Normal        Both
# 479         17      M             1      Normal        Both
# 480         17      M             1      Normal        Both
# 481         17      M             1      Normal        Both
# 482         17      M             1      Normal          Lt
#
#                                              Path_Name      Filename
# 462  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       K88.jpg
# 463  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipK88.jpg
# 464  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       K91.jpg
# 465  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipK91.jpg
# 466  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K100.jpg
# 467  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK100.jpg
# 468  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K105.jpg
# 469  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK105.jpg
# 470  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K108.jpg
# 471  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK108.jpg
# 472  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K134.jpg
# 473  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK134.jpg
# 474  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K137.jpg
# 475  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK137.jpg
# 476  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K159.jpg
# 477  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK159.jpg
# 478  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K161.jpg
# 479  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK161.jpg
# 480  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      K166.jpg
# 481  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK166.jpg
# 482  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipK200.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y17M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/17Y/Male/'+filename)

# %% [markdown]
# ## Y18

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y18 = os.path.join(base_dir, '18Y')
os.makedirs(Full_image_Y18, exist_ok=True)

# %%
Full_image_Y18_F = os.path.join(Full_image_Y18, 'Female')
os.makedirs(Full_image_Y18_F, exist_ok=True)

Full_image_Y18_M = os.path.join(Full_image_Y18, 'Male')
os.makedirs(Full_image_Y18_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y18F = df[(df['Age(year)'] == 18)&(df['Gender']=='F')]
Y18F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 530         18      F             0      Normal        Both
# 531         18      F             0      Normal        Both
# 532         18      F             0      Normal        Both
# 533         18      F             0      Normal        Both
# 534         18      F             0      Normal        Both
# 535         18      F             0      Normal        Both
# 536         18      F             0      Normal        Both
# 537         18      F             0      Normal        Both
# 538         18      F             0      Normal        Both
# 539         18      F             0      Normal        Both
# 540         18      F             0      Normal        Both
# 541         18      F             0      Normal        Both
# 542         18      F             0      Normal        Both
# 543         18      F             0      Normal        Both
# 544         18      F             0      Normal        Both
# 545         18      F             0      Normal        Both
# 546         18      F             0      Normal        Both
# 547         18      F             0      Normal        Both
# 548         18      F             0      Normal        Both
# 549         18      F             0      Normal        Both
# 550         18      F             0      Normal          Lt
# 551         18      F             0      Normal          Rt
# 552         18      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 530  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S56.jpg
# 531  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS56.jpg
# 532  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S59.jpg
# 533  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS59.jpg
# 534  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S62.jpg
# 535  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS62.jpg
# 536  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S64.jpg
# 537  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS64.jpg
# 538  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S66.jpg
# 539  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS66.jpg
# 540  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S71.jpg
# 541  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS71.jpg
# 542  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S78.jpg
# 543  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS78.jpg
# 544  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S79.jpg
# 545  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS79.jpg
# 546  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S82.jpg
# 547  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS82.jpg
# 548  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S84.jpg
# 549  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS84.jpg
# 550  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS225.jpg
# 551  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S116.jpg
# 552  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S127.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y18F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/18Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y18M = df[(df['Age(year)'] == 18)&(df['Gender']=='M')]
Y18M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 506         18      M             1      Normal        Both
# 507         18      M             1      Normal        Both
# 508         18      M             1      Normal        Both
# 509         18      M             1      Normal        Both
# 510         18      M             1      Normal        Both
# 511         18      M             1      Normal        Both
# 512         18      M             1      Normal        Both
# 513         18      M             1      Normal        Both
# 514         18      M             1      Normal        Both
# 515         18      M             1      Normal        Both
# 516         18      M             1      Normal        Both
# 517         18      M             1      Normal        Both
# 518         18      M             1      Normal        Both
# 519         18      M             1      Normal        Both
# 520         18      M             1      Normal        Both
# 521         18      M             1      Normal        Both
# 522         18      M             1      Normal        Both
# 523         18      M             1      Normal        Both
# 524         18      M             1      Normal        Both
# 525         18      M             1      Normal        Both
# 526         18      M             1      Normal        Both
# 527         18      M             1      Normal        Both
# 528         18      M             1      Normal        Both
# 529         18      M             1      Normal        Both
#
#                                              Path_Name      Filename
# 506  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S87.jpg
# 507  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS87.jpg
# 508  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       S97.jpg
# 509  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipS97.jpg
# 510  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S137.jpg
# 511  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS137.jpg
# 512  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S138.jpg
# 513  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS138.jpg
# 514  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S154.jpg
# 515  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS154.jpg
# 516  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S162.jpg
# 517  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS162.jpg
# 518  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S164.jpg
# 519  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS164.jpg
# 520  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S180.jpg
# 521  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS180.jpg
# 522  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S190.jpg
# 523  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS190.jpg
# 524  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S192.jpg
# 525  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS192.jpg
# 526  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S194.jpg
# 527  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS194.jpg
# 528  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      S205.jpg
# 529  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipS205.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y18M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/18Y/Male/'+filename)

# %% [markdown]
# ## Y19

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y19 = os.path.join(base_dir, '19Y')
os.makedirs(Full_image_Y19, exist_ok=True)

# %%
Full_image_Y19_F = os.path.join(Full_image_Y19, 'Female')
os.makedirs(Full_image_Y19_F, exist_ok=True)

Full_image_Y19_M = os.path.join(Full_image_Y19, 'Male')
os.makedirs(Full_image_Y19_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y19F = df[(df['Age(year)'] == 19)&(df['Gender']=='F')]
Y19F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 574         19      F             0      Normal        Both
# 575         19      F             0      Normal        Both
# 576         19      F             0      Normal        Both
# 577         19      F             0      Normal        Both
# 578         19      F             0      Normal        Both
# 579         19      F             0      Normal        Both
# 580         19      F             0      Normal        Both
# 581         19      F             0      Normal        Both
# 582         19      F             0      Normal        Both
# 583         19      F             0      Normal        Both
# 584         19      F             0      Normal        Both
# 585         19      F             0      Normal        Both
# 586         19      F             0      Normal        Both
# 587         19      F             0      Normal        Both
# 588         19      F             0      Normal        Both
# 589         19      F             0      Normal        Both
# 590         19      F             0      Normal        Both
# 591         19      F             0      Normal        Both
# 592         19      F             0      Normal        Both
# 593         19      F             0      Normal        Both
# 594         19      F             0      Normal        Both
# 595         19      F             0      Normal        Both
# 596         19      F             0      Normal        Both
# 597         19      F             0      Normal        Both
#
#                                              Path_Name      Filename
# 574  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L64.jpg
# 575  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL64.jpg
# 576  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L71.jpg
# 577  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL71.jpg
# 578  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L72.jpg
# 579  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL72.jpg
# 580  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L82.jpg
# 581  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL82.jpg
# 582  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L94.jpg
# 583  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL94.jpg
# 584  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L101.jpg
# 585  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL101.jpg
# 586  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L105.jpg
# 587  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL105.jpg
# 588  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L118.jpg
# 589  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL118.jpg
# 590  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L132.jpg
# 591  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL132.jpg
# 592  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L135.jpg
# 593  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL135.jpg
# 594  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L143.jpg
# 595  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL143.jpg
# 596  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L146.jpg
# 597  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL146.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y19F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/19Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y19M = df[(df['Age(year)'] == 19)&(df['Gender']=='M')]
Y19M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 553         19      M             1      Normal        Both
# 554         19      M             1      Normal        Both
# 555         19      M             1      Normal        Both
# 556         19      M             1      Normal        Both
# 557         19      M             1      Normal        Both
# 558         19      M             1      Normal        Both
# 559         19      M             1      Normal        Both
# 560         19      M             1      Normal        Both
# 561         19      M             1      Normal        Both
# 562         19      M             1      Normal        Both
# 563         19      M             1      Normal        Both
# 564         19      M             1      Normal        Both
# 565         19      M             1      Normal        Both
# 566         19      M             1      Normal        Both
# 567         19      M             1      Normal        Both
# 568         19      M             1      Normal        Both
# 569         19      M             1      Normal        Both
# 570         19      M             1      Normal        Both
# 571         19      M             1      Normal          Lt
# 572         19      M             1      Normal          Rt
# 573         19      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 553  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L88.jpg
# 554  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL88.jpg
# 555  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L92.jpg
# 556  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL92.jpg
# 557  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       L98.jpg
# 558  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipL98.jpg
# 559  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L102.jpg
# 560  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL102.jpg
# 561  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L104.jpg
# 562  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL104.jpg
# 563  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L109.jpg
# 564  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL109.jpg
# 565  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L122.jpg
# 566  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL122.jpg
# 567  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L129.jpg
# 568  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL129.jpg
# 569  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L131.jpg
# 570  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL131.jpg
# 571  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipL123.jpg
# 572  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L221.jpg
# 573  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      L229.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y19M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/19Y/Male/'+filename)

# %% [markdown]
# ## Y20

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y20 = os.path.join(base_dir, '20Y')
os.makedirs(Full_image_Y20, exist_ok=True)

# %%
Full_image_Y20_F = os.path.join(Full_image_Y20, 'Female')
os.makedirs(Full_image_Y20_F, exist_ok=True)

Full_image_Y20_M = os.path.join(Full_image_Y20, 'Male')
os.makedirs(Full_image_Y20_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y20F = df[(df['Age(year)'] == 20)&(df['Gender']=='F')]
Y20F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 618         20      F             0      Normal        Both
# 619         20      F             0      Normal        Both
# 620         20      F             0      Normal        Both
# 621         20      F             0      Normal        Both
# 622         20      F             0      Normal        Both
# 623         20      F             0      Normal        Both
# 624         20      F             0      Normal        Both
# 625         20      F             0      Normal        Both
# 626         20      F             0      Normal        Both
# 627         20      F             0      Normal        Both
# 628         20      F             0      Normal        Both
# 629         20      F             0      Normal        Both
# 630         20      F             0      Normal        Both
# 631         20      F             0      Normal        Both
# 632         20      F             0      Normal        Both
# 633         20      F             0      Normal        Both
# 634         20      F             0      Normal        Both
# 635         20      F             0      Normal        Both
# 636         20      F             0      Normal          Lt
# 637         20      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 618  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q59.jpg
# 619  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ59.jpg
# 620  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q66.jpg
# 621  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ66.jpg
# 622  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q68.jpg
# 623  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ68.jpg
# 624  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q76.jpg
# 625  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ76.jpg
# 626  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q77.jpg
# 627  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ77.jpg
# 628  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q82.jpg
# 629  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ82.jpg
# 630  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q88.jpg
# 631  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ88.jpg
# 632  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q89.jpg
# 633  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ89.jpg
# 634  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q97.jpg
# 635  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ97.jpg
# 636  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ146.jpg
# 637  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q43.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y20F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/20Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y20M = df[(df['Age(year)'] == 20)&(df['Gender']=='M')]
Y20M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 598         20      M             1      Normal        Both
# 599         20      M             1      Normal        Both
# 600         20      M             1      Normal        Both
# 601         20      M             1      Normal        Both
# 602         20      M             1      Normal        Both
# 603         20      M             1      Normal        Both
# 604         20      M             1      Normal        Both
# 605         20      M             1      Normal        Both
# 606         20      M             1      Normal        Both
# 607         20      M             1      Normal        Both
# 608         20      M             1      Normal        Both
# 609         20      M             1      Normal        Both
# 610         20      M             1      Normal        Both
# 611         20      M             1      Normal        Both
# 612         20      M             1      Normal        Both
# 613         20      M             1      Normal        Both
# 614         20      M             1      Normal        Both
# 615         20      M             1      Normal        Both
# 616         20      M             1      Normal          Lt
# 617         20      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 598  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q62.jpg
# 599  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ62.jpg
# 600  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q64.jpg
# 601  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ64.jpg
# 602  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q90.jpg
# 603  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ90.jpg
# 604  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q96.jpg
# 605  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ96.jpg
# 606  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q131.jpg
# 607  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ131.jpg
# 608  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q132.jpg
# 609  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ132.jpg
# 610  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q134.jpg
# 611  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ134.jpg
# 612  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q137.jpg
# 613  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ137.jpg
# 614  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Q148.jpg
# 615  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipQ148.jpg
# 616  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipQ37.jpg
# 617  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Q67.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y20M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/20Y/Male/'+filename)

# %% [markdown]
# ## Y21

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y21 = os.path.join(base_dir, '21Y')
os.makedirs(Full_image_Y21, exist_ok=True)

# %%
Full_image_Y21_F = os.path.join(Full_image_Y21, 'Female')
os.makedirs(Full_image_Y21_F, exist_ok=True)

Full_image_Y21_M = os.path.join(Full_image_Y21, 'Male')
os.makedirs(Full_image_Y21_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y21F = df[(df['Age(year)'] == 21)&(df['Gender']=='F')]
Y21F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 659         21      F             0      Normal        Both
# 660         21      F             0      Normal        Both
# 661         21      F             0      Normal        Both
# 662         21      F             0      Normal        Both
# 663         21      F             0      Normal        Both
# 664         21      F             0      Normal        Both
# 665         21      F             0      Normal        Both
# 666         21      F             0      Normal        Both
# 667         21      F             0      Normal        Both
# 668         21      F             0      Normal        Both
# 669         21      F             0      Normal        Both
# 670         21      F             0      Normal        Both
# 671         21      F             0      Normal        Both
# 672         21      F             0      Normal        Both
# 673         21      F             0      Normal        Both
# 674         21      F             0      Normal        Both
# 675         21      F             0      Normal        Both
# 676         21      F             0      Normal        Both
# 677         21      F             0      Normal          Lt
# 678         21      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 659  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N85.jpg
# 660  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN85.jpg
# 661  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N91.jpg
# 662  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN91.jpg
# 663  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N119.jpg
# 664  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN119.jpg
# 665  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N127.jpg
# 666  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN127.jpg
# 667  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N132.jpg
# 668  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN132.jpg
# 669  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N134.jpg
# 670  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN134.jpg
# 671  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N136.jpg
# 672  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN136.jpg
# 673  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N142.jpg
# 674  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN142.jpg
# 675  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N188.jpg
# 676  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN188.jpg
# 677  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN111.jpg
# 678  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N21.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y21F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/21Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y21M = df[(df['Age(year)'] == 21)&(df['Gender']=='M')]
Y21M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 638         21      M             1      Normal        Both
# 639         21      M             1      Normal        Both
# 640         21      M             1      Normal        Both
# 641         21      M             1      Normal        Both
# 642         21      M             1      Normal        Both
# 643         21      M             1      Normal        Both
# 644         21      M             1      Normal        Both
# 645         21      M             1      Normal        Both
# 646         21      M             1      Normal        Both
# 647         21      M             1      Normal        Both
# 648         21      M             1      Normal        Both
# 649         21      M             1      Normal        Both
# 650         21      M             1      Normal        Both
# 651         21      M             1      Normal        Both
# 652         21      M             1      Normal        Both
# 653         21      M             1      Normal        Both
# 654         21      M             1      Normal        Both
# 655         21      M             1      Normal        Both
# 656         21      M             1      Normal          Lt
# 657         21      M             1      Normal          Lt
# 658         21      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 638  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N109.jpg
# 639  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN109.jpg
# 640  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N126.jpg
# 641  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN126.jpg
# 642  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N141.jpg
# 643  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN141.jpg
# 644  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N163.jpg
# 645  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN163.jpg
# 646  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N179.jpg
# 647  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN179.jpg
# 648  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N189.jpg
# 649  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN189.jpg
# 650  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N202.jpg
# 651  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN202.jpg
# 652  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N204.jpg
# 653  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN204.jpg
# 654  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      N207.jpg
# 655  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipN207.jpg
# 656  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN23.jpg
# 657  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipN42.jpg
# 658  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       N76.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y21M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/21Y/Male/'+filename)

# %% [markdown]
# ## Y22

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y22 = os.path.join(base_dir, '22Y')
os.makedirs(Full_image_Y22, exist_ok=True)

# %%
Full_image_Y22_F = os.path.join(Full_image_Y22, 'Female')
os.makedirs(Full_image_Y22_F, exist_ok=True)

Full_image_Y22_M = os.path.join(Full_image_Y22, 'Male')
os.makedirs(Full_image_Y22_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y22F = df[(df['Age(year)'] == 22)&(df['Gender']=='F')]
Y22F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 699         22      F             0      Normal        Both
# 700         22      F             0      Normal        Both
# 701         22      F             0      Normal        Both
# 702         22      F             0      Normal        Both
# 703         22      F             0      Normal        Both
# 704         22      F             0      Normal        Both
# 705         22      F             0      Normal        Both
# 706         22      F             0      Normal        Both
# 707         22      F             0      Normal        Both
# 708         22      F             0      Normal        Both
# 709         22      F             0      Normal        Both
# 710         22      F             0      Normal        Both
# 711         22      F             0      Normal        Both
# 712         22      F             0      Normal        Both
# 713         22      F             0      Normal        Both
# 714         22      F             0      Normal        Both
# 715         22      F             0      Normal        Both
# 716         22      F             0      Normal        Both
# 717         22      F             0      Normal          Lt
# 718         22      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 699  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U85.jpg
# 700  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU85.jpg
# 701  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U88.jpg
# 702  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU88.jpg
# 703  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U93.jpg
# 704  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU93.jpg
# 705  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U96.jpg
# 706  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU96.jpg
# 707  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U97.jpg
# 708  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipU97.jpg
# 709  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U112.jpg
# 710  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU112.jpg
# 711  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U115.jpg
# 712  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU115.jpg
# 713  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U122.jpg
# 714  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU122.jpg
# 715  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U129.jpg
# 716  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU129.jpg
# 717  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU260.jpg
# 718  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U59.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y22F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/22Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y22M = df[(df['Age(year)'] == 22)&(df['Gender']=='M')]
Y22M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 679         22      M             1      Normal        Both
# 680         22      M             1      Normal        Both
# 681         22      M             1      Normal        Both
# 682         22      M             1      Normal        Both
# 683         22      M             1      Normal        Both
# 684         22      M             1      Normal        Both
# 685         22      M             1      Normal        Both
# 686         22      M             1      Normal        Both
# 687         22      M             1      Normal        Both
# 688         22      M             1      Normal        Both
# 689         22      M             1      Normal        Both
# 690         22      M             1      Normal        Both
# 691         22      M             1      Normal        Both
# 692         22      M             1      Normal        Both
# 693         22      M             1      Normal        Both
# 694         22      M             1      Normal        Both
# 695         22      M             1      Normal          Lt
# 696         22      M             1      Normal          Lt
# 697         22      M             1      Normal          Rt
# 698         22      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 679  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U126.jpg
# 680  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU126.jpg
# 681  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U138.jpg
# 682  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU138.jpg
# 683  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U145.jpg
# 684  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU145.jpg
# 685  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U147.jpg
# 686  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU147.jpg
# 687  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U164.jpg
# 688  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU164.jpg
# 689  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U174.jpg
# 690  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU174.jpg
# 691  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U176.jpg
# 692  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU176.jpg
# 693  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      U179.jpg
# 694  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU179.jpg
# 695  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU204.jpg
# 696  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipU251.jpg
# 697  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U54.jpg
# 698  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       U80.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y22M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/22Y/Male/'+filename)

# %% [markdown]
# ## Y23

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y23 = os.path.join(base_dir, '23Y')
os.makedirs(Full_image_Y23, exist_ok=True)

# %%
Full_image_Y23_F = os.path.join(Full_image_Y23, 'Female')
os.makedirs(Full_image_Y23_F, exist_ok=True)

Full_image_Y23_M = os.path.join(Full_image_Y23, 'Male')
os.makedirs(Full_image_Y23_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y23F = df[(df['Age(year)'] == 23)&(df['Gender']=='F')]
Y23F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 741         23      F             0      Normal        Both
# 742         23      F             0      Normal        Both
# 743         23      F             0      Normal        Both
# 744         23      F             0      Normal        Both
# 745         23      F             0      Normal        Both
# 746         23      F             0      Normal        Both
# 747         23      F             0      Normal        Both
# 748         23      F             0      Normal        Both
# 749         23      F             0      Normal        Both
# 750         23      F             0      Normal        Both
# 751         23      F             0      Normal        Both
# 752         23      F             0      Normal        Both
# 753         23      F             0      Normal        Both
# 754         23      F             0      Normal        Both
# 755         23      F             0      Normal        Both
# 756         23      F             0      Normal        Both
# 757         23      F             0      Normal          Rt
# 758         23      F             0      Normal          Rt
# 759         23      F             0      Normal          Rt
# 760         23      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 741  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E68.jpg
# 742  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE68.jpg
# 743  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E76.jpg
# 744  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE76.jpg
# 745  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E79.jpg
# 746  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE79.jpg
# 747  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       E87.jpg
# 748  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipE87.jpg
# 749  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E104.jpg
# 750  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE104.jpg
# 751  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E112.jpg
# 752  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE112.jpg
# 753  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E124.jpg
# 754  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE124.jpg
# 755  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E130.jpg
# 756  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE130.jpg
# 757  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E144.jpg
# 758  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E153.jpg
# 759  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E166.jpg
# 760  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E169.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y23F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/23Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y23M = df[(df['Age(year)'] == 23)&(df['Gender']=='M')]
Y23M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 719         23      M             1      Normal        Both
# 720         23      M             1      Normal        Both
# 721         23      M             1      Normal        Both
# 722         23      M             1      Normal        Both
# 723         23      M             1      Normal        Both
# 724         23      M             1      Normal        Both
# 725         23      M             1      Normal        Both
# 726         23      M             1      Normal        Both
# 727         23      M             1      Normal        Both
# 728         23      M             1      Normal        Both
# 729         23      M             1      Normal        Both
# 730         23      M             1      Normal        Both
# 731         23      M             1      Normal        Both
# 732         23      M             1      Normal        Both
# 733         23      M             1      Normal        Both
# 734         23      M             1      Normal        Both
# 735         23      M             1      Normal        Both
# 736         23      M             1      Normal        Both
# 737         23      M             1      Normal        Both
# 738         23      M             1      Normal        Both
# 739         23      M             1      Normal        Both
# 740         23      M             1      Normal        Both
#
#                                              Path_Name      Filename
# 719  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E134.jpg
# 720  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE134.jpg
# 721  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E136.jpg
# 722  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE136.jpg
# 723  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E139.jpg
# 724  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE139.jpg
# 725  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E142.jpg
# 726  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE142.jpg
# 727  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E146.jpg
# 728  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE146.jpg
# 729  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E152.jpg
# 730  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE152.jpg
# 731  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E164.jpg
# 732  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE164.jpg
# 733  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E165.jpg
# 734  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE165.jpg
# 735  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E172.jpg
# 736  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE172.jpg
# 737  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E176.jpg
# 738  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE176.jpg
# 739  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      E183.jpg
# 740  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipE183.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y23M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/23Y/Male/'+filename)

# %% [markdown]
# ## Y24

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y24 = os.path.join(base_dir, '24Y')
os.makedirs(Full_image_Y24, exist_ok=True)

# %%
Full_image_Y24_F = os.path.join(Full_image_Y24, 'Female')
os.makedirs(Full_image_Y24_F, exist_ok=True)

Full_image_Y24_M = os.path.join(Full_image_Y24, 'Male')
os.makedirs(Full_image_Y24_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y24F = df[(df['Age(year)'] == 24)&(df['Gender']=='F')]
Y24F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 781         24      F             0      Normal        Both
# 782         24      F             0      Normal        Both
# 783         24      F             0      Normal        Both
# 784         24      F             0      Normal        Both
# 785         24      F             0      Normal        Both
# 786         24      F             0      Normal        Both
# 787         24      F             0      Normal        Both
# 788         24      F             0      Normal        Both
# 789         24      F             0      Normal        Both
# 790         24      F             0      Normal        Both
# 791         24      F             0      Normal        Both
# 792         24      F             0      Normal        Both
# 793         24      F             0      Normal        Both
# 794         24      F             0      Normal        Both
# 795         24      F             0      Normal        Both
# 796         24      F             0      Normal        Both
# 797         24      F             0      Normal          Lt
# 798         24      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 781  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z70.jpg
# 782  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ70.jpg
# 783  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z75.jpg
# 784  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ75.jpg
# 785  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z80.jpg
# 786  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ80.jpg
# 787  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z82.jpg
# 788  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ82.jpg
# 789  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z93.jpg
# 790  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ93.jpg
# 791  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z105.jpg
# 792  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ105.jpg
# 793  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z121.jpg
# 794  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ121.jpg
# 795  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z122.jpg
# 796  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ122.jpg
# 797  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ242.jpg
# 798  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z156.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y24F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/24Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y24M = df[(df['Age(year)'] == 24)&(df['Gender']=='M')]
Y24M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 761         24      M             1      Normal        Both
# 762         24      M             1      Normal        Both
# 763         24      M             1      Normal        Both
# 764         24      M             1      Normal        Both
# 765         24      M             1      Normal        Both
# 766         24      M             1      Normal        Both
# 767         24      M             1      Normal        Both
# 768         24      M             1      Normal        Both
# 769         24      M             1      Normal        Both
# 770         24      M             1      Normal        Both
# 771         24      M             1      Normal        Both
# 772         24      M             1      Normal        Both
# 773         24      M             1      Normal        Both
# 774         24      M             1      Normal        Both
# 775         24      M             1      Normal        Both
# 776         24      M             1      Normal        Both
# 777         24      M             1      Normal        Both
# 778         24      M             1      Normal        Both
# 779         24      M             1      Normal          Lt
# 780         24      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 761  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z74.jpg
# 762  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ74.jpg
# 763  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z85.jpg
# 764  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ85.jpg
# 765  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z86.jpg
# 766  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ86.jpg
# 767  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       Z90.jpg
# 768  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipZ90.jpg
# 769  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z100.jpg
# 770  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ100.jpg
# 771  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z101.jpg
# 772  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ101.jpg
# 773  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z135.jpg
# 774  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ135.jpg
# 775  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z157.jpg
# 776  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ157.jpg
# 777  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z165.jpg
# 778  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ165.jpg
# 779  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipZ403.jpg
# 780  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      Z207.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y24M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/24Y/Male/'+filename)

# %% [markdown]
# ## Y25

# %%
base_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train'
os.makedirs(base_dir, exist_ok=True)

Full_image_Y25 = os.path.join(base_dir, '25Y')
os.makedirs(Full_image_Y25, exist_ok=True)

# %%
Full_image_Y25_F = os.path.join(Full_image_Y25, 'Female')
os.makedirs(Full_image_Y25_F, exist_ok=True)

Full_image_Y25_M = os.path.join(Full_image_Y25, 'Male')
os.makedirs(Full_image_Y25_M, exist_ok=True)

# %% [markdown]
# ### Female

# %%
Y25F = df[(df['Age(year)'] == 25)&(df['Gender']=='F')]
Y25F
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 819         25      F             0      Normal        Both
# 820         25      F             0      Normal        Both
# 821         25      F             0      Normal        Both
# 822         25      F             0      Normal        Both
# 823         25      F             0      Normal        Both
# 824         25      F             0      Normal        Both
# 825         25      F             0      Normal        Both
# 826         25      F             0      Normal        Both
# 827         25      F             0      Normal        Both
# 828         25      F             0      Normal        Both
# 829         25      F             0      Normal        Both
# 830         25      F             0      Normal        Both
# 831         25      F             0      Normal        Both
# 832         25      F             0      Normal        Both
# 833         25      F             0      Normal        Both
# 834         25      F             0      Normal        Both
# 835         25      F             0      Normal        Both
# 836         25      F             0      Normal        Both
# 837         25      F             0      Normal          Lt
# 838         25      F             0      Normal          Lt
# 839         25      F             0      Normal          Rt
#
#                                              Path_Name      Filename
# 819  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J59.jpg
# 820  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ59.jpg
# 821  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J64.jpg
# 822  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ64.jpg
# 823  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J74.jpg
# 824  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...   FlipJ74.jpg
# 825  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J107.jpg
# 826  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ107.jpg
# 827  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J114.jpg
# 828  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ114.jpg
# 829  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J122.jpg
# 830  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ122.jpg
# 831  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J125.jpg
# 832  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ125.jpg
# 833  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J133.jpg
# 834  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ133.jpg
# 835  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J140.jpg
# 836  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ140.jpg
# 837  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ272.jpg
# 838  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ280.jpg
# 839  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J244.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y25F['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/25Y/Female/'+filename)

# %% [markdown]
# ### Male

# %%
Y25M = df[(df['Age(year)'] == 25)&(df['Gender']=='M')]
Y25M
# Out:
#      Age(year) Gender  Gender_Class Folder_type Folder_name  \
# 799         25      M             1      Normal        Both
# 800         25      M             1      Normal        Both
# 801         25      M             1      Normal        Both
# 802         25      M             1      Normal        Both
# 803         25      M             1      Normal        Both
# 804         25      M             1      Normal        Both
# 805         25      M             1      Normal        Both
# 806         25      M             1      Normal        Both
# 807         25      M             1      Normal        Both
# 808         25      M             1      Normal        Both
# 809         25      M             1      Normal        Both
# 810         25      M             1      Normal        Both
# 811         25      M             1      Normal        Both
# 812         25      M             1      Normal        Both
# 813         25      M             1      Normal        Both
# 814         25      M             1      Normal        Both
# 815         25      M             1      Normal          Lt
# 816         25      M             1      Normal          Lt
# 817         25      M             1      Normal          Rt
# 818         25      M             1      Normal          Rt
#
#                                              Path_Name      Filename
# 799  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J315.jpg
# 800  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ315.jpg
# 801  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J322.jpg
# 802  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ322.jpg
# 803  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J336.jpg
# 804  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ336.jpg
# 805  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J339.jpg
# 806  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ339.jpg
# 807  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J346.jpg
# 808  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ346.jpg
# 809  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J350.jpg
# 810  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ350.jpg
# 811  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J365.jpg
# 812  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ365.jpg
# 813  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J408.jpg
# 814  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ408.jpg
# 815  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ162.jpg
# 816  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...  FlipJ176.jpg
# 817  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       J81.jpg
# 818  /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      J146.jpg

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

path = Y25M['Path_Name'].tolist()
for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    # print(i)
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Detection/25percent/Train/25Y/Male/'+filename)
