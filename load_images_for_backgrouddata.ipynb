# %% [markdown]
# <a href="https://colab.research.google.com/github/nattntn/DataPreparation_ForDeeptooth/blob/main/load_images_for_backgrouddata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import urllib.request
import pandas as pd

# %%
#เชื่อม google drive
from google.colab  import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# อ่านตาราง
df = pd.read_csv('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/Model/Multi_task(Age)(7-25)/Bg_train.csv')  # เปลี่ยนเส้นทางไปยังไฟล์ของคุณ

# %%
df
# Out:
#       Unnamed: 0  Age(year) Gender Folder_type Folder_name  \
# 0            184          7      M      Normal        Both
# 1            120          7      M      Normal        Both
# 2            207          7      M      Normal        Both
# 3            148          7      M      Normal        Both
# 4            214          7      M      Normal          Lt
# ...          ...        ...    ...         ...         ...
# 2655        4050         25      F      Normal        Both
# 2656        4044         25      F      Normal        Both
# 2657        4024         25      F      Normal        Both
# 2658        4020         25      F      Normal        Both
# 2659        4003         25      F      Normal        Both
#
#                                               Path_Name       Filename
# 0     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...      VV116.jpg
# 1     /content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_to...       VV13.jpg
# ...

# %%
path = df['Path_Name'].tolist()

# %%
save_dir = '/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/images'  # เปลี่ยนเป็นเส้นทางที่คุณต้องการบันทึก
os.makedirs(save_dir, exist_ok=True)

# %%
from PIL import Image   # PIL = module ที่ใช้ในการจัดการภาพ
import matplotlib.pyplot as plt # แสดงภาพ

for i in path:
    filename = i.split("/")[-1]
    img = Image.open(i) #Image.open(i) คือ คำสั่งที่ใช้โหลดรูปภาพจาก path หรือที่อยู่ของไฟล์รูปภาพที่ระบุไว้ในตัวแปร i โดย Image เป็น module ที่ใช้จัดการรูปภาพและสร้างเครื่องมือในการประมวลผลภาพต่างๆ ซึ่งต้องติดตั้งก่อนใช้งาน และ open เป็น method ที่ใช้เปิดไฟล์ภาพ ซึ่งจะอ่านข้อมูลภาพและโหลดภาพให้เรียบร้อยก่อนที่จะนำไปใช้งานต่อไป
    img.save('/content/gdrive/MyDrive/Tooth_Shap_GPT/Deep_tooth/images/'+filename)
